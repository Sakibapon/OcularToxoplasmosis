# %%
import sys
import os
from math import log
import numpy as np
import seaborn as sns
import pandas as pd
import scipy as sp
from PIL import Image
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_addons as tfa
from tensorflow import keras
from tensorflow.keras import layers
import cv2 as cv
import pickle
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.models import Model
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.utils import compute_class_weight
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import roc_curve, roc_auc_score, auc

np.random.seed(72)
tf.random.set_seed(72)
sess = tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(log_device_placement=True))
# Out:
# D:\anaconda\envs\tf_gpu\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.3.0 and strictly below 2.6.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.8.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 4070 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
def get_train_test(train_dir, test_dir):
    datagen_train = ImageDataGenerator(rescale=1./255, width_shift_range=0.1, height_shift_range=0.1,
                                      horizontal_flip=True,  vertical_flip=False)
    datagen_test = ImageDataGenerator(rescale=1./255)

    generator_train = datagen_train.flow_from_directory(directory=train_dir, target_size=(image_size, image_size),
                                                        batch_size=batch_size, shuffle=True)
    generator_test = datagen_test.flow_from_directory(directory=test_dir, target_size=(image_size, image_size),
                                                      batch_size=batch_size, shuffle=False)

    num_classes = generator_train.num_classes
    labels = generator_train.classes
    class_weights = compute_class_weight(class_weight="balanced", classes=np.unique(labels), y=labels)
    class_weights = dict(zip(np.unique(labels), class_weights))
    print(class_weights)
    
    steps_per_epoch = generator_train.n / batch_size
    steps_test = generator_test.n / batch_size
    return generator_train, generator_test, labels, class_weights, num_classes, steps_per_epoch, steps_test

def compile_model(model, weight):
    optimizer = Adam(lr=0.0000026) 
    loss = 'categorical_crossentropy'

    metrics = ['accuracy', 'categorical_accuracy', tf.keras.metrics.AUC(), tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), 
               tf.keras.metrics.TruePositives(), tf.keras.metrics.TrueNegatives(), tf.keras.metrics.FalsePositives(), 
               tf.keras.metrics.FalseNegatives(), tfa.metrics.CohenKappa(num_classes = num_classes), 
               tfa.metrics.F1Score(num_classes = num_classes)]

    model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

    lr = tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.1,
        patience=9, mode="max", min_delta=0.0001, min_lr=0.00001, verbose=1)
    checkpoint = ModelCheckpoint(filepath=weight, save_best_only=True, monitor = 'val_accuracy', verbose=1)
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=1, restore_best_weights=True)

    callbacks = [lr, checkpoint, early_stopping]
    return model, callbacks

def evaluate_(model, generator_test):
    model.evaluate(generator_test)
    
    y_pred = model.predict(generator_test)
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_true = generator_test.classes
    class_labels = list(generator_test.class_indices.keys())

    print(classification_report(y_true, y_pred_classes))
    cm = confusion_matrix(y_true, y_pred_classes)
    
    # Plotting the confusion matrix
    plt.figure(figsize=(8, 8))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_labels, yticklabels=class_labels)
    plt.show()
    
def plot_graphs(history, generator_test):
    plt.figure(figsize=(15,7))
    plt.plot(history.history['accuracy'], 'r', linewidth=2.5)
    plt.plot(history.history['val_accuracy'], linewidth=2.5)
    plt.title('Model Accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['Training Accuracy', 'Testing Accuracy'], loc='upper left')
    plt.show()

    plt.figure(figsize=(15,7))
    plt.plot(history.history['loss'], 'r', linewidth=2.5)
    plt.plot(history.history['val_loss'], linewidth=2.5)
    plt.title('Model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['Train Loss', 'Test Loss'], loc='upper left')
    plt.show()
    
    # Generate predictions
    predictions = model.predict_generator(generator_test)
    # Get true labels
    true_labels = generator_test.classes
    # Binarize the true labels
    encoder = OneHotEncoder(sparse=False)
    true_labels = encoder.fit_transform(true_labels.reshape(-1, 1))
    # Calculate ROC curve and ROC AUC for each class
    n_classes = true_labels.shape[1]
    fpr = dict()
    tpr = dict()
    roc_auc = dict()

    for class_idx in range(n_classes):
        fpr[class_idx], tpr[class_idx], _ = roc_curve(true_labels[:, class_idx], predictions[:, class_idx])
        roc_auc[class_idx] = auc(fpr[class_idx], tpr[class_idx])

    # Plot ROC curves for each class
    plt.figure(figsize=(12, 12))
    for class_idx in range(n_classes):

        plt.plot(fpr[class_idx], tpr[class_idx], label='ROC curve (area = %0.2f) for class %d' % (roc_auc[class_idx], class_idx),
                linewidth=2.5)

    plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic per Class')
    plt.legend(loc='lower right')
    plt.show()

# %%
# Params
num_classes = 2
batch_size = 8
image_size = 112
weight = 'convnext.h5'

# %%
from keras_cv_attention_models import convnext
model = convnext.ConvNeXtLarge(input_shape=(image_size, image_size, 3) , num_classes=num_classes, 
                         drop_connect_rate=0.2, classifier_activation="softmax")
# Out:
# >>>> Load pretrained from: C:\Users\sakib\.keras\models\convnext_large_224_imagenet.h5
# WARNING:tensorflow:Skipping loading weights for layer #334 (named predictions) due to mismatch in shape for weight predictions/kernel:0. Weight expects shape (1536, 2). Received saved weight with shape (1536, 1000)
# WARNING:tensorflow:Skipping loading weights for layer #334 (named predictions) due to mismatch in shape for weight predictions/bias:0. Weight expects shape (2,). Received saved weight with shape (1000,)

# %%
train_dir = r"F:\Projects\Personal\Ocular Toxoplasmosis\data\BinaryClassification\train"
test_dir = r"F:\Projects\Personal\Ocular Toxoplasmosis\data\BinaryClassification\val"
generator_train, generator_test, labels, class_weights, num_classes, steps_per_epoch, steps_test = get_train_test(train_dir, test_dir)
model, callbacks = compile_model(model, weight)
# Out:
# Found 366 images belonging to 2 classes.
# Found 83 images belonging to 2 classes.
# {0: 1.3863636363636365, 1: 0.782051282051282}
# D:\anaconda\envs\tf_gpu\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
model.summary()
# Out:
# Model: "convnext_large"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 112, 112, 3  0           []
#                                 )]
#
#  stem_conv (Conv2D)             (None, 28, 28, 192)  9408        ['input_1[0][0]']
#
#  stem_ln (LayerNormalization)   (None, 28, 28, 192)  384         ['stem_conv[0][0]']
#
#  stack1_block1_dw_pad (ZeroPadd  (None, 34, 34, 192)  0          ['stem_ln[0][0]']
#  ing2D)
#
#  stack1_block1_dw_conv (Depthwi  (None, 28, 28, 192)  9600       ['stack1_block1_dw_pad[0][0]']
#  seConv2D)
#
#  stack1_block1_ln (LayerNormali  (None, 28, 28, 192)  384        ['stack1_block1_dw_conv[0][0]']
#  zation)
#
#  stack1_block1_up_dense (Dense)  (None, 28, 28, 768)  148224     ['stack1_block1_ln[0][0]']
#
#  stack1_block1_gelu (Activation  (None, 28, 28, 768)  0          ['stack1_block1_up_dense[0][0]']
#  )
#
#  stack1_block1_down_dense (Dens  (None, 28, 28, 192)  147648     ['stack1_block1_gelu[0][0]']
#  e)
#
#  stack1_block1_gamma (ChannelAf  (None, 28, 28, 192)  192        ['stack1_block1_down_dense[0][0]'
#  fine)                                                           ]
#
#  stack1_block1_output (Add)     (None, 28, 28, 192)  0           ['stem_ln[0][0]',
#                                                                   'stack1_block1_gamma[0][0]']
#
#  stack1_block2_dw_pad (ZeroPadd  (None, 34, 34, 192)  0          ['stack1_block1_output[0][0]']
#  ing2D)
#
#  stack1_block2_dw_conv (Depthwi  (None, 28, 28, 192)  9600       ['stack1_block2_dw_pad[0][0]']
#  seConv2D)
#
#  stack1_block2_ln (LayerNormali  (None, 28, 28, 192)  384        ['stack1_block2_dw_conv[0][0]']
#  zation)
#
#  stack1_block2_up_dense (Dense)  (None, 28, 28, 768)  148224     ['stack1_block2_ln[0][0]']
#
#  stack1_block2_gelu (Activation  (None, 28, 28, 768)  0          ['stack1_block2_up_dense[0][0]']
#  )
#
#  stack1_block2_down_dense (Dens  (None, 28, 28, 192)  147648     ['stack1_block2_gelu[0][0]']
#  e)
#
#  stack1_block2_gamma (ChannelAf  (None, 28, 28, 192)  192        ['stack1_block2_down_dense[0][0]'
#  fine)                                                           ]
#
#  stack1_block2_drop (Dropout)   (None, 28, 28, 192)  0           ['stack1_block2_gamma[0][0]']
#
#  stack1_block2_output (Add)     (None, 28, 28, 192)  0           ['stack1_block1_output[0][0]',
#                                                                   'stack1_block2_drop[0][0]']
#
#  stack1_block3_dw_pad (ZeroPadd  (None, 34, 34, 192)  0          ['stack1_block2_output[0][0]']
#  ing2D)
#
#  stack1_block3_dw_conv (Depthwi  (None, 28, 28, 192)  9600       ['stack1_block3_dw_pad[0][0]']
#  seConv2D)
#
#  stack1_block3_ln (LayerNormali  (None, 28, 28, 192)  384        ['stack1_block3_dw_conv[0][0]']
#  zation)
#
#  stack1_block3_up_dense (Dense)  (None, 28, 28, 768)  148224     ['stack1_block3_ln[0][0]']
#
#  stack1_block3_gelu (Activation  (None, 28, 28, 768)  0          ['stack1_block3_up_dense[0][0]']
#  )
#
#  stack1_block3_down_dense (Dens  (None, 28, 28, 192)  147648     ['stack1_block3_gelu[0][0]']
#  e)
#
#  stack1_block3_gamma (ChannelAf  (None, 28, 28, 192)  192        ['stack1_block3_down_dense[0][0]'
#  fine)                                                           ]
#
#  stack1_block3_drop (Dropout)   (None, 28, 28, 192)  0           ['stack1_block3_gamma[0][0]']
#
#  stack1_block3_output (Add)     (None, 28, 28, 192)  0           ['stack1_block2_output[0][0]',
#                                                                   'stack1_block3_drop[0][0]']
#  stack2_downsample_ln (LayerNor  (None, 28, 28, 192)  384        ['stack1_block3_output[0][0]']
#  malization)
#
#  stack2_downsample_conv (Conv2D  (None, 14, 14, 384)  295296     ['stack2_downsample_ln[0][0]']
#  )
#
#  stack2_block1_dw_pad (ZeroPadd  (None, 20, 20, 384)  0          ['stack2_downsample_conv[0][0]']
#  ing2D)
#
#  stack2_block1_dw_conv (Depthwi  (None, 14, 14, 384)  19200      ['stack2_block1_dw_pad[0][0]']
#  seConv2D)
#
#  stack2_block1_ln (LayerNormali  (None, 14, 14, 384)  768        ['stack2_block1_dw_conv[0][0]']
#  zation)
#
#  stack2_block1_up_dense (Dense)  (None, 14, 14, 1536  591360     ['stack2_block1_ln[0][0]']
#                                 )
#
#  stack2_block1_gelu (Activation  (None, 14, 14, 1536  0          ['stack2_block1_up_dense[0][0]']
#  )                              )
#
#  stack2_block1_down_dense (Dens  (None, 14, 14, 384)  590208     ['stack2_block1_gelu[0][0]']
#  e)
#
#  stack2_block1_gamma (ChannelAf  (None, 14, 14, 384)  384        ['stack2_block1_down_dense[0][0]'
#  fine)                                                           ]
#
#  stack2_block1_drop (Dropout)   (None, 14, 14, 384)  0           ['stack2_block1_gamma[0][0]']
#
#  stack2_block1_output (Add)     (None, 14, 14, 384)  0           ['stack2_downsample_conv[0][0]',
#                                                                   'stack2_block1_drop[0][0]']
#
#  stack2_block2_dw_pad (ZeroPadd  (None, 20, 20, 384)  0          ['stack2_block1_output[0][0]']
#  ing2D)
#
#  stack2_block2_dw_conv (Depthwi  (None, 14, 14, 384)  19200      ['stack2_block2_dw_pad[0][0]']
#  seConv2D)
#
#  stack2_block2_ln (LayerNormali  (None, 14, 14, 384)  768        ['stack2_block2_dw_conv[0][0]']
#  zation)
#
#  stack2_block2_up_dense (Dense)  (None, 14, 14, 1536  591360     ['stack2_block2_ln[0][0]']
#                                 )
#
#  stack2_block2_gelu (Activation  (None, 14, 14, 1536  0          ['stack2_block2_up_dense[0][0]']
#  )                              )
#
#  stack2_block2_down_dense (Dens  (None, 14, 14, 384)  590208     ['stack2_block2_gelu[0][0]']
#  e)
#
#  stack2_block2_gamma (ChannelAf  (None, 14, 14, 384)  384        ['stack2_block2_down_dense[0][0]'
#  fine)                                                           ]
#
#  stack2_block2_drop (Dropout)   (None, 14, 14, 384)  0           ['stack2_block2_gamma[0][0]']
#
#  stack2_block2_output (Add)     (None, 14, 14, 384)  0           ['stack2_block1_output[0][0]',
#                                                                   'stack2_block2_drop[0][0]']
#
#  stack2_block3_dw_pad (ZeroPadd  (None, 20, 20, 384)  0          ['stack2_block2_output[0][0]']
#  ing2D)
#
#  stack2_block3_dw_conv (Depthwi  (None, 14, 14, 384)  19200      ['stack2_block3_dw_pad[0][0]']
#  seConv2D)
#
#  stack2_block3_ln (LayerNormali  (None, 14, 14, 384)  768        ['stack2_block3_dw_conv[0][0]']
#  zation)
#
#  stack2_block3_up_dense (Dense)  (None, 14, 14, 1536  591360     ['stack2_block3_ln[0][0]']
#                                 )
#
#  stack2_block3_gelu (Activation  (None, 14, 14, 1536  0          ['stack2_block3_up_dense[0][0]']
#  )                              )
#
#  stack2_block3_down_dense (Dens  (None, 14, 14, 384)  590208     ['stack2_block3_gelu[0][0]']
#  e)
#
#  stack2_block3_gamma (ChannelAf  (None, 14, 14, 384)  384        ['stack2_block3_down_dense[0][0]'
#  fine)                                                           ]
#
#  stack2_block3_drop (Dropout)   (None, 14, 14, 384)  0           ['stack2_block3_gamma[0][0]']
#
#  stack2_block3_output (Add)     (None, 14, 14, 384)  0           ['stack2_block2_output[0][0]',
#                                                                   'stack2_block3_drop[0][0]']
#
#  stack3_downsample_ln (LayerNor  (None, 14, 14, 384)  768        ['stack2_block3_output[0][0]']
#  malization)
#
#  stack3_downsample_conv (Conv2D  (None, 7, 7, 768)   1180416     ['stack3_downsample_ln[0][0]']
#  )
#
#  stack3_block1_dw_pad (ZeroPadd  (None, 13, 13, 768)  0          ['stack3_downsample_conv[0][0]']
#  ing2D)
#
#  stack3_block1_dw_conv (Depthwi  (None, 7, 7, 768)   38400       ['stack3_block1_dw_pad[0][0]']
#  seConv2D)
#
#  stack3_block1_ln (LayerNormali  (None, 7, 7, 768)   1536        ['stack3_block1_dw_conv[0][0]']
#  zation)
#
#  stack3_block1_up_dense (Dense)  (None, 7, 7, 3072)  2362368     ['stack3_block1_ln[0][0]']
#
#  stack3_block1_gelu (Activation  (None, 7, 7, 3072)  0           ['stack3_block1_up_dense[0][0]']
#  )
#
#  stack3_block1_down_dense (Dens  (None, 7, 7, 768)   2360064     ['stack3_block1_gelu[0][0]']
#  e)
#
#  stack3_block1_gamma (ChannelAf  (None, 7, 7, 768)   768         ['stack3_block1_down_dense[0][0]'
#  fine)                                                           ]
#
#  stack3_block1_drop (Dropout)   (None, 7, 7, 768)    0           ['stack3_block1_gamma[0][0]']
#
#  stack3_block1_output (Add)     (None, 7, 7, 768)    0           ['stack3_downsample_conv[0][0]',
#                                                                   'stack3_block1_drop[0][0]']
#
#  stack3_block2_dw_pad (ZeroPadd  (None, 13, 13, 768)  0          ['stack3_block1_output[0][0]']
#  ing2D)
#
#  stack3_block2_dw_conv (Depthwi  (None, 7, 7, 768)   38400       ['stack3_block2_dw_pad[0][0]']
#  seConv2D)
#
#  stack3_block2_ln (LayerNormali  (None, 7, 7, 768)   1536        ['stack3_block2_dw_conv[0][0]']
#  zation)
#
#  stack3_block2_up_dense (Dense)  (None, 7, 7, 3072)  2362368     ['stack3_block2_ln[0][0]']
#
#  stack3_block2_gelu (Activation  (None, 7, 7, 3072)  0           ['stack3_block2_up_dense[0][0]']
#  )
#
#  stack3_block2_down_dense (Dens  (None, 7, 7, 768)   2360064     ['stack3_block2_gelu[0][0]']
#  e)
#
#  stack3_block2_gamma (ChannelAf  (None, 7, 7, 768)   768         ['stack3_block2_down_dense[0][0]'
#  fine)                                                           ]
#
#  stack3_block2_drop (Dropout)   (None, 7, 7, 768)    0           ['stack3_block2_gamma[0][0]']
#
#  stack3_block2_output (Add)     (None, 7, 7, 768)    0           ['stack3_block1_output[0][0]',
#                                                                   'stack3_block2_drop[0][0]']
#
#  stack3_block3_dw_pad (ZeroPadd  (None, 13, 13, 768)  0          ['stack3_block2_output[0][0]']
#  ing2D)
#
#  stack3_block3_dw_conv (Depthwi  (None, 7, 7, 768)   38400       ['stack3_block3_dw_pad[0][0]']
#  seConv2D)
#
#  stack3_block3_ln (LayerNormali  (None, 7, 7, 768)   1536        ['stack3_block3_dw_conv[0][0]']
#  zation)
#
#  stack3_block3_up_dense (Dense)  (None, 7, 7, 3072)  2362368     ['stack3_block3_ln[0][0]']
#
#  stack3_block3_gelu (Activation  (None, 7, 7, 3072)  0           ['stack3_block3_up_dense[0][0]']
#  )
#
#  stack3_block3_down_dense (Dens  (None, 7, 7, 768)   2360064     ['stack3_block3_gelu[0][0]']
#  e)
#
#  stack3_block3_gamma (ChannelAf  (None, 7, 7, 768)   768         ['stack3_block3_down_dense[0][0]'
#  fine)                                                           ]
#
#  stack3_block3_drop (Dropout)   (None, 7, 7, 768)    0           ['stack3_block3_gamma[0][0]']
#
#  stack3_block3_output (Add)     (None, 7, 7, 768)    0           ['stack3_block2_output[0][0]',
#                                                                   'stack3_block3_drop[0][0]']
#
#  stack3_block4_dw_pad (ZeroPadd  (None, 13, 13, 768)  0          ['stack3_block3_output[0][0]']
#  ing2D)
#
#  stack3_block4_dw_conv (Depthwi  (None, 7, 7, 768)   38400       ['stack3_block4_dw_pad[0][0]']
#  seConv2D)
#
#  stack3_block4_ln (LayerNormali  (None, 7, 7, 768)   1536        ['stack3_block4_dw_conv[0][0]']
#  zation)
#
#  stack3_block4_up_dense (Dense)  (None, 7, 7, 3072)  2362368     ['stack3_block4_ln[0][0]']
#
#  stack3_block4_gelu (Activation  (None, 7, 7, 3072)  0           ['stack3_block4_up_dense[0][0]']
#  )
#
#  stack3_block4_down_dense (Dens  (None, 7, 7, 768)   2360064     ['stack3_block4_gelu[0][0]']
#  e)
#
#  stack3_block4_gamma (ChannelAf  (None, 7, 7, 768)   768         ['stack3_block4_down_dense[0][0]'
#  fine)                                                           ]
#
#  stack3_block4_drop (Dropout)   (None, 7, 7, 768)    0           ['stack3_block4_gamma[0][0]']
#
#  stack3_block4_output (Add)     (None, 7, 7, 768)    0           ['stack3_block3_output[0][0]',
#                                                                   'stack3_block4_drop[0][0]']
#
#  stack3_block5_dw_pad (ZeroPadd  (None, 13, 13, 768)  0          ['stack3_block4_output[0][0]']
#  ing2D)
#
#  stack3_block5_dw_conv (Depthwi  (None, 7, 7, 768)   38400       ['stack3_block5_dw_pad[0][0]']
#  seConv2D)
#
#  stack3_block5_ln (LayerNormali  (None, 7, 7, 768)   1536        ['stack3_block5_dw_conv[0][0]']
#  zation)
#
#  stack3_block5_up_dense (Dense)  (None, 7, 7, 3072)  2362368     ['stack3_block5_ln[0][0]']
#
#  stack3_block5_gelu (Activation  (None, 7, 7, 3072)  0           ['stack3_block5_up_dense[0][0]']
#  )
#
#  stack3_block5_down_dense (Dens  (None, 7, 7, 768)   2360064     ['stack3_block5_gelu[0][0]']
#  e)
#
#  stack3_block5_gamma (ChannelAf  (None, 7, 7, 768)   768         ['stack3_block5_down_dense[0][0]'
#  fine)                                                           ]
#
#  stack3_block5_drop (Dropout)   (None, 7, 7, 768)    0           ['stack3_block5_gamma[0][0]']
#
#  stack3_block5_output (Add)     (None, 7, 7, 768)    0           ['stack3_block4_output[0][0]',
#                                                                   'stack3_block5_drop[0][0]']
#
#  stack3_block6_dw_pad (ZeroPadd  (None, 13, 13, 768)  0          ['stack3_block5_output[0][0]']
#  ing2D)
#
#  stack3_block6_dw_conv (Depthwi  (None, 7, 7, 768)   38400       ['stack3_block6_dw_pad[0][0]']
#  seConv2D)
#
#  stack3_block6_ln (LayerNormali  (None, 7, 7, 768)   1536        ['stack3_block6_dw_conv[0][0]']
#  zation)
#
#  stack3_block6_up_dense (Dense)  (None, 7, 7, 3072)  2362368     ['stack3_block6_ln[0][0]']
#
#  stack3_block6_gelu (Activation  (None, 7, 7, 3072)  0           ['stack3_block6_up_dense[0][0]']
#  )
#
#  stack3_block6_down_dense (Dens  (None, 7, 7, 768)   2360064     ['stack3_block6_gelu[0][0]']
#  e)
#
#  stack3_block6_gamma (ChannelAf  (None, 7, 7, 768)   768         ['stack3_block6_down_dense[0][0]'
#  fine)                                                           ]
#
#  stack3_block6_drop (Dropout)   (None, 7, 7, 768)    0           ['stack3_block6_gamma[0][0]']
#
#  stack3_block6_output (Add)     (None, 7, 7, 768)    0           ['stack3_block5_output[0][0]',
#                                                                   'stack3_block6_drop[0][0]']
#
#  stack3_block7_dw_pad (ZeroPadd  (None, 13, 13, 768)  0          ['stack3_block6_output[0][0]']
#  ing2D)
#
#  stack3_block7_dw_conv (Depthwi  (None, 7, 7, 768)   38400       ['stack3_block7_dw_pad[0][0]']
#  seConv2D)
#
#  stack3_block7_ln (LayerNormali  (None, 7, 7, 768)   1536        ['stack3_block7_dw_conv[0][0]']
#  zation)
#  stack3_block7_up_dense (Dense)  (None, 7, 7, 3072)  2362368     ['stack3_block7_ln[0][0]']
#
#  stack3_block7_gelu (Activation  (None, 7, 7, 3072)  0           ['stack3_block7_up_dense[0][0]']
#  )
#
#  stack3_block7_down_dense (Dens  (None, 7, 7, 768)   2360064     ['stack3_block7_gelu[0][0]']
#  e)
#
#  stack3_block7_gamma (ChannelAf  (None, 7, 7, 768)   768         ['stack3_block7_down_dense[0][0]'
#  fine)                                                           ]
#
#  stack3_block7_drop (Dropout)   (None, 7, 7, 768)    0           ['stack3_block7_gamma[0][0]']
#
#  stack3_block7_output (Add)     (None, 7, 7, 768)    0           ['stack3_block6_output[0][0]',
#                                                                   'stack3_block7_drop[0][0]']
#
#  stack3_block8_dw_pad (ZeroPadd  (None, 13, 13, 768)  0          ['stack3_block7_output[0][0]']
#  ing2D)
#
#  stack3_block8_dw_conv (Depthwi  (None, 7, 7, 768)   38400       ['stack3_block8_dw_pad[0][0]']
#  seConv2D)
#
#  stack3_block8_ln (LayerNormali  (None, 7, 7, 768)   1536        ['stack3_block8_dw_conv[0][0]']
#  zation)
#
#  stack3_block8_up_dense (Dense)  (None, 7, 7, 3072)  2362368     ['stack3_block8_ln[0][0]']
#
#  stack3_block8_gelu (Activation  (None, 7, 7, 3072)  0           ['stack3_block8_up_dense[0][0]']
#  )
#
#  stack3_block8_down_dense (Dens  (None, 7, 7, 768)   2360064     ['stack3_block8_gelu[0][0]']
#  e)
#
#  stack3_block8_gamma (ChannelAf  (None, 7, 7, 768)   768         ['stack3_block8_down_dense[0][0]'
#  fine)                                                           ]
#
#  stack3_block8_drop (Dropout)   (None, 7, 7, 768)    0           ['stack3_block8_gamma[0][0]']
#
#  stack3_block8_output (Add)     (None, 7, 7, 768)    0           ['stack3_block7_output[0][0]',
#                                                                   'stack3_block8_drop[0][0]']
#
#  stack3_block9_dw_pad (ZeroPadd  (None, 13, 13, 768)  0          ['stack3_block8_output[0][0]']
#  ing2D)
#
#  stack3_block9_dw_conv (Depthwi  (None, 7, 7, 768)   38400       ['stack3_block9_dw_pad[0][0]']
#  seConv2D)
#
#  stack3_block9_ln (LayerNormali  (None, 7, 7, 768)   1536        ['stack3_block9_dw_conv[0][0]']
#  zation)
#
#  stack3_block9_up_dense (Dense)  (None, 7, 7, 3072)  2362368     ['stack3_block9_ln[0][0]']
#
#  stack3_block9_gelu (Activation  (None, 7, 7, 3072)  0           ['stack3_block9_up_dense[0][0]']
#  )
#
#  stack3_block9_down_dense (Dens  (None, 7, 7, 768)   2360064     ['stack3_block9_gelu[0][0]']
#  e)
#
#  stack3_block9_gamma (ChannelAf  (None, 7, 7, 768)   768         ['stack3_block9_down_dense[0][0]'
#  fine)                                                           ]
#
#  stack3_block9_drop (Dropout)   (None, 7, 7, 768)    0           ['stack3_block9_gamma[0][0]']
#
#  stack3_block9_output (Add)     (None, 7, 7, 768)    0           ['stack3_block8_output[0][0]',
#                                                                   'stack3_block9_drop[0][0]']
#
#  stack3_block10_dw_pad (ZeroPad  (None, 13, 13, 768)  0          ['stack3_block9_output[0][0]']
#  ding2D)
#
#  stack3_block10_dw_conv (Depthw  (None, 7, 7, 768)   38400       ['stack3_block10_dw_pad[0][0]']
#  iseConv2D)
#
#  stack3_block10_ln (LayerNormal  (None, 7, 7, 768)   1536        ['stack3_block10_dw_conv[0][0]']
#  ization)
#
#  stack3_block10_up_dense (Dense  (None, 7, 7, 3072)  2362368     ['stack3_block10_ln[0][0]']
#  )
#
#  stack3_block10_gelu (Activatio  (None, 7, 7, 3072)  0           ['stack3_block10_up_dense[0][0]']
#  n)
#
#  stack3_block10_down_dense (Den  (None, 7, 7, 768)   2360064     ['stack3_block10_gelu[0][0]']
#  se)
#
#  stack3_block10_gamma (ChannelA  (None, 7, 7, 768)   768         ['stack3_block10_down_dense[0][0]
#  ffine)                                                          ']
#
#  stack3_block10_drop (Dropout)  (None, 7, 7, 768)    0           ['stack3_block10_gamma[0][0]']
#
#  stack3_block10_output (Add)    (None, 7, 7, 768)    0           ['stack3_block9_output[0][0]',
#                                                                   'stack3_block10_drop[0][0]']
#
#  stack3_block11_dw_pad (ZeroPad  (None, 13, 13, 768)  0          ['stack3_block10_output[0][0]']
#  ding2D)
#
#  stack3_block11_dw_conv (Depthw  (None, 7, 7, 768)   38400       ['stack3_block11_dw_pad[0][0]']
#  iseConv2D)
#
#  stack3_block11_ln (LayerNormal  (None, 7, 7, 768)   1536        ['stack3_block11_dw_conv[0][0]']
#  ization)
#
#  stack3_block11_up_dense (Dense  (None, 7, 7, 3072)  2362368     ['stack3_block11_ln[0][0]']
#  )
#
#  stack3_block11_gelu (Activatio  (None, 7, 7, 3072)  0           ['stack3_block11_up_dense[0][0]']
#  n)
#
#  stack3_block11_down_dense (Den  (None, 7, 7, 768)   2360064     ['stack3_block11_gelu[0][0]']
#  se)
#
#  stack3_block11_gamma (ChannelA  (None, 7, 7, 768)   768         ['stack3_block11_down_dense[0][0]
#  ffine)                                                          ']
#
#  stack3_block11_drop (Dropout)  (None, 7, 7, 768)    0           ['stack3_block11_gamma[0][0]']
#
#  stack3_block11_output (Add)    (None, 7, 7, 768)    0           ['stack3_block10_output[0][0]',
#                                                                   'stack3_block11_drop[0][0]']
#
#  stack3_block12_dw_pad (ZeroPad  (None, 13, 13, 768)  0          ['stack3_block11_output[0][0]']
#  ding2D)
#
#  stack3_block12_dw_conv (Depthw  (None, 7, 7, 768)   38400       ['stack3_block12_dw_pad[0][0]']
#  iseConv2D)
#
#  stack3_block12_ln (LayerNormal  (None, 7, 7, 768)   1536        ['stack3_block12_dw_conv[0][0]']
#  ization)
#
#  stack3_block12_up_dense (Dense  (None, 7, 7, 3072)  2362368     ['stack3_block12_ln[0][0]']
#  )
#
#  stack3_block12_gelu (Activatio  (None, 7, 7, 3072)  0           ['stack3_block12_up_dense[0][0]']
#  n)
#
#  stack3_block12_down_dense (Den  (None, 7, 7, 768)   2360064     ['stack3_block12_gelu[0][0]']
#  se)
#
#  stack3_block12_gamma (ChannelA  (None, 7, 7, 768)   768         ['stack3_block12_down_dense[0][0]
#  ffine)                                                          ']
#
#  stack3_block12_drop (Dropout)  (None, 7, 7, 768)    0           ['stack3_block12_gamma[0][0]']
#
#  stack3_block12_output (Add)    (None, 7, 7, 768)    0           ['stack3_block11_output[0][0]',
#                                                                   'stack3_block12_drop[0][0]']
#
#  stack3_block13_dw_pad (ZeroPad  (None, 13, 13, 768)  0          ['stack3_block12_output[0][0]']
#  ding2D)
#
#  stack3_block13_dw_conv (Depthw  (None, 7, 7, 768)   38400       ['stack3_block13_dw_pad[0][0]']
#  iseConv2D)
#
#  stack3_block13_ln (LayerNormal  (None, 7, 7, 768)   1536        ['stack3_block13_dw_conv[0][0]']
#  ization)
#
#  stack3_block13_up_dense (Dense  (None, 7, 7, 3072)  2362368     ['stack3_block13_ln[0][0]']
#  )
#
# ...
#  ization)
#
#  stack3_block25_up_dense (Dense  (None, 7, 7, 3072)  2362368     ['stack3_block25_ln[0][0]']
#  )
#
#  stack3_block25_gelu (Activatio  (None, 7, 7, 3072)  0           ['stack3_block25_up_dense[0][0]']
#  n)
#
#  stack3_block25_down_dense (Den  (None, 7, 7, 768)   2360064     ['stack3_block25_gelu[0][0]']
#  se)
#
#  stack3_block25_gamma (ChannelA  (None, 7, 7, 768)   768         ['stack3_block25_down_dense[0][0]
#  ffine)                                                          ']
#
#  stack3_block25_drop (Dropout)  (None, 7, 7, 768)    0           ['stack3_block25_gamma[0][0]']
#
#  stack3_block25_output (Add)    (None, 7, 7, 768)    0           ['stack3_block24_output[0][0]',
#                                                                   'stack3_block25_drop[0][0]']
#
#  stack3_block26_dw_pad (ZeroPad  (None, 13, 13, 768)  0          ['stack3_block25_output[0][0]']
#  ding2D)
#
#  stack3_block26_dw_conv (Depthw  (None, 7, 7, 768)   38400       ['stack3_block26_dw_pad[0][0]']
#  iseConv2D)
#
#  stack3_block26_ln (LayerNormal  (None, 7, 7, 768)   1536        ['stack3_block26_dw_conv[0][0]']
#  ization)
#
#  stack3_block26_up_dense (Dense  (None, 7, 7, 3072)  2362368     ['stack3_block26_ln[0][0]']
#  )
#
#  stack3_block26_gelu (Activatio  (None, 7, 7, 3072)  0           ['stack3_block26_up_dense[0][0]']
#  n)
#
#  stack3_block26_down_dense (Den  (None, 7, 7, 768)   2360064     ['stack3_block26_gelu[0][0]']
#  se)
#
#  stack3_block26_gamma (ChannelA  (None, 7, 7, 768)   768         ['stack3_block26_down_dense[0][0]
#  ffine)                                                          ']
#
#  stack3_block26_drop (Dropout)  (None, 7, 7, 768)    0           ['stack3_block26_gamma[0][0]']
#
#  stack3_block26_output (Add)    (None, 7, 7, 768)    0           ['stack3_block25_output[0][0]',
#                                                                   'stack3_block26_drop[0][0]']
#
#  stack3_block27_dw_pad (ZeroPad  (None, 13, 13, 768)  0          ['stack3_block26_output[0][0]']
#  ding2D)
#
#  stack3_block27_dw_conv (Depthw  (None, 7, 7, 768)   38400       ['stack3_block27_dw_pad[0][0]']
#  iseConv2D)
#
#  stack3_block27_ln (LayerNormal  (None, 7, 7, 768)   1536        ['stack3_block27_dw_conv[0][0]']
#  ization)
#
#  stack3_block27_up_dense (Dense  (None, 7, 7, 3072)  2362368     ['stack3_block27_ln[0][0]']
#  )
#
#  stack3_block27_gelu (Activatio  (None, 7, 7, 3072)  0           ['stack3_block27_up_dense[0][0]']
#  n)
#
#  stack3_block27_down_dense (Den  (None, 7, 7, 768)   2360064     ['stack3_block27_gelu[0][0]']
#  se)
#
#  stack3_block27_gamma (ChannelA  (None, 7, 7, 768)   768         ['stack3_block27_down_dense[0][0]
#  ffine)                                                          ']
#
#  stack3_block27_drop (Dropout)  (None, 7, 7, 768)    0           ['stack3_block27_gamma[0][0]']
#
#  stack3_block27_output (Add)    (None, 7, 7, 768)    0           ['stack3_block26_output[0][0]',
#                                                                   'stack3_block27_drop[0][0]']
#
#  stack4_downsample_ln (LayerNor  (None, 7, 7, 768)   1536        ['stack3_block27_output[0][0]']
#  malization)
#
#  stack4_downsample_conv (Conv2D  (None, 3, 3, 1536)  4720128     ['stack4_downsample_ln[0][0]']
#  )
#
#  stack4_block1_dw_pad (ZeroPadd  (None, 9, 9, 1536)  0           ['stack4_downsample_conv[0][0]']
#  ing2D)
#
#  stack4_block1_dw_conv (Depthwi  (None, 3, 3, 1536)  76800       ['stack4_block1_dw_pad[0][0]']
#  seConv2D)
#
#  stack4_block1_ln (LayerNormali  (None, 3, 3, 1536)  3072        ['stack4_block1_dw_conv[0][0]']
#  zation)
#
#  stack4_block1_up_dense (Dense)  (None, 3, 3, 6144)  9443328     ['stack4_block1_ln[0][0]']
#
#  stack4_block1_gelu (Activation  (None, 3, 3, 6144)  0           ['stack4_block1_up_dense[0][0]']
#  )
#
#  stack4_block1_down_dense (Dens  (None, 3, 3, 1536)  9438720     ['stack4_block1_gelu[0][0]']
#  e)
#
#  stack4_block1_gamma (ChannelAf  (None, 3, 3, 1536)  1536        ['stack4_block1_down_dense[0][0]'
#  fine)                                                           ]
#
#  stack4_block1_drop (Dropout)   (None, 3, 3, 1536)   0           ['stack4_block1_gamma[0][0]']
#
#  stack4_block1_output (Add)     (None, 3, 3, 1536)   0           ['stack4_downsample_conv[0][0]',
#                                                                   'stack4_block1_drop[0][0]']
#
#  stack4_block2_dw_pad (ZeroPadd  (None, 9, 9, 1536)  0           ['stack4_block1_output[0][0]']
#  ing2D)
#
#  stack4_block2_dw_conv (Depthwi  (None, 3, 3, 1536)  76800       ['stack4_block2_dw_pad[0][0]']
#  seConv2D)
#
#  stack4_block2_ln (LayerNormali  (None, 3, 3, 1536)  3072        ['stack4_block2_dw_conv[0][0]']
#  zation)
#
#  stack4_block2_up_dense (Dense)  (None, 3, 3, 6144)  9443328     ['stack4_block2_ln[0][0]']
#
#  stack4_block2_gelu (Activation  (None, 3, 3, 6144)  0           ['stack4_block2_up_dense[0][0]']
#  )
#
#  stack4_block2_down_dense (Dens  (None, 3, 3, 1536)  9438720     ['stack4_block2_gelu[0][0]']
#  e)
#
#  stack4_block2_gamma (ChannelAf  (None, 3, 3, 1536)  1536        ['stack4_block2_down_dense[0][0]'
#  fine)                                                           ]
#
#  stack4_block2_drop (Dropout)   (None, 3, 3, 1536)   0           ['stack4_block2_gamma[0][0]']
#
#  stack4_block2_output (Add)     (None, 3, 3, 1536)   0           ['stack4_block1_output[0][0]',
#                                                                   'stack4_block2_drop[0][0]']
#
#  stack4_block3_dw_pad (ZeroPadd  (None, 9, 9, 1536)  0           ['stack4_block2_output[0][0]']
#  ing2D)
#
#  stack4_block3_dw_conv (Depthwi  (None, 3, 3, 1536)  76800       ['stack4_block3_dw_pad[0][0]']
#  seConv2D)
#
#  stack4_block3_ln (LayerNormali  (None, 3, 3, 1536)  3072        ['stack4_block3_dw_conv[0][0]']
#  zation)
#
#  stack4_block3_up_dense (Dense)  (None, 3, 3, 6144)  9443328     ['stack4_block3_ln[0][0]']
#
#  stack4_block3_gelu (Activation  (None, 3, 3, 6144)  0           ['stack4_block3_up_dense[0][0]']
#  )
#
#  stack4_block3_down_dense (Dens  (None, 3, 3, 1536)  9438720     ['stack4_block3_gelu[0][0]']
#  e)
#
#  stack4_block3_gamma (ChannelAf  (None, 3, 3, 1536)  1536        ['stack4_block3_down_dense[0][0]'
#  fine)                                                           ]
#
#  stack4_block3_drop (Dropout)   (None, 3, 3, 1536)   0           ['stack4_block3_gamma[0][0]']
#
#  stack4_block3_output (Add)     (None, 3, 3, 1536)   0           ['stack4_block2_output[0][0]',
#                                                                   'stack4_block3_drop[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 1536)        0           ['stack4_block3_output[0][0]']
#  2D)
#
#  head_ln (LayerNormalization)   (None, 1536)         3072        ['avg_pool[0][0]']
#
#  predictions (Dense)            (None, 2)            3074        ['head_ln[0][0]']
#
# ==================================================================================================
# Total params: 196,233,410
# Trainable params: 196,233,410
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
epochs = 50
history = model.fit_generator(generator=generator_train, epochs=epochs,steps_per_epoch=steps_per_epoch,
                                  validation_data=generator_test, validation_steps=steps_test,
                                 callbacks= callbacks, class_weight =class_weights)
# Out:
# C:\Users\sakib\AppData\Local\Temp\ipykernel_15476\3578285518.py:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(generator=generator_train, epochs=epochs,steps_per_epoch=steps_per_epoch,
# Epoch 1/50
# 46/45 [==============================] - ETA: 0s - loss: 0.7019 - accuracy: 0.5246 - categorical_accuracy: 0.5246 - auc: 0.5635 - precision: 0.5246 - recall: 0.5246 - true_positives: 192.0000 - true_negatives: 192.0000 - false_positives: 174.0000 - false_negatives: 174.0000 - cohen_kappa: -0.7124 - f1_score: 0.4286
# D:\anaconda\envs\tf_gpu\lib\site-packages\keras\engine\training.py:2034: UserWarning: Metric CohenKappa implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
# D:\anaconda\envs\tf_gpu\lib\site-packages\keras\engine\training.py:2034: UserWarning: Metric F1Score implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
# Epoch 1: val_accuracy improved from -inf to 0.65060, saving model to convnext.h5
# 45/45 [==============================] - 33s 341ms/step - loss: 0.7019 - accuracy: 0.5246 - categorical_accuracy: 0.5246 - auc: 0.5635 - precision: 0.5246 - recall: 0.5246 - true_positives: 192.0000 - true_negatives: 192.0000 - false_positives: 174.0000 - false_negatives: 174.0000 - cohen_kappa: -0.7124 - f1_score: 0.4286 - val_loss: 0.6761 - val_accuracy: 0.6506 - val_categorical_accuracy: 0.6506 - val_auc: 0.7139 - val_precision: 0.6506 - val_recall: 0.6506 - val_true_positives: 54.0000 - val_true_negatives: 54.0000 - val_false_positives: 29.0000 - val_false_negatives: 29.0000 - val_cohen_kappa: -0.6833 - val_f1_score: 0.5696 - lr: 2.6000e-06
# Epoch 2/50
# 46/45 [==============================] - ETA: 0s - loss: 0.6865 - accuracy: 0.5956 - categorical_accuracy: 0.5956 - auc: 0.6399 - precision: 0.5956 - recall: 0.5956 - true_positives: 218.0000 - true_negatives: 218.0000 - false_positives: 148.0000 - false_negatives: 148.0000 - cohen_kappa: -0.7511 - f1_score: 0.5286
# Epoch 2: val_accuracy did not improve from 0.65060
# 45/45 [==============================] - 12s 246ms/step - loss: 0.6865 - accuracy: 0.5956 - categorical_accuracy: 0.5956 - auc: 0.6399 - precision: 0.5956 - recall: 0.5956 - true_positives: 218.0000 - true_negatives: 218.0000 - false_positives: 148.0000 - false_negatives: 148.0000 - cohen_kappa: -0.7511 - f1_score: 0.5286 - val_loss: 0.6709 - val_accuracy: 0.6265 - val_categorical_accuracy: 0.6265 - val_auc: 0.7756 - val_precision: 0.6265 - val_recall: 0.6265 - val_true_positives: 52.0000 - val_true_negatives: 52.0000 - val_false_positives: 31.0000 - val_false_negatives: 31.0000 - val_cohen_kappa: -0.8457 - val_f1_score: 0.5924 - lr: 2.6000e-06
# Epoch 3/50
# 46/45 [==============================] - ETA: 0s - loss: 0.6691 - accuracy: 0.6913 - categorical_accuracy: 0.6913 - auc: 0.7451 - precision: 0.6913 - recall: 0.6913 - true_positives: 253.0000 - true_negatives: 253.0000 - false_positives: 113.0000 - false_negatives: 113.0000 - cohen_kappa: -0.8687 - f1_score: 0.6679
# Epoch 3: val_accuracy improved from 0.65060 to 0.68675, saving model to convnext.h5
# 45/45 [==============================] - 14s 309ms/step - loss: 0.6691 - accuracy: 0.6913 - categorical_accuracy: 0.6913 - auc: 0.7451 - precision: 0.6913 - recall: 0.6913 - true_positives: 253.0000 - true_negatives: 253.0000 - false_positives: 113.0000 - false_negatives: 113.0000 - cohen_kappa: -0.8687 - f1_score: 0.6679 - val_loss: 0.6651 - val_accuracy: 0.6867 - val_categorical_accuracy: 0.6867 - val_auc: 0.7891 - val_precision: 0.6867 - val_recall: 0.6867 - val_true_positives: 57.0000 - val_true_negatives: 57.0000 - val_false_positives: 26.0000 - val_false_negatives: 26.0000 - val_cohen_kappa: -0.9195 - val_f1_score: 0.6730 - lr: 2.6000e-06
# Epoch 4/50
# 46/45 [==============================] - ETA: 0s - loss: 0.6543 - accuracy: 0.7404 - categorical_accuracy: 0.7404 - auc: 0.7994 - precision: 0.7404 - recall: 0.7404 - true_positives: 271.0000 - true_negatives: 271.0000 - false_positives: 95.0000 - false_negatives: 95.0000 - cohen_kappa: -0.9152 - f1_score: 0.7284
# Epoch 4: val_accuracy improved from 0.68675 to 0.74699, saving model to convnext.h5
# 45/45 [==============================] - 14s 310ms/step - loss: 0.6543 - accuracy: 0.7404 - categorical_accuracy: 0.7404 - auc: 0.7994 - precision: 0.7404 - recall: 0.7404 - true_positives: 271.0000 - true_negatives: 271.0000 - false_positives: 95.0000 - false_negatives: 95.0000 - cohen_kappa: -0.9152 - f1_score: 0.7284 - val_loss: 0.6572 - val_accuracy: 0.7470 - val_categorical_accuracy: 0.7470 - val_auc: 0.8030 - val_precision: 0.7470 - val_recall: 0.7470 - val_true_positives: 62.0000 - val_true_negatives: 62.0000 - val_false_positives: 21.0000 - val_false_negatives: 21.0000 - val_cohen_kappa: -0.9283 - val_f1_score: 0.7372 - lr: 2.6000e-06
# Epoch 5/50
# 46/45 [==============================] - ETA: 0s - loss: 0.6284 - accuracy: 0.7896 - categorical_accuracy: 0.7896 - auc: 0.8803 - precision: 0.7896 - recall: 0.7896 - true_positives: 289.0000 - true_negatives: 289.0000 - false_positives: 77.0000 - false_negatives: 77.0000 - cohen_kappa: -0.9352 - f1_score: 0.7823
# Epoch 5: val_accuracy improved from 0.74699 to 0.77108, saving model to convnext.h5
# 45/45 [==============================] - 15s 320ms/step - loss: 0.6284 - accuracy: 0.7896 - categorical_accuracy: 0.7896 - auc: 0.8803 - precision: 0.7896 - recall: 0.7896 - true_positives: 289.0000 - true_negatives: 289.0000 - false_positives: 77.0000 - false_negatives: 77.0000 - cohen_kappa: -0.9352 - f1_score: 0.7823 - val_loss: 0.6487 - val_accuracy: 0.7711 - val_categorical_accuracy: 0.7711 - val_auc: 0.8096 - val_precision: 0.7711 - val_recall: 0.7711 - val_true_positives: 64.0000 - val_true_negatives: 64.0000 - val_false_positives: 19.0000 - val_false_negatives: 19.0000 - val_cohen_kappa: -0.9591 - val_f1_score: 0.7662 - lr: 2.6000e-06
# Epoch 6/50
# 46/45 [==============================] - ETA: 0s - loss: 0.6135 - accuracy: 0.8306 - categorical_accuracy: 0.8306 - auc: 0.9054 - precision: 0.8306 - recall: 0.8306 - true_positives: 304.0000 - true_negatives: 304.0000 - false_positives: 62.0000 - false_negatives: 62.0000 - cohen_kappa: -0.9088 - f1_score: 0.8221
# Epoch 6: val_accuracy did not improve from 0.77108
# 45/45 [==============================] - 13s 267ms/step - loss: 0.6135 - accuracy: 0.8306 - categorical_accuracy: 0.8306 - auc: 0.9054 - precision: 0.8306 - recall: 0.8306 - true_positives: 304.0000 - true_negatives: 304.0000 - false_positives: 62.0000 - false_negatives: 62.0000 - cohen_kappa: -0.9088 - f1_score: 0.8221 - val_loss: 0.6374 - val_accuracy: 0.7711 - val_categorical_accuracy: 0.7711 - val_auc: 0.8215 - val_precision: 0.7711 - val_recall: 0.7711 - val_true_positives: 64.0000 - val_true_negatives: 64.0000 - val_false_positives: 19.0000 - val_false_negatives: 19.0000 - val_cohen_kappa: -0.9714 - val_f1_score: 0.7677 - lr: 2.6000e-06
# Epoch 7/50
# 46/45 [==============================] - ETA: 0s - loss: 0.5881 - accuracy: 0.8306 - categorical_accuracy: 0.8306 - auc: 0.9136 - precision: 0.8306 - recall: 0.8306 - true_positives: 304.0000 - true_negatives: 304.0000 - false_positives: 62.0000 - false_negatives: 62.0000 - cohen_kappa: -0.9477 - f1_score: 0.8259
# Epoch 7: val_accuracy did not improve from 0.77108
# 45/45 [==============================] - 13s 282ms/step - loss: 0.5881 - accuracy: 0.8306 - categorical_accuracy: 0.8306 - auc: 0.9136 - precision: 0.8306 - recall: 0.8306 - true_positives: 304.0000 - true_negatives: 304.0000 - false_positives: 62.0000 - false_negatives: 62.0000 - cohen_kappa: -0.9477 - f1_score: 0.8259 - val_loss: 0.6297 - val_accuracy: 0.7229 - val_categorical_accuracy: 0.7229 - val_auc: 0.7999 - val_precision: 0.7229 - val_recall: 0.7229 - val_true_positives: 60.0000 - val_true_negatives: 60.0000 - val_false_positives: 23.0000 - val_false_negatives: 23.0000 - val_cohen_kappa: -0.9896 - val_f1_score: 0.7214 - lr: 2.6000e-06
# Epoch 8/50
# 46/45 [==============================] - ETA: 0s - loss: 0.5622 - accuracy: 0.8579 - categorical_accuracy: 0.8579 - auc: 0.9374 - precision: 0.8579 - recall: 0.8579 - true_positives: 314.0000 - true_negatives: 314.0000 - false_positives: 52.0000 - false_negatives: 52.0000 - cohen_kappa: -0.9407 - f1_score: 0.8534
# Epoch 8: val_accuracy did not improve from 0.77108
# 45/45 [==============================] - 13s 282ms/step - loss: 0.5622 - accuracy: 0.8579 - categorical_accuracy: 0.8579 - auc: 0.9374 - precision: 0.8579 - recall: 0.8579 - true_positives: 314.0000 - true_negatives: 314.0000 - false_positives: 52.0000 - false_negatives: 52.0000 - cohen_kappa: -0.9407 - f1_score: 0.8534 - val_loss: 0.6160 - val_accuracy: 0.7229 - val_categorical_accuracy: 0.7229 - val_auc: 0.8188 - val_precision: 0.7229 - val_recall: 0.7229 - val_true_positives: 60.0000 - val_true_negatives: 60.0000 - val_false_positives: 23.0000 - val_false_negatives: 23.0000 - val_cohen_kappa: -0.9896 - val_f1_score: 0.7214 - lr: 2.6000e-06
# Epoch 9/50
# 46/45 [==============================] - ETA: 0s - loss: 0.5412 - accuracy: 0.8224 - categorical_accuracy: 0.8224 - auc: 0.9354 - precision: 0.8224 - recall: 0.8224 - true_positives: 301.0000 - true_negatives: 301.0000 - false_positives: 65.0000 - false_negatives: 65.0000 - cohen_kappa: -0.9424 - f1_score: 0.8170
# Epoch 9: val_accuracy did not improve from 0.77108
# 45/45 [==============================] - 14s 300ms/step - loss: 0.5412 - accuracy: 0.8224 - categorical_accuracy: 0.8224 - auc: 0.9354 - precision: 0.8224 - recall: 0.8224 - true_positives: 301.0000 - true_negatives: 301.0000 - false_positives: 65.0000 - false_negatives: 65.0000 - cohen_kappa: -0.9424 - f1_score: 0.8170 - val_loss: 0.6070 - val_accuracy: 0.7229 - val_categorical_accuracy: 0.7229 - val_auc: 0.8138 - val_precision: 0.7229 - val_recall: 0.7229 - val_true_positives: 60.0000 - val_true_negatives: 60.0000 - val_false_positives: 23.0000 - val_false_negatives: 23.0000 - val_cohen_kappa: -0.9896 - val_f1_score: 0.7214 - lr: 2.6000e-06
# Epoch 10/50
# 46/45 [==============================] - ETA: 0s - loss: 0.5171 - accuracy: 0.8852 - categorical_accuracy: 0.8852 - auc: 0.9490 - precision: 0.8852 - recall: 0.8852 - true_positives: 324.0000 - true_negatives: 324.0000 - false_positives: 42.0000 - false_negatives: 42.0000 - cohen_kappa: -0.9255 - f1_score: 0.8806
# Epoch 10: val_accuracy did not improve from 0.77108
# 45/45 [==============================] - 13s 274ms/step - loss: 0.5171 - accuracy: 0.8852 - categorical_accuracy: 0.8852 - auc: 0.9490 - precision: 0.8852 - recall: 0.8852 - true_positives: 324.0000 - true_negatives: 324.0000 - false_positives: 42.0000 - false_negatives: 42.0000 - cohen_kappa: -0.9255 - f1_score: 0.8806 - val_loss: 0.6005 - val_accuracy: 0.7229 - val_categorical_accuracy: 0.7229 - val_auc: 0.8032 - val_precision: 0.7229 - val_recall: 0.7229 - val_true_positives: 60.0000 - val_true_negatives: 60.0000 - val_false_positives: 23.0000 - val_false_negatives: 23.0000 - val_cohen_kappa: -0.9896 - val_f1_score: 0.7214 - lr: 2.6000e-06
# Epoch 11/50
# 46/45 [==============================] - ETA: 0s - loss: 0.4909 - accuracy: 0.8661 - categorical_accuracy: 0.8661 - auc: 0.9470 - precision: 0.8661 - recall: 0.8661 - true_positives: 317.0000 - true_negatives: 317.0000 - false_positives: 49.0000 - false_negatives: 49.0000 - cohen_kappa: -0.9388 - f1_score: 0.8618
# Epoch 11: val_accuracy did not improve from 0.77108
# 45/45 [==============================] - 13s 270ms/step - loss: 0.4909 - accuracy: 0.8661 - categorical_accuracy: 0.8661 - auc: 0.9470 - precision: 0.8661 - recall: 0.8661 - true_positives: 317.0000 - true_negatives: 317.0000 - false_positives: 49.0000 - false_negatives: 49.0000 - cohen_kappa: -0.9388 - f1_score: 0.8618 - val_loss: 0.5895 - val_accuracy: 0.7470 - val_categorical_accuracy: 0.7470 - val_auc: 0.8097 - val_precision: 0.7470 - val_recall: 0.7470 - val_true_positives: 62.0000 - val_true_negatives: 62.0000 - val_false_positives: 21.0000 - val_false_negatives: 21.0000 - val_cohen_kappa: -0.9816 - val_f1_score: 0.7446 - lr: 2.6000e-06
# Epoch 12/50
# 46/45 [==============================] - ETA: 0s - loss: 0.4792 - accuracy: 0.8525 - categorical_accuracy: 0.8525 - auc: 0.9460 - precision: 0.8525 - recall: 0.8525 - true_positives: 312.0000 - true_negatives: 312.0000 - false_positives: 54.0000 - false_negatives: 54.0000 - cohen_kappa: -0.9215 - f1_score: 0.8462
# Epoch 12: val_accuracy did not improve from 0.77108
# 45/45 [==============================] - 13s 273ms/step - loss: 0.4792 - accuracy: 0.8525 - categorical_accuracy: 0.8525 - auc: 0.9460 - precision: 0.8525 - recall: 0.8525 - true_positives: 312.0000 - true_negatives: 312.0000 - false_positives: 54.0000 - false_negatives: 54.0000 - cohen_kappa: -0.9215 - f1_score: 0.8462 - val_loss: 0.5766 - val_accuracy: 0.7470 - val_categorical_accuracy: 0.7470 - val_auc: 0.8183 - val_precision: 0.7470 - val_recall: 0.7470 - val_true_positives: 62.0000 - val_true_negatives: 62.0000 - val_false_positives: 21.0000 - val_false_negatives: 21.0000 - val_cohen_kappa: -0.9816 - val_f1_score: 0.7446 - lr: 2.6000e-06
# Epoch 13/50
# 46/45 [==============================] - ETA: 0s - loss: 0.4433 - accuracy: 0.8934 - categorical_accuracy: 0.8934 - auc: 0.9611 - precision: 0.8934 - recall: 0.8934 - true_positives: 327.0000 - true_negatives: 327.0000 - false_positives: 39.0000 - false_negatives: 39.0000 - cohen_kappa: -0.9275 - f1_score: 0.8893
# Epoch 13: val_accuracy did not improve from 0.77108
# 45/45 [==============================] - 13s 271ms/step - loss: 0.4433 - accuracy: 0.8934 - categorical_accuracy: 0.8934 - auc: 0.9611 - precision: 0.8934 - recall: 0.8934 - true_positives: 327.0000 - true_negatives: 327.0000 - false_positives: 39.0000 - false_negatives: 39.0000 - cohen_kappa: -0.9275 - f1_score: 0.8893 - val_loss: 0.5724 - val_accuracy: 0.7349 - val_categorical_accuracy: 0.7349 - val_auc: 0.8098 - val_precision: 0.7349 - val_recall: 0.7349 - val_true_positives: 61.0000 - val_true_negatives: 61.0000 - val_false_positives: 22.0000 - val_false_negatives: 22.0000 - val_cohen_kappa: -0.9859 - val_f1_score: 0.7330 - lr: 2.6000e-06
# Epoch 14/50
# 46/45 [==============================] - ETA: 0s - loss: 0.4239 - accuracy: 0.8907 - categorical_accuracy: 0.8907 - auc: 0.9616 - precision: 0.8907 - recall: 0.8907 - true_positives: 326.0000 - true_negatives: 326.0000 - false_positives: 40.0000 - false_negatives: 40.0000 - cohen_kappa: -0.9294 - f1_score: 0.8866
# Epoch 14: val_accuracy did not improve from 0.77108
# 45/45 [==============================] - 13s 272ms/step - loss: 0.4239 - accuracy: 0.8907 - categorical_accuracy: 0.8907 - auc: 0.9616 - precision: 0.8907 - recall: 0.8907 - true_positives: 326.0000 - true_negatives: 326.0000 - false_positives: 40.0000 - false_negatives: 40.0000 - cohen_kappa: -0.9294 - f1_score: 0.8866 - val_loss: 0.5538 - val_accuracy: 0.7470 - val_categorical_accuracy: 0.7470 - val_auc: 0.8313 - val_precision: 0.7470 - val_recall: 0.7470 - val_true_positives: 62.0000 - val_true_negatives: 62.0000 - val_false_positives: 21.0000 - val_false_negatives: 21.0000 - val_cohen_kappa: -0.9816 - val_f1_score: 0.7446 - lr: 2.6000e-06
# Epoch 15/50
# 46/45 [==============================] - ETA: 0s - loss: 0.3930 - accuracy: 0.9098 - categorical_accuracy: 0.9098 - auc: 0.9719 - precision: 0.9098 - recall: 0.9098 - true_positives: 333.0000 - true_negatives: 333.0000 - false_positives: 33.0000 - false_negatives: 33.0000 - cohen_kappa: -0.9152 - f1_score: 0.9057
# Epoch 15: val_accuracy did not improve from 0.77108
# 45/45 [==============================] - 13s 274ms/step - loss: 0.3930 - accuracy: 0.9098 - categorical_accuracy: 0.9098 - auc: 0.9719 - precision: 0.9098 - recall: 0.9098 - true_positives: 333.0000 - true_negatives: 333.0000 - false_positives: 33.0000 - false_negatives: 33.0000 - cohen_kappa: -0.9152 - f1_score: 0.9057 - val_loss: 0.5457 - val_accuracy: 0.7349 - val_categorical_accuracy: 0.7349 - val_auc: 0.8323 - val_precision: 0.7349 - val_recall: 0.7349 - val_true_positives: 61.0000 - val_true_negatives: 61.0000 - val_false_positives: 22.0000 - val_false_negatives: 22.0000 - val_cohen_kappa: -0.9859 - val_f1_score: 0.7330 - lr: 2.6000e-06
# Epoch 16/50
# 46/45 [==============================] - ETA: 0s - loss: 0.3759 - accuracy: 0.9098 - categorical_accuracy: 0.9098 - auc: 0.9708 - precision: 0.9098 - recall: 0.9098 - true_positives: 333.0000 - true_negatives: 333.0000 - false_positives: 33.0000 - false_negatives: 33.0000 - cohen_kappa: -0.9152 - f1_score: 0.9057
# Epoch 16: val_accuracy did not improve from 0.77108
# 45/45 [==============================] - 13s 278ms/step - loss: 0.3759 - accuracy: 0.9098 - categorical_accuracy: 0.9098 - auc: 0.9708 - precision: 0.9098 - recall: 0.9098 - true_positives: 333.0000 - true_negatives: 333.0000 - false_positives: 33.0000 - false_negatives: 33.0000 - cohen_kappa: -0.9152 - f1_score: 0.9057 - val_loss: 0.5329 - val_accuracy: 0.7470 - val_categorical_accuracy: 0.7470 - val_auc: 0.8394 - val_precision: 0.7470 - val_recall: 0.7470 - val_true_positives: 62.0000 - val_true_negatives: 62.0000 - val_false_positives: 21.0000 - val_false_negatives: 21.0000 - val_cohen_kappa: -0.9816 - val_f1_score: 0.7446 - lr: 2.6000e-06
# Epoch 17/50
# 46/45 [==============================] - ETA: 0s - loss: 0.3556 - accuracy: 0.9044 - categorical_accuracy: 0.9044 - auc: 0.9723 - precision: 0.9044 - recall: 0.9044 - true_positives: 331.0000 - true_negatives: 331.0000 - false_positives: 35.0000 - false_negatives: 35.0000 - cohen_kappa: -0.9110 - f1_score: 0.8997
# Epoch 17: val_accuracy did not improve from 0.77108
# 45/45 [==============================] - 14s 297ms/step - loss: 0.3556 - accuracy: 0.9044 - categorical_accuracy: 0.9044 - auc: 0.9723 - precision: 0.9044 - recall: 0.9044 - true_positives: 331.0000 - true_negatives: 331.0000 - false_positives: 35.0000 - false_negatives: 35.0000 - cohen_kappa: -0.9110 - f1_score: 0.8997 - val_loss: 0.5237 - val_accuracy: 0.7470 - val_categorical_accuracy: 0.7470 - val_auc: 0.8410 - val_precision: 0.7470 - val_recall: 0.7470 - val_true_positives: 62.0000 - val_true_negatives: 62.0000 - val_false_positives: 21.0000 - val_false_negatives: 21.0000 - val_cohen_kappa: -0.9816 - val_f1_score: 0.7446 - lr: 2.6000e-06
# Epoch 18/50
# 46/45 [==============================] - ETA: 0s - loss: 0.3400 - accuracy: 0.9098 - categorical_accuracy: 0.9098 - auc: 0.9672 - precision: 0.9098 - recall: 0.9098 - true_positives: 333.0000 - true_negatives: 333.0000 - false_positives: 33.0000 - false_negatives: 33.0000 - cohen_kappa: -0.9152 - f1_score: 0.9057
# Epoch 18: val_accuracy did not improve from 0.77108
# 45/45 [==============================] - 13s 280ms/step - loss: 0.3400 - accuracy: 0.9098 - categorical_accuracy: 0.9098 - auc: 0.9672 - precision: 0.9098 - recall: 0.9098 - true_positives: 333.0000 - true_negatives: 333.0000 - false_positives: 33.0000 - false_negatives: 33.0000 - cohen_kappa: -0.9152 - f1_score: 0.9057 - val_loss: 0.5080 - val_accuracy: 0.7590 - val_categorical_accuracy: 0.7590 - val_auc: 0.8510 - val_precision: 0.7590 - val_recall: 0.7590 - val_true_positives: 63.0000 - val_true_negatives: 63.0000 - val_false_positives: 20.0000 - val_false_negatives: 20.0000 - val_cohen_kappa: -0.9768 - val_f1_score: 0.7562 - lr: 2.6000e-06
# Epoch 19/50
# 46/45 [==============================] - ETA: 0s - loss: 0.3158 - accuracy: 0.9290 - categorical_accuracy: 0.9290 - auc: 0.9798 - precision: 0.9290 - recall: 0.9290 - true_positives: 340.0000 - true_negatives: 340.0000 - false_positives: 26.0000 - false_negatives: 26.0000 - cohen_kappa: -0.8907 - f1_score: 0.9246
# Epoch 19: val_accuracy did not improve from 0.77108
# 45/45 [==============================] - 13s 286ms/step - loss: 0.3158 - accuracy: 0.9290 - categorical_accuracy: 0.9290 - auc: 0.9798 - precision: 0.9290 - recall: 0.9290 - true_positives: 340.0000 - true_negatives: 340.0000 - false_positives: 26.0000 - false_negatives: 26.0000 - cohen_kappa: -0.8907 - f1_score: 0.9246 - val_loss: 0.4974 - val_accuracy: 0.7711 - val_categorical_accuracy: 0.7711 - val_auc: 0.8556 - val_precision: 0.7711 - val_recall: 0.7711 - val_true_positives: 64.0000 - val_true_negatives: 64.0000 - val_false_positives: 19.0000 - val_false_negatives: 19.0000 - val_cohen_kappa: -0.9714 - val_f1_score: 0.7677 - lr: 2.6000e-06
# Epoch 20/50
# 46/45 [==============================] - ETA: 0s - loss: 0.3122 - accuracy: 0.9098 - categorical_accuracy: 0.9098 - auc: 0.9760 - precision: 0.9098 - recall: 0.9098 - true_positives: 333.0000 - true_negatives: 333.0000 - false_positives: 33.0000 - false_negatives: 33.0000 - cohen_kappa: -0.9022 - f1_score: 0.9049
# Epoch 20: val_accuracy did not improve from 0.77108
# 45/45 [==============================] - 13s 287ms/step - loss: 0.3122 - accuracy: 0.9098 - categorical_accuracy: 0.9098 - auc: 0.9760 - precision: 0.9098 - recall: 0.9098 - true_positives: 333.0000 - true_negatives: 333.0000 - false_positives: 33.0000 - false_negatives: 33.0000 - cohen_kappa: -0.9022 - f1_score: 0.9049 - val_loss: 0.4973 - val_accuracy: 0.7590 - val_categorical_accuracy: 0.7590 - val_auc: 0.8511 - val_precision: 0.7590 - val_recall: 0.7590 - val_true_positives: 63.0000 - val_true_negatives: 63.0000 - val_false_positives: 20.0000 - val_false_negatives: 20.0000 - val_cohen_kappa: -0.9768 - val_f1_score: 0.7562 - lr: 2.6000e-06
# Epoch 21/50
# 46/45 [==============================] - ETA: 0s - loss: 0.2835 - accuracy: 0.9481 - categorical_accuracy: 0.9481 - auc: 0.9855 - precision: 0.9481 - recall: 0.9481 - true_positives: 347.0000 - true_negatives: 347.0000 - false_positives: 19.0000 - false_negatives: 19.0000 - cohen_kappa: -0.8787 - f1_score: 0.9445
# Epoch 21: val_accuracy improved from 0.77108 to 0.79518, saving model to convnext.h5
# 45/45 [==============================] - 16s 354ms/step - loss: 0.2835 - accuracy: 0.9481 - categorical_accuracy: 0.9481 - auc: 0.9855 - precision: 0.9481 - recall: 0.9481 - true_positives: 347.0000 - true_negatives: 347.0000 - false_positives: 19.0000 - false_negatives: 19.0000 - cohen_kappa: -0.8787 - f1_score: 0.9445 - val_loss: 0.4758 - val_accuracy: 0.7952 - val_categorical_accuracy: 0.7952 - val_auc: 0.8691 - val_precision: 0.7952 - val_recall: 0.7952 - val_true_positives: 66.0000 - val_true_negatives: 66.0000 - val_false_positives: 17.0000 - val_false_negatives: 17.0000 - val_cohen_kappa: -0.9591 - val_f1_score: 0.7908 - lr: 2.6000e-06
# Epoch 22/50
# 46/45 [==============================] - ETA: 0s - loss: 0.2679 - accuracy: 0.9235 - categorical_accuracy: 0.9235 - auc: 0.9803 - precision: 0.9235 - recall: 0.9235 - true_positives: 338.0000 - true_negatives: 338.0000 - false_positives: 28.0000 - false_negatives: 28.0000 - cohen_kappa: -0.9088 - f1_score: 0.9197
# Epoch 22: val_accuracy improved from 0.79518 to 0.81928, saving model to convnext.h5
# 45/45 [==============================] - 16s 338ms/step - loss: 0.2679 - accuracy: 0.9235 - categorical_accuracy: 0.9235 - auc: 0.9803 - precision: 0.9235 - recall: 0.9235 - true_positives: 338.0000 - true_negatives: 338.0000 - false_positives: 28.0000 - false_negatives: 28.0000 - cohen_kappa: -0.9088 - f1_score: 0.9197 - val_loss: 0.4579 - val_accuracy: 0.8193 - val_categorical_accuracy: 0.8193 - val_auc: 0.8789 - val_precision: 0.8193 - val_recall: 0.8193 - val_true_positives: 68.0000 - val_true_negatives: 68.0000 - val_false_positives: 15.0000 - val_false_negatives: 15.0000 - val_cohen_kappa: -0.9447 - val_f1_score: 0.8140 - lr: 2.6000e-06
# Epoch 23/50
# 46/45 [==============================] - ETA: 0s - loss: 0.2597 - accuracy: 0.9290 - categorical_accuracy: 0.9290 - auc: 0.9830 - precision: 0.9290 - recall: 0.9290 - true_positives: 340.0000 - true_negatives: 340.0000 - false_positives: 26.0000 - false_negatives: 26.0000 - cohen_kappa: -0.8860 - f1_score: 0.9244
# Epoch 23: val_accuracy did not improve from 0.81928
# 45/45 [==============================] - 13s 277ms/step - loss: 0.2597 - accuracy: 0.9290 - categorical_accuracy: 0.9290 - auc: 0.9830 - precision: 0.9290 - recall: 0.9290 - true_positives: 340.0000 - true_negatives: 340.0000 - false_positives: 26.0000 - false_negatives: 26.0000 - cohen_kappa: -0.8860 - f1_score: 0.9244 - val_loss: 0.4570 - val_accuracy: 0.8072 - val_categorical_accuracy: 0.8072 - val_auc: 0.8757 - val_precision: 0.8072 - val_recall: 0.8072 - val_true_positives: 67.0000 - val_true_negatives: 67.0000 - val_false_positives: 16.0000 - val_false_negatives: 16.0000 - val_cohen_kappa: -0.9521 - val_f1_score: 0.8024 - lr: 2.6000e-06
# Epoch 24/50
# 46/45 [==============================] - ETA: 0s - loss: 0.2403 - accuracy: 0.9508 - categorical_accuracy: 0.9508 - auc: 0.9864 - precision: 0.9508 - recall: 0.9508 - true_positives: 348.0000 - true_negatives: 348.0000 - false_positives: 18.0000 - false_negatives: 18.0000 - cohen_kappa: -0.8811 - f1_score: 0.9475
# Epoch 24: val_accuracy did not improve from 0.81928
# 45/45 [==============================] - 13s 281ms/step - loss: 0.2403 - accuracy: 0.9508 - categorical_accuracy: 0.9508 - auc: 0.9864 - precision: 0.9508 - recall: 0.9508 - true_positives: 348.0000 - true_negatives: 348.0000 - false_positives: 18.0000 - false_negatives: 18.0000 - cohen_kappa: -0.8811 - f1_score: 0.9475 - val_loss: 0.4497 - val_accuracy: 0.8072 - val_categorical_accuracy: 0.8072 - val_auc: 0.8785 - val_precision: 0.8072 - val_recall: 0.8072 - val_true_positives: 67.0000 - val_true_negatives: 67.0000 - val_false_positives: 16.0000 - val_false_negatives: 16.0000 - val_cohen_kappa: -0.9521 - val_f1_score: 0.8024 - lr: 2.6000e-06
# Epoch 25/50
# 46/45 [==============================] - ETA: 0s - loss: 0.2247 - accuracy: 0.9426 - categorical_accuracy: 0.9426 - auc: 0.9868 - precision: 0.9426 - recall: 0.9426 - true_positives: 345.0000 - true_negatives: 345.0000 - false_positives: 21.0000 - false_negatives: 21.0000 - cohen_kappa: -0.8836 - f1_score: 0.9388
# Epoch 25: val_accuracy did not improve from 0.81928
# 45/45 [==============================] - 13s 273ms/step - loss: 0.2247 - accuracy: 0.9426 - categorical_accuracy: 0.9426 - auc: 0.9868 - precision: 0.9426 - recall: 0.9426 - true_positives: 345.0000 - true_negatives: 345.0000 - false_positives: 21.0000 - false_negatives: 21.0000 - cohen_kappa: -0.8836 - f1_score: 0.9388 - val_loss: 0.4621 - val_accuracy: 0.7831 - val_categorical_accuracy: 0.7831 - val_auc: 0.8665 - val_precision: 0.7831 - val_recall: 0.7831 - val_true_positives: 65.0000 - val_true_negatives: 65.0000 - val_false_positives: 18.0000 - val_false_negatives: 18.0000 - val_cohen_kappa: -0.9655 - val_f1_score: 0.7793 - lr: 2.6000e-06
# Epoch 26/50
# 46/45 [==============================] - ETA: 0s - loss: 0.2091 - accuracy: 0.9563 - categorical_accuracy: 0.9563 - auc: 0.9899 - precision: 0.9563 - recall: 0.9563 - true_positives: 350.0000 - true_negatives: 350.0000 - false_positives: 16.0000 - false_negatives: 16.0000 - cohen_kappa: -0.8860 - f1_score: 0.9535
# Epoch 26: val_accuracy improved from 0.81928 to 0.84337, saving model to convnext.h5
# 45/45 [==============================] - 16s 342ms/step - loss: 0.2091 - accuracy: 0.9563 - categorical_accuracy: 0.9563 - auc: 0.9899 - precision: 0.9563 - recall: 0.9563 - true_positives: 350.0000 - true_negatives: 350.0000 - false_positives: 16.0000 - false_negatives: 16.0000 - cohen_kappa: -0.8860 - f1_score: 0.9535 - val_loss: 0.4253 - val_accuracy: 0.8434 - val_categorical_accuracy: 0.8434 - val_auc: 0.8902 - val_precision: 0.8434 - val_recall: 0.8434 - val_true_positives: 70.0000 - val_true_negatives: 70.0000 - val_false_positives: 13.0000 - val_false_negatives: 13.0000 - val_cohen_kappa: -0.9283 - val_f1_score: 0.8373 - lr: 2.6000e-06
# Epoch 27/50
# 46/45 [==============================] - ETA: 0s - loss: 0.2018 - accuracy: 0.9536 - categorical_accuracy: 0.9536 - auc: 0.9912 - precision: 0.9536 - recall: 0.9536 - true_positives: 349.0000 - true_negatives: 349.0000 - false_positives: 17.0000 - false_negatives: 17.0000 - cohen_kappa: -0.8836 - f1_score: 0.9505
# Epoch 27: val_accuracy did not improve from 0.84337
# 45/45 [==============================] - 13s 279ms/step - loss: 0.2018 - accuracy: 0.9536 - categorical_accuracy: 0.9536 - auc: 0.9912 - precision: 0.9536 - recall: 0.9536 - true_positives: 349.0000 - true_negatives: 349.0000 - false_positives: 17.0000 - false_negatives: 17.0000 - cohen_kappa: -0.8836 - f1_score: 0.9505 - val_loss: 0.4156 - val_accuracy: 0.8434 - val_categorical_accuracy: 0.8434 - val_auc: 0.8962 - val_precision: 0.8434 - val_recall: 0.8434 - val_true_positives: 70.0000 - val_true_negatives: 70.0000 - val_false_positives: 13.0000 - val_false_negatives: 13.0000 - val_cohen_kappa: -0.9283 - val_f1_score: 0.8373 - lr: 2.6000e-06
# Epoch 28/50
# 46/45 [==============================] - ETA: 0s - loss: 0.1974 - accuracy: 0.9617 - categorical_accuracy: 0.9617 - auc: 0.9906 - precision: 0.9617 - recall: 0.9617 - true_positives: 352.0000 - true_negatives: 352.0000 - false_positives: 14.0000 - false_negatives: 14.0000 - cohen_kappa: -0.8762 - f1_score: 0.9590
# Epoch 28: val_accuracy did not improve from 0.84337
# 45/45 [==============================] - 13s 281ms/step - loss: 0.1974 - accuracy: 0.9617 - categorical_accuracy: 0.9617 - auc: 0.9906 - precision: 0.9617 - recall: 0.9617 - true_positives: 352.0000 - true_negatives: 352.0000 - false_positives: 14.0000 - false_negatives: 14.0000 - cohen_kappa: -0.8762 - f1_score: 0.9590 - val_loss: 0.4153 - val_accuracy: 0.8434 - val_categorical_accuracy: 0.8434 - val_auc: 0.8929 - val_precision: 0.8434 - val_recall: 0.8434 - val_true_positives: 70.0000 - val_true_negatives: 70.0000 - val_false_positives: 13.0000 - val_false_negatives: 13.0000 - val_cohen_kappa: -0.9283 - val_f1_score: 0.8373 - lr: 2.6000e-06
# Epoch 29/50
# 46/45 [==============================] - ETA: 0s - loss: 0.1870 - accuracy: 0.9536 - categorical_accuracy: 0.9536 - auc: 0.9927 - precision: 0.9536 - recall: 0.9536 - true_positives: 349.0000 - true_negatives: 349.0000 - false_positives: 17.0000 - false_negatives: 17.0000 - cohen_kappa: -0.8738 - f1_score: 0.9502
# Epoch 29: val_accuracy did not improve from 0.84337
# 45/45 [==============================] - 13s 287ms/step - loss: 0.1870 - accuracy: 0.9536 - categorical_accuracy: 0.9536 - auc: 0.9927 - precision: 0.9536 - recall: 0.9536 - true_positives: 349.0000 - true_negatives: 349.0000 - false_positives: 17.0000 - false_negatives: 17.0000 - cohen_kappa: -0.8738 - f1_score: 0.9502 - val_loss: 0.4082 - val_accuracy: 0.8434 - val_categorical_accuracy: 0.8434 - val_auc: 0.8962 - val_precision: 0.8434 - val_recall: 0.8434 - val_true_positives: 70.0000 - val_true_negatives: 70.0000 - val_false_positives: 13.0000 - val_false_negatives: 13.0000 - val_cohen_kappa: -0.9283 - val_f1_score: 0.8373 - lr: 2.6000e-06
# Epoch 30/50
# 46/45 [==============================] - ETA: 0s - loss: 0.1693 - accuracy: 0.9645 - categorical_accuracy: 0.9645 - auc: 0.9925 - precision: 0.9645 - recall: 0.9645 - true_positives: 353.0000 - true_negatives: 353.0000 - false_positives: 13.0000 - false_negatives: 13.0000 - cohen_kappa: -0.8787 - f1_score: 0.9620
# Epoch 30: val_accuracy did not improve from 0.84337
# 45/45 [==============================] - 13s 286ms/step - loss: 0.1693 - accuracy: 0.9645 - categorical_accuracy: 0.9645 - auc: 0.9925 - precision: 0.9645 - recall: 0.9645 - true_positives: 353.0000 - true_negatives: 353.0000 - false_positives: 13.0000 - false_negatives: 13.0000 - cohen_kappa: -0.8787 - f1_score: 0.9620 - val_loss: 0.4029 - val_accuracy: 0.8434 - val_categorical_accuracy: 0.8434 - val_auc: 0.8987 - val_precision: 0.8434 - val_recall: 0.8434 - val_true_positives: 70.0000 - val_true_negatives: 70.0000 - val_false_positives: 13.0000 - val_false_negatives: 13.0000 - val_cohen_kappa: -0.9283 - val_f1_score: 0.8373 - lr: 2.6000e-06
# Epoch 31/50
# 46/45 [==============================] - ETA: 0s - loss: 0.1580 - accuracy: 0.9672 - categorical_accuracy: 0.9672 - auc: 0.9926 - precision: 0.9672 - recall: 0.9672 - true_positives: 354.0000 - true_negatives: 354.0000 - false_positives: 12.0000 - false_negatives: 12.0000 - cohen_kappa: -0.8811 - f1_score: 0.9650
# Epoch 31: val_accuracy did not improve from 0.84337
# 45/45 [==============================] - 13s 286ms/step - loss: 0.1580 - accuracy: 0.9672 - categorical_accuracy: 0.9672 - auc: 0.9926 - precision: 0.9672 - recall: 0.9672 - true_positives: 354.0000 - true_negatives: 354.0000 - false_positives: 12.0000 - false_negatives: 12.0000 - cohen_kappa: -0.8811 - f1_score: 0.9650 - val_loss: 0.3817 - val_accuracy: 0.8434 - val_categorical_accuracy: 0.8434 - val_auc: 0.9119 - val_precision: 0.8434 - val_recall: 0.8434 - val_true_positives: 70.0000 - val_true_negatives: 70.0000 - val_false_positives: 13.0000 - val_false_negatives: 13.0000 - val_cohen_kappa: -0.9283 - val_f1_score: 0.8373 - lr: 2.6000e-06
# Epoch 32/50
# 46/45 [==============================] - ETA: 0s - loss: 0.1503 - accuracy: 0.9672 - categorical_accuracy: 0.9672 - auc: 0.9930 - precision: 0.9672 - recall: 0.9672 - true_positives: 354.0000 - true_negatives: 354.0000 - false_positives: 12.0000 - false_negatives: 12.0000 - cohen_kappa: -0.8811 - f1_score: 0.9650
# Epoch 32: val_accuracy improved from 0.84337 to 0.86747, saving model to convnext.h5
# 45/45 [==============================] - 16s 341ms/step - loss: 0.1503 - accuracy: 0.9672 - categorical_accuracy: 0.9672 - auc: 0.9930 - precision: 0.9672 - recall: 0.9672 - true_positives: 354.0000 - true_negatives: 354.0000 - false_positives: 12.0000 - false_negatives: 12.0000 - cohen_kappa: -0.8811 - f1_score: 0.9650 - val_loss: 0.3690 - val_accuracy: 0.8675 - val_categorical_accuracy: 0.8675 - val_auc: 0.9156 - val_precision: 0.8675 - val_recall: 0.8675 - val_true_positives: 72.0000 - val_true_negatives: 72.0000 - val_false_positives: 11.0000 - val_false_negatives: 11.0000 - val_cohen_kappa: -0.9102 - val_f1_score: 0.8609 - lr: 2.6000e-06
# Epoch 33/50
# 46/45 [==============================] - ETA: 0s - loss: 0.1505 - accuracy: 0.9617 - categorical_accuracy: 0.9617 - auc: 0.9929 - precision: 0.9617 - recall: 0.9617 - true_positives: 352.0000 - true_negatives: 352.0000 - false_positives: 14.0000 - false_negatives: 14.0000 - cohen_kappa: -0.8762 - f1_score: 0.9590
# Epoch 33: val_accuracy did not improve from 0.86747
# 45/45 [==============================] - 13s 273ms/step - loss: 0.1505 - accuracy: 0.9617 - categorical_accuracy: 0.9617 - auc: 0.9929 - precision: 0.9617 - recall: 0.9617 - true_positives: 352.0000 - true_negatives: 352.0000 - false_positives: 14.0000 - false_negatives: 14.0000 - cohen_kappa: -0.8762 - f1_score: 0.9590 - val_loss: 0.3819 - val_accuracy: 0.8434 - val_categorical_accuracy: 0.8434 - val_auc: 0.9075 - val_precision: 0.8434 - val_recall: 0.8434 - val_true_positives: 70.0000 - val_true_negatives: 70.0000 - val_false_positives: 13.0000 - val_false_negatives: 13.0000 - val_cohen_kappa: -0.9283 - val_f1_score: 0.8373 - lr: 2.6000e-06
# Epoch 34/50
# 46/45 [==============================] - ETA: 0s - loss: 0.1432 - accuracy: 0.9645 - categorical_accuracy: 0.9645 - auc: 0.9949 - precision: 0.9645 - recall: 0.9645 - true_positives: 353.0000 - true_negatives: 353.0000 - false_positives: 13.0000 - false_negatives: 13.0000 - cohen_kappa: -0.8738 - f1_score: 0.9619
# Epoch 34: val_accuracy improved from 0.86747 to 0.87952, saving model to convnext.h5
# 45/45 [==============================] - 16s 346ms/step - loss: 0.1432 - accuracy: 0.9645 - categorical_accuracy: 0.9645 - auc: 0.9949 - precision: 0.9645 - recall: 0.9645 - true_positives: 353.0000 - true_negatives: 353.0000 - false_positives: 13.0000 - false_negatives: 13.0000 - cohen_kappa: -0.8738 - f1_score: 0.9619 - val_loss: 0.3547 - val_accuracy: 0.8795 - val_categorical_accuracy: 0.8795 - val_auc: 0.9219 - val_precision: 0.8795 - val_recall: 0.8795 - val_true_positives: 73.0000 - val_true_negatives: 73.0000 - val_false_positives: 10.0000 - val_false_negatives: 10.0000 - val_cohen_kappa: -0.9004 - val_f1_score: 0.8729 - lr: 2.6000e-06
# Epoch 35/50
# 46/45 [==============================] - ETA: 0s - loss: 0.1250 - accuracy: 0.9699 - categorical_accuracy: 0.9699 - auc: 0.9975 - precision: 0.9699 - recall: 0.9699 - true_positives: 355.0000 - true_negatives: 355.0000 - false_positives: 11.0000 - false_negatives: 11.0000 - cohen_kappa: -0.8787 - f1_score: 0.9679
# Epoch 35: val_accuracy did not improve from 0.87952
# 45/45 [==============================] - 13s 273ms/step - loss: 0.1250 - accuracy: 0.9699 - categorical_accuracy: 0.9699 - auc: 0.9975 - precision: 0.9699 - recall: 0.9699 - true_positives: 355.0000 - true_negatives: 355.0000 - false_positives: 11.0000 - false_negatives: 11.0000 - cohen_kappa: -0.8787 - f1_score: 0.9679 - val_loss: 0.3684 - val_accuracy: 0.8675 - val_categorical_accuracy: 0.8675 - val_auc: 0.9138 - val_precision: 0.8675 - val_recall: 0.8675 - val_true_positives: 72.0000 - val_true_negatives: 72.0000 - val_false_positives: 11.0000 - val_false_negatives: 11.0000 - val_cohen_kappa: -0.9102 - val_f1_score: 0.8609 - lr: 2.6000e-06
# Epoch 36/50
# 46/45 [==============================] - ETA: 0s - loss: 0.1223 - accuracy: 0.9754 - categorical_accuracy: 0.9754 - auc: 0.9974 - precision: 0.9754 - recall: 0.9754 - true_positives: 357.0000 - true_negatives: 357.0000 - false_positives: 9.0000 - false_negatives: 9.0000 - cohen_kappa: -0.8738 - f1_score: 0.9736
# Epoch 36: val_accuracy did not improve from 0.87952
# 45/45 [==============================] - 13s 277ms/step - loss: 0.1223 - accuracy: 0.9754 - categorical_accuracy: 0.9754 - auc: 0.9974 - precision: 0.9754 - recall: 0.9754 - true_positives: 357.0000 - true_negatives: 357.0000 - false_positives: 9.0000 - false_negatives: 9.0000 - cohen_kappa: -0.8738 - f1_score: 0.9736 - val_loss: 0.3548 - val_accuracy: 0.8795 - val_categorical_accuracy: 0.8795 - val_auc: 0.9180 - val_precision: 0.8795 - val_recall: 0.8795 - val_true_positives: 73.0000 - val_true_negatives: 73.0000 - val_false_positives: 10.0000 - val_false_negatives: 10.0000 - val_cohen_kappa: -0.9004 - val_f1_score: 0.8729 - lr: 2.6000e-06
# Epoch 37/50
# 46/45 [==============================] - ETA: 0s - loss: 0.1120 - accuracy: 0.9863 - categorical_accuracy: 0.9863 - auc: 0.9966 - precision: 0.9863 - recall: 0.9863 - true_positives: 361.0000 - true_negatives: 361.0000 - false_positives: 5.0000 - false_negatives: 5.0000 - cohen_kappa: -0.8687 - f1_score: 0.9853
# Epoch 37: val_accuracy did not improve from 0.87952
# 45/45 [==============================] - 13s 279ms/step - loss: 0.1120 - accuracy: 0.9863 - categorical_accuracy: 0.9863 - auc: 0.9966 - precision: 0.9863 - recall: 0.9863 - true_positives: 361.0000 - true_negatives: 361.0000 - false_positives: 5.0000 - false_negatives: 5.0000 - cohen_kappa: -0.8687 - f1_score: 0.9853 - val_loss: 0.3567 - val_accuracy: 0.8795 - val_categorical_accuracy: 0.8795 - val_auc: 0.9165 - val_precision: 0.8795 - val_recall: 0.8795 - val_true_positives: 73.0000 - val_true_negatives: 73.0000 - val_false_positives: 10.0000 - val_false_negatives: 10.0000 - val_cohen_kappa: -0.9004 - val_f1_score: 0.8729 - lr: 2.6000e-06
# Epoch 38/50
# 46/45 [==============================] - ETA: 0s - loss: 0.1075 - accuracy: 0.9809 - categorical_accuracy: 0.9809 - auc: 0.9952 - precision: 0.9809 - recall: 0.9809 - true_positives: 359.0000 - true_negatives: 359.0000 - false_positives: 7.0000 - false_negatives: 7.0000 - cohen_kappa: -0.8738 - f1_score: 0.9795
# Epoch 38: val_accuracy improved from 0.87952 to 0.89157, saving model to convnext.h5
# 45/45 [==============================] - 16s 349ms/step - loss: 0.1075 - accuracy: 0.9809 - categorical_accuracy: 0.9809 - auc: 0.9952 - precision: 0.9809 - recall: 0.9809 - true_positives: 359.0000 - true_negatives: 359.0000 - false_positives: 7.0000 - false_negatives: 7.0000 - cohen_kappa: -0.8738 - f1_score: 0.9795 - val_loss: 0.3355 - val_accuracy: 0.8916 - val_categorical_accuracy: 0.8916 - val_auc: 0.9250 - val_precision: 0.8916 - val_recall: 0.8916 - val_true_positives: 74.0000 - val_true_negatives: 74.0000 - val_false_positives: 9.0000 - val_false_negatives: 9.0000 - val_cohen_kappa: -0.8902 - val_f1_score: 0.8849 - lr: 2.6000e-06
# Epoch 39/50
# 46/45 [==============================] - ETA: 0s - loss: 0.1035 - accuracy: 0.9781 - categorical_accuracy: 0.9781 - auc: 0.9986 - precision: 0.9781 - recall: 0.9781 - true_positives: 358.0000 - true_negatives: 358.0000 - false_positives: 8.0000 - false_negatives: 8.0000 - cohen_kappa: -0.8662 - f1_score: 0.9765
# Epoch 39: val_accuracy did not improve from 0.89157
# 45/45 [==============================] - 13s 277ms/step - loss: 0.1035 - accuracy: 0.9781 - categorical_accuracy: 0.9781 - auc: 0.9986 - precision: 0.9781 - recall: 0.9781 - true_positives: 358.0000 - true_negatives: 358.0000 - false_positives: 8.0000 - false_negatives: 8.0000 - cohen_kappa: -0.8662 - f1_score: 0.9765 - val_loss: 0.3498 - val_accuracy: 0.8795 - val_categorical_accuracy: 0.8795 - val_auc: 0.9191 - val_precision: 0.8795 - val_recall: 0.8795 - val_true_positives: 73.0000 - val_true_negatives: 73.0000 - val_false_positives: 10.0000 - val_false_negatives: 10.0000 - val_cohen_kappa: -0.9004 - val_f1_score: 0.8729 - lr: 2.6000e-06
# Epoch 40/50
# 46/45 [==============================] - ETA: 0s - loss: 0.0956 - accuracy: 0.9754 - categorical_accuracy: 0.9754 - auc: 0.9982 - precision: 0.9754 - recall: 0.9754 - true_positives: 357.0000 - true_negatives: 357.0000 - false_positives: 9.0000 - false_negatives: 9.0000 - cohen_kappa: -0.8687 - f1_score: 0.9736
# Epoch 40: val_accuracy did not improve from 0.89157
# 45/45 [==============================] - 13s 276ms/step - loss: 0.0956 - accuracy: 0.9754 - categorical_accuracy: 0.9754 - auc: 0.9982 - precision: 0.9754 - recall: 0.9754 - true_positives: 357.0000 - true_negatives: 357.0000 - false_positives: 9.0000 - false_negatives: 9.0000 - cohen_kappa: -0.8687 - f1_score: 0.9736 - val_loss: 0.3473 - val_accuracy: 0.8916 - val_categorical_accuracy: 0.8916 - val_auc: 0.9205 - val_precision: 0.8916 - val_recall: 0.8916 - val_true_positives: 74.0000 - val_true_negatives: 74.0000 - val_false_positives: 9.0000 - val_false_negatives: 9.0000 - val_cohen_kappa: -0.8902 - val_f1_score: 0.8849 - lr: 2.6000e-06
# Epoch 41/50
# 46/45 [==============================] - ETA: 0s - loss: 0.0920 - accuracy: 0.9863 - categorical_accuracy: 0.9863 - auc: 0.9984 - precision: 0.9863 - recall: 0.9863 - true_positives: 361.0000 - true_negatives: 361.0000 - false_positives: 5.0000 - false_negatives: 5.0000 - cohen_kappa: -0.8636 - f1_score: 0.9853
# Epoch 41: val_accuracy did not improve from 0.89157
# 45/45 [==============================] - 13s 280ms/step - loss: 0.0920 - accuracy: 0.9863 - categorical_accuracy: 0.9863 - auc: 0.9984 - precision: 0.9863 - recall: 0.9863 - true_positives: 361.0000 - true_negatives: 361.0000 - false_positives: 5.0000 - false_negatives: 5.0000 - cohen_kappa: -0.8636 - f1_score: 0.9853 - val_loss: 0.3416 - val_accuracy: 0.8916 - val_categorical_accuracy: 0.8916 - val_auc: 0.9209 - val_precision: 0.8916 - val_recall: 0.8916 - val_true_positives: 74.0000 - val_true_negatives: 74.0000 - val_false_positives: 9.0000 - val_false_negatives: 9.0000 - val_cohen_kappa: -0.8902 - val_f1_score: 0.8849 - lr: 2.6000e-06
# Epoch 42/50
# 46/45 [==============================] - ETA: 0s - loss: 0.0909 - accuracy: 0.9809 - categorical_accuracy: 0.9809 - auc: 0.9987 - precision: 0.9809 - recall: 0.9809 - true_positives: 359.0000 - true_negatives: 359.0000 - false_positives: 7.0000 - false_negatives: 7.0000 - cohen_kappa: -0.8738 - f1_score: 0.9795
# Epoch 42: val_accuracy did not improve from 0.89157
# 45/45 [==============================] - 13s 285ms/step - loss: 0.0909 - accuracy: 0.9809 - categorical_accuracy: 0.9809 - auc: 0.9987 - precision: 0.9809 - recall: 0.9809 - true_positives: 359.0000 - true_negatives: 359.0000 - false_positives: 7.0000 - false_negatives: 7.0000 - cohen_kappa: -0.8738 - f1_score: 0.9795 - val_loss: 0.2942 - val_accuracy: 0.8916 - val_categorical_accuracy: 0.8916 - val_auc: 0.9427 - val_precision: 0.8916 - val_recall: 0.8916 - val_true_positives: 74.0000 - val_true_negatives: 74.0000 - val_false_positives: 9.0000 - val_false_negatives: 9.0000 - val_cohen_kappa: -0.8902 - val_f1_score: 0.8849 - lr: 2.6000e-06
# Epoch 43/50
# 46/45 [==============================] - ETA: 0s - loss: 0.0832 - accuracy: 0.9918 - categorical_accuracy: 0.9918 - auc: 0.9993 - precision: 0.9918 - recall: 0.9918 - true_positives: 363.0000 - true_negatives: 363.0000 - false_positives: 3.0000 - false_negatives: 3.0000 - cohen_kappa: -0.8636 - f1_score: 0.9912
# Epoch 43: val_accuracy did not improve from 0.89157
# 45/45 [==============================] - 13s 278ms/step - loss: 0.0832 - accuracy: 0.9918 - categorical_accuracy: 0.9918 - auc: 0.9993 - precision: 0.9918 - recall: 0.9918 - true_positives: 363.0000 - true_negatives: 363.0000 - false_positives: 3.0000 - false_negatives: 3.0000 - cohen_kappa: -0.8636 - f1_score: 0.9912 - val_loss: 0.3342 - val_accuracy: 0.8795 - val_categorical_accuracy: 0.8795 - val_auc: 0.9250 - val_precision: 0.8795 - val_recall: 0.8795 - val_true_positives: 73.0000 - val_true_negatives: 73.0000 - val_false_positives: 10.0000 - val_false_negatives: 10.0000 - val_cohen_kappa: -0.9004 - val_f1_score: 0.8729 - lr: 2.6000e-06
# Epoch 44/50
# 46/45 [==============================] - ETA: 0s - loss: 0.0810 - accuracy: 0.9836 - categorical_accuracy: 0.9836 - auc: 0.9982 - precision: 0.9836 - recall: 0.9836 - true_positives: 360.0000 - true_negatives: 360.0000 - false_positives: 6.0000 - false_negatives: 6.0000 - cohen_kappa: -0.8662 - f1_score: 0.9823
# Epoch 44: val_accuracy did not improve from 0.89157
# 45/45 [==============================] - 13s 277ms/step - loss: 0.0810 - accuracy: 0.9836 - categorical_accuracy: 0.9836 - auc: 0.9982 - precision: 0.9836 - recall: 0.9836 - true_positives: 360.0000 - true_negatives: 360.0000 - false_positives: 6.0000 - false_negatives: 6.0000 - cohen_kappa: -0.8662 - f1_score: 0.9823 - val_loss: 0.3146 - val_accuracy: 0.8916 - val_categorical_accuracy: 0.8916 - val_auc: 0.9322 - val_precision: 0.8916 - val_recall: 0.8916 - val_true_positives: 74.0000 - val_true_negatives: 74.0000 - val_false_positives: 9.0000 - val_false_negatives: 9.0000 - val_cohen_kappa: -0.8902 - val_f1_score: 0.8849 - lr: 2.6000e-06
# Epoch 45/50
# 46/45 [==============================] - ETA: 0s - loss: 0.0694 - accuracy: 0.9863 - categorical_accuracy: 0.9863 - auc: 0.9996 - precision: 0.9863 - recall: 0.9863 - true_positives: 361.0000 - true_negatives: 361.0000 - false_positives: 5.0000 - false_negatives: 5.0000 - cohen_kappa: -0.8687 - f1_score: 0.9853
# Epoch 45: val_accuracy did not improve from 0.89157
# 45/45 [==============================] - 13s 280ms/step - loss: 0.0694 - accuracy: 0.9863 - categorical_accuracy: 0.9863 - auc: 0.9996 - precision: 0.9863 - recall: 0.9863 - true_positives: 361.0000 - true_negatives: 361.0000 - false_positives: 5.0000 - false_negatives: 5.0000 - cohen_kappa: -0.8687 - f1_score: 0.9853 - val_loss: 0.2975 - val_accuracy: 0.8916 - val_categorical_accuracy: 0.8916 - val_auc: 0.9393 - val_precision: 0.8916 - val_recall: 0.8916 - val_true_positives: 74.0000 - val_true_negatives: 74.0000 - val_false_positives: 9.0000 - val_false_negatives: 9.0000 - val_cohen_kappa: -0.8902 - val_f1_score: 0.8849 - lr: 2.6000e-06
# Epoch 46/50
# 46/45 [==============================] - ETA: 0s - loss: 0.0611 - accuracy: 0.9945 - categorical_accuracy: 0.9945 - auc: 1.0000 - precision: 0.9945 - recall: 0.9945 - true_positives: 364.0000 - true_negatives: 364.0000 - false_positives: 2.0000 - false_negatives: 2.0000 - cohen_kappa: -0.8559 - f1_score: 0.9941
# Epoch 46: val_accuracy did not improve from 0.89157
# 45/45 [==============================] - 13s 277ms/step - loss: 0.0611 - accuracy: 0.9945 - categorical_accuracy: 0.9945 - auc: 1.0000 - precision: 0.9945 - recall: 0.9945 - true_positives: 364.0000 - true_negatives: 364.0000 - false_positives: 2.0000 - false_negatives: 2.0000 - cohen_kappa: -0.8559 - f1_score: 0.9941 - val_loss: 0.3317 - val_accuracy: 0.8795 - val_categorical_accuracy: 0.8795 - val_auc: 0.9274 - val_precision: 0.8795 - val_recall: 0.8795 - val_true_positives: 73.0000 - val_true_negatives: 73.0000 - val_false_positives: 10.0000 - val_false_negatives: 10.0000 - val_cohen_kappa: -0.9004 - val_f1_score: 0.8729 - lr: 2.6000e-06
# Epoch 47/50
# 46/45 [==============================] - ETA: 0s - loss: 0.0712 - accuracy: 0.9781 - categorical_accuracy: 0.9781 - auc: 0.9993 - precision: 0.9781 - recall: 0.9781 - true_positives: 358.0000 - true_negatives: 358.0000 - false_positives: 8.0000 - false_negatives: 8.0000 - cohen_kappa: -0.8662 - f1_score: 0.9765
# Epoch 47: val_accuracy did not improve from 0.89157
# 45/45 [==============================] - 13s 278ms/step - loss: 0.0712 - accuracy: 0.9781 - categorical_accuracy: 0.9781 - auc: 0.9993 - precision: 0.9781 - recall: 0.9781 - true_positives: 358.0000 - true_negatives: 358.0000 - false_positives: 8.0000 - false_negatives: 8.0000 - cohen_kappa: -0.8662 - f1_score: 0.9765 - val_loss: 0.3390 - val_accuracy: 0.8795 - val_categorical_accuracy: 0.8795 - val_auc: 0.9226 - val_precision: 0.8795 - val_recall: 0.8795 - val_true_positives: 73.0000 - val_true_negatives: 73.0000 - val_false_positives: 10.0000 - val_false_negatives: 10.0000 - val_cohen_kappa: -0.9004 - val_f1_score: 0.8729 - lr: 2.6000e-06
# Epoch 48/50
# 46/45 [==============================] - ETA: 0s - loss: 0.0606 - accuracy: 0.9918 - categorical_accuracy: 0.9918 - auc: 0.9991 - precision: 0.9918 - recall: 0.9918 - true_positives: 363.0000 - true_negatives: 363.0000 - false_positives: 3.0000 - false_negatives: 3.0000 - cohen_kappa: -0.8636 - f1_score: 0.9912
# Epoch 48: val_accuracy did not improve from 0.89157
# 45/45 [==============================] - 13s 279ms/step - loss: 0.0606 - accuracy: 0.9918 - categorical_accuracy: 0.9918 - auc: 0.9991 - precision: 0.9918 - recall: 0.9918 - true_positives: 363.0000 - true_negatives: 363.0000 - false_positives: 3.0000 - false_negatives: 3.0000 - cohen_kappa: -0.8636 - f1_score: 0.9912 - val_loss: 0.3133 - val_accuracy: 0.8916 - val_categorical_accuracy: 0.8916 - val_auc: 0.9325 - val_precision: 0.8916 - val_recall: 0.8916 - val_true_positives: 74.0000 - val_true_negatives: 74.0000 - val_false_positives: 9.0000 - val_false_negatives: 9.0000 - val_cohen_kappa: -0.8902 - val_f1_score: 0.8849 - lr: 2.6000e-06
# Epoch 49/50
# 46/45 [==============================] - ETA: 0s - loss: 0.0623 - accuracy: 0.9891 - categorical_accuracy: 0.9891 - auc: 0.9994 - precision: 0.9891 - recall: 0.9891 - true_positives: 362.0000 - true_negatives: 362.0000 - false_positives: 4.0000 - false_negatives: 4.0000 - cohen_kappa: -0.8611 - f1_score: 0.9882
# Epoch 49: val_accuracy did not improve from 0.89157
# 45/45 [==============================] - 14s 302ms/step - loss: 0.0623 - accuracy: 0.9891 - categorical_accuracy: 0.9891 - auc: 0.9994 - precision: 0.9891 - recall: 0.9891 - true_positives: 362.0000 - true_negatives: 362.0000 - false_positives: 4.0000 - false_negatives: 4.0000 - cohen_kappa: -0.8611 - f1_score: 0.9882 - val_loss: 0.3342 - val_accuracy: 0.8795 - val_categorical_accuracy: 0.8795 - val_auc: 0.9264 - val_precision: 0.8795 - val_recall: 0.8795 - val_true_positives: 73.0000 - val_true_negatives: 73.0000 - val_false_positives: 10.0000 - val_false_negatives: 10.0000 - val_cohen_kappa: -0.9004 - val_f1_score: 0.8729 - lr: 2.6000e-06
# Epoch 50/50
# 46/45 [==============================] - ETA: 0s - loss: 0.0548 - accuracy: 0.9891 - categorical_accuracy: 0.9891 - auc: 0.9996 - precision: 0.9891 - recall: 0.9891 - true_positives: 362.0000 - true_negatives: 362.0000 - false_positives: 4.0000 - false_negatives: 4.0000 - cohen_kappa: -0.8662 - f1_score: 0.9882
# Epoch 50: val_accuracy did not improve from 0.89157
# 45/45 [==============================] - 13s 289ms/step - loss: 0.0548 - accuracy: 0.9891 - categorical_accuracy: 0.9891 - auc: 0.9996 - precision: 0.9891 - recall: 0.9891 - true_positives: 362.0000 - true_negatives: 362.0000 - false_positives: 4.0000 - false_negatives: 4.0000 - cohen_kappa: -0.8662 - f1_score: 0.9882 - val_loss: 0.2891 - val_accuracy: 0.8916 - val_categorical_accuracy: 0.8916 - val_auc: 0.9419 - val_precision: 0.8916 - val_recall: 0.8916 - val_true_positives: 74.0000 - val_true_negatives: 74.0000 - val_false_positives: 9.0000 - val_false_negatives: 9.0000 - val_cohen_kappa: -0.8902 - val_f1_score: 0.8849 - lr: 2.6000e-06

# %%
model = keras.models.load_model(weight)
evaluate_(model, generator_test)
plot_graphs(history, generator_test)
# Out:
# 11/11 [==============================] - 4s 139ms/step - loss: 0.3355 - accuracy: 0.8916 - categorical_accuracy: 0.8916 - auc: 0.9250 - precision: 0.8916 - recall: 0.8916 - true_positives: 74.0000 - true_negatives: 74.0000 - false_positives: 9.0000 - false_negatives: 9.0000 - cohen_kappa: -0.8902 - f1_score: 0.8849
#               precision    recall  f1-score   support
#
#            0       0.75      1.00      0.86        27
#            1       1.00      0.84      0.91        56
#
#     accuracy                           0.89        83
#    macro avg       0.88      0.92      0.88        83
# weighted avg       0.92      0.89      0.89        83
# C:\Users\sakib\AppData\Local\Temp\ipykernel_15476\4210797192.py:76: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   predictions = model.predict_generator(generator_test)
