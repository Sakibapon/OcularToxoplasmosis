# %%
import sys
import os
from math import log
import numpy as np
import seaborn as sns
import pandas as pd
import scipy as sp
from PIL import Image
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_addons as tfa
from tensorflow import keras
from tensorflow.keras import layers
import cv2 as cv
import pickle
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.models import Model
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.utils import compute_class_weight
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import roc_curve, roc_auc_score, auc

np.random.seed(72)
tf.random.set_seed(72)
sess = tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(log_device_placement=True))
# Out:
# D:\anaconda\envs\tf_gpu\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.3.0 and strictly below 2.6.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.8.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 4070 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
def get_train_test(train_dir, test_dir):
    datagen_train = ImageDataGenerator(rescale=1./255, width_shift_range=0.1, height_shift_range=0.1,
                                      horizontal_flip=True,  vertical_flip=False)
    datagen_test = ImageDataGenerator(rescale=1./255)

    generator_train = datagen_train.flow_from_directory(directory=train_dir, target_size=(image_size, image_size),
                                                        batch_size=batch_size, shuffle=True)
    generator_test = datagen_test.flow_from_directory(directory=test_dir, target_size=(image_size, image_size),
                                                      batch_size=batch_size, shuffle=False)

    num_classes = generator_train.num_classes
    labels = generator_train.classes
    class_weights = compute_class_weight(class_weight="balanced", classes=np.unique(labels), y=labels)
    class_weights = dict(zip(np.unique(labels), class_weights))
    print(class_weights)
    
    steps_per_epoch = generator_train.n / batch_size
    steps_test = generator_test.n / batch_size
    return generator_train, generator_test, labels, class_weights, num_classes, steps_per_epoch, steps_test

def compile_model(model, weight):
    optimizer = Adam(lr=0.0000026) 
    loss = 'categorical_crossentropy'

    metrics = ['accuracy', 'categorical_accuracy', tf.keras.metrics.AUC(), tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), 
               tf.keras.metrics.TruePositives(), tf.keras.metrics.TrueNegatives(), tf.keras.metrics.FalsePositives(), 
               tf.keras.metrics.FalseNegatives(), tfa.metrics.CohenKappa(num_classes = num_classes), 
               tfa.metrics.F1Score(num_classes = num_classes)]

    model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

    lr = tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.1,
        patience=9, mode="max", min_delta=0.0001, min_lr=0.00001, verbose=1)
    checkpoint = ModelCheckpoint(filepath=weight, save_best_only=True, monitor = 'val_accuracy', verbose=1)
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=1, restore_best_weights=True)

    callbacks = [lr, checkpoint, early_stopping]
    return model, callbacks

def evaluate_(model, generator_test):
    model.evaluate(generator_test)
    
    y_pred = model.predict(generator_test)
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_true = generator_test.classes
    class_labels = list(generator_test.class_indices.keys())

    print(classification_report(y_true, y_pred_classes))
    cm = confusion_matrix(y_true, y_pred_classes)
    
    # Plotting the confusion matrix
    plt.figure(figsize=(8, 8))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_labels, yticklabels=class_labels)
    plt.show()
    
def plot_graphs(history, generator_test):
    plt.figure(figsize=(15,7))
    plt.plot(history.history['accuracy'], 'r', linewidth=2.5)
    plt.plot(history.history['val_accuracy'], linewidth=2.5)
    plt.title('Model Accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['Training Accuracy', 'Testing Accuracy'], loc='upper left')
    plt.show()

    plt.figure(figsize=(15,7))
    plt.plot(history.history['loss'], 'r', linewidth=2.5)
    plt.plot(history.history['val_loss'], linewidth=2.5)
    plt.title('Model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['Train Loss', 'Test Loss'], loc='upper left')
    plt.show()
    
    # Generate predictions
    predictions = model.predict_generator(generator_test)
    # Get true labels
    true_labels = generator_test.classes
    # Binarize the true labels
    encoder = OneHotEncoder(sparse=False)
    true_labels = encoder.fit_transform(true_labels.reshape(-1, 1))
    # Calculate ROC curve and ROC AUC for each class
    n_classes = true_labels.shape[1]
    fpr = dict()
    tpr = dict()
    roc_auc = dict()

    for class_idx in range(n_classes):
        fpr[class_idx], tpr[class_idx], _ = roc_curve(true_labels[:, class_idx], predictions[:, class_idx])
        roc_auc[class_idx] = auc(fpr[class_idx], tpr[class_idx])

    # Plot ROC curves for each class
    plt.figure(figsize=(12, 12))
    for class_idx in range(n_classes):

        plt.plot(fpr[class_idx], tpr[class_idx], label='ROC curve (area = %0.2f) for class %d' % (roc_auc[class_idx], class_idx),
                linewidth=2.5)

    plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic per Class')
    plt.legend(loc='lower right')
    plt.show()

# %%
# Params
num_classes = 2
batch_size = 8
image_size = 112
weight = 'MobileViT.h5'

# %%
from keras_cv_attention_models import mobilevit
model = mobilevit.MobileViT_V2_200(input_shape=(image_size, image_size, 3) , num_classes=num_classes, 
                         drop_connect_rate=0.2, classifier_activation="softmax")
# Out:
# Downloading data from https://github.com/leondgarse/keras_cv_attention_models/releases/download/mobilevit/mobilevit_v2_200_256_imagenet.h5
# 74539008/74536532 [==============================] - 10s 0us/step
# 74547200/74536532 [==============================] - 10s 0us/step
# >>>> Load pretrained from: C:\Users\sakib\.keras\models\mobilevit_v2_200_256_imagenet.h5
# WARNING:tensorflow:Skipping loading weights for layer #250 (named predictions) due to mismatch in shape for weight predictions/kernel:0. Weight expects shape (1024, 2). Received saved weight with shape (1024, 1000)
# WARNING:tensorflow:Skipping loading weights for layer #250 (named predictions) due to mismatch in shape for weight predictions/bias:0. Weight expects shape (2,). Received saved weight with shape (1000,)

# %%
train_dir = r"F:\Projects\Personal\Ocular Toxoplasmosis\data\BinaryClassification\train"
test_dir = r"F:\Projects\Personal\Ocular Toxoplasmosis\data\BinaryClassification\val"
generator_train, generator_test, labels, class_weights, num_classes, steps_per_epoch, steps_test = get_train_test(train_dir, test_dir)
model, callbacks = compile_model(model, weight)
# Out:
# Found 366 images belonging to 2 classes.
# Found 83 images belonging to 2 classes.
# {0: 1.3863636363636365, 1: 0.782051282051282}
# D:\anaconda\envs\tf_gpu\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
model.summary()
# Out:
# Model: "mobilevit_v2_200"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 112, 112, 3  0           []
#                                 )]
#
#  stem_pad (ZeroPadding2D)       (None, 114, 114, 3)  0           ['input_1[0][0]']
#
#  stem_conv (Conv2D)             (None, 56, 56, 64)   1728        ['stem_pad[0][0]']
#
#  stem_bn (BatchNormalization)   (None, 56, 56, 64)   256         ['stem_conv[0][0]']
#
#  stem_swish (Activation)        (None, 56, 56, 64)   0           ['stem_bn[0][0]']
#
#  stack1_block1_deep_1_conv (Con  (None, 56, 56, 128)  8192       ['stem_swish[0][0]']
#  v2D)
#
#  stack1_block1_deep_1_bn (Batch  (None, 56, 56, 128)  512        ['stack1_block1_deep_1_conv[0][0]
#  Normalization)                                                  ']
#
#  stack1_block1_deep_1_swish (Ac  (None, 56, 56, 128)  0          ['stack1_block1_deep_1_bn[0][0]']
#  tivation)
#
#  stack1_block1_deep_2_dw_pad (Z  (None, 58, 58, 128)  0          ['stack1_block1_deep_1_swish[0][0
#  eroPadding2D)                                                   ]']
#
#  stack1_block1_deep_2_dw_conv (  (None, 56, 56, 128)  1152       ['stack1_block1_deep_2_dw_pad[0][
#  DepthwiseConv2D)                                                0]']
#
#  stack1_block1_deep_2_bn (Batch  (None, 56, 56, 128)  512        ['stack1_block1_deep_2_dw_conv[0]
#  Normalization)                                                  [0]']
#
#  stack1_block1_deep_2_swish (Ac  (None, 56, 56, 128)  0          ['stack1_block1_deep_2_bn[0][0]']
#  tivation)
#
#  stack1_block1_deep_3_conv (Con  (None, 56, 56, 128)  16384      ['stack1_block1_deep_2_swish[0][0
#  v2D)                                                            ]']
#
#  stack1_block1_deep_3_bn (Batch  (None, 56, 56, 128)  512        ['stack1_block1_deep_3_conv[0][0]
#  Normalization)                                                  ']
#
#  stack2_block1_deep_1_conv (Con  (None, 56, 56, 256)  32768      ['stack1_block1_deep_3_bn[0][0]']
#  v2D)
#
#  stack2_block1_deep_1_bn (Batch  (None, 56, 56, 256)  1024       ['stack2_block1_deep_1_conv[0][0]
#  Normalization)                                                  ']
#
#  stack2_block1_deep_1_swish (Ac  (None, 56, 56, 256)  0          ['stack2_block1_deep_1_bn[0][0]']
#  tivation)
#
#  stack2_block1_deep_2_dw_pad (Z  (None, 58, 58, 256)  0          ['stack2_block1_deep_1_swish[0][0
#  eroPadding2D)                                                   ]']
#
#  stack2_block1_deep_2_dw_conv (  (None, 28, 28, 256)  2304       ['stack2_block1_deep_2_dw_pad[0][
#  DepthwiseConv2D)                                                0]']
#
#  stack2_block1_deep_2_bn (Batch  (None, 28, 28, 256)  1024       ['stack2_block1_deep_2_dw_conv[0]
#  Normalization)                                                  [0]']
#
#  stack2_block1_deep_2_swish (Ac  (None, 28, 28, 256)  0          ['stack2_block1_deep_2_bn[0][0]']
#  tivation)
#
#  stack2_block1_deep_3_conv (Con  (None, 28, 28, 256)  65536      ['stack2_block1_deep_2_swish[0][0
#  v2D)                                                            ]']
#
#  stack2_block1_deep_3_bn (Batch  (None, 28, 28, 256)  1024       ['stack2_block1_deep_3_conv[0][0]
#  Normalization)                                                  ']
#
#  stack2_block1_deep_drop (Dropo  (None, 28, 28, 256)  0          ['stack2_block1_deep_3_bn[0][0]']
#  ut)
#
#  stack2_block2_deep_1_conv (Con  (None, 28, 28, 512)  131072     ['stack2_block1_deep_drop[0][0]']
#  v2D)
#
#  stack2_block2_deep_1_bn (Batch  (None, 28, 28, 512)  2048       ['stack2_block2_deep_1_conv[0][0]
#  Normalization)                                                  ']
#
#  stack2_block2_deep_1_swish (Ac  (None, 28, 28, 512)  0          ['stack2_block2_deep_1_bn[0][0]']
#  tivation)
#
#  stack2_block2_deep_2_dw_pad (Z  (None, 30, 30, 512)  0          ['stack2_block2_deep_1_swish[0][0
#  eroPadding2D)                                                   ]']
#  stack2_block2_deep_2_dw_conv (  (None, 28, 28, 512)  4608       ['stack2_block2_deep_2_dw_pad[0][
#  DepthwiseConv2D)                                                0]']
#
#  stack2_block2_deep_2_bn (Batch  (None, 28, 28, 512)  2048       ['stack2_block2_deep_2_dw_conv[0]
#  Normalization)                                                  [0]']
#
#  stack2_block2_deep_2_swish (Ac  (None, 28, 28, 512)  0          ['stack2_block2_deep_2_bn[0][0]']
#  tivation)
#
#  stack2_block2_deep_3_conv (Con  (None, 28, 28, 256)  131072     ['stack2_block2_deep_2_swish[0][0
#  v2D)                                                            ]']
#
#  stack2_block2_deep_3_bn (Batch  (None, 28, 28, 256)  1024       ['stack2_block2_deep_3_conv[0][0]
#  Normalization)                                                  ']
#
#  stack2_block2_deep_drop (Dropo  (None, 28, 28, 256)  0          ['stack2_block2_deep_3_bn[0][0]']
#  ut)
#
#  add (Add)                      (None, 28, 28, 256)  0           ['stack2_block1_deep_drop[0][0]',
#                                                                   'stack2_block2_deep_drop[0][0]']
#
#  stack3_block1_deep_1_conv (Con  (None, 28, 28, 512)  131072     ['add[0][0]']
#  v2D)
#
#  stack3_block1_deep_1_bn (Batch  (None, 28, 28, 512)  2048       ['stack3_block1_deep_1_conv[0][0]
#  Normalization)                                                  ']
#
#  stack3_block1_deep_1_swish (Ac  (None, 28, 28, 512)  0          ['stack3_block1_deep_1_bn[0][0]']
#  tivation)
#
#  stack3_block1_deep_2_dw_pad (Z  (None, 30, 30, 512)  0          ['stack3_block1_deep_1_swish[0][0
#  eroPadding2D)                                                   ]']
#
#  stack3_block1_deep_2_dw_conv (  (None, 14, 14, 512)  4608       ['stack3_block1_deep_2_dw_pad[0][
#  DepthwiseConv2D)                                                0]']
#
#  stack3_block1_deep_2_bn (Batch  (None, 14, 14, 512)  2048       ['stack3_block1_deep_2_dw_conv[0]
#  Normalization)                                                  [0]']
#
#  stack3_block1_deep_2_swish (Ac  (None, 14, 14, 512)  0          ['stack3_block1_deep_2_bn[0][0]']
#  tivation)
#
#  stack3_block1_deep_3_conv (Con  (None, 14, 14, 512)  262144     ['stack3_block1_deep_2_swish[0][0
#  v2D)                                                            ]']
#
#  stack3_block1_deep_3_bn (Batch  (None, 14, 14, 512)  2048       ['stack3_block1_deep_3_conv[0][0]
#  Normalization)                                                  ']
#
#  stack3_block1_deep_drop (Dropo  (None, 14, 14, 512)  0          ['stack3_block1_deep_3_bn[0][0]']
#  ut)
#
#  stack3_block2_pre_1_dw_pad (Ze  (None, 16, 16, 512)  0          ['stack3_block1_deep_drop[0][0]']
#  roPadding2D)
#
#  stack3_block2_pre_1_dw_conv (D  (None, 14, 14, 512)  4608       ['stack3_block2_pre_1_dw_pad[0][0
#  epthwiseConv2D)                                                 ]']
#
#  stack3_block2_pre_1_bn (BatchN  (None, 14, 14, 512)  2048       ['stack3_block2_pre_1_dw_conv[0][
#  ormalization)                                                   0]']
#
#  stack3_block2_pre_1_swish (Act  (None, 14, 14, 512)  0          ['stack3_block2_pre_1_bn[0][0]']
#  ivation)
#
#  stack3_block2_pre_2_conv (Conv  (None, 14, 14, 256)  131072     ['stack3_block2_pre_1_swish[0][0]
#  2D)                                                             ']
#
#  tf.reshape (TFOpLambda)        (None, 7, 2, 256)    0           ['stack3_block2_pre_2_conv[0][0]'
#                                                                  ]
#
#  tf.compat.v1.transpose (TFOpLa  (None, 2, 7, 256)   0           ['tf.reshape[0][0]']
#  mbda)
#
#  tf.reshape_1 (TFOpLambda)      (None, 7, 4, 1792)   0           ['tf.compat.v1.transpose[0][0]']
#
#  tf.compat.v1.transpose_1 (TFOp  (None, 4, 7, 1792)  0           ['tf.reshape_1[0][0]']
#  Lambda)
#
#  tf.reshape_2 (TFOpLambda)      (None, 4, 49, 256)   0           ['tf.compat.v1.transpose_1[0][0]'
#                                                                  ]
#
#  stack3_block2_attn_group_norm   (None, 4, 49, 256)  512         ['tf.reshape_2[0][0]']
#  (GroupNormalization)
#  reshape (Reshape)              (None, 4, 49, 256)   0           ['stack3_block2_attn_group_norm[0
#                                                                  ][0]']
#
#  stack3_block2_attn_mhsa_qkv_co  (None, 4, 49, 513)  131841      ['reshape[0][0]']
#  nv (Conv2D)
#
#  tf.split (TFOpLambda)          [(None, 4, 49, 1),   0           ['stack3_block2_attn_mhsa_qkv_con
#                                  (None, 4, 49, 256)              v[0][0]']
#                                 , (None, 4, 49, 256
#                                 )]
#
#  stack3_block2_attn_mhsa_attent  (None, 4, 49, 1)    0           ['tf.split[0][0]']
#  ion_scores (Softmax)
#
#  multiply (Multiply)            (None, 4, 49, 256)   0           ['tf.split[0][1]',
#                                                                   'stack3_block2_attn_mhsa_attenti
#                                                                  on_scores[0][0]']
#
#  tf.nn.relu (TFOpLambda)        (None, 4, 49, 256)   0           ['tf.split[0][2]']
#
#  tf.math.reduce_sum (TFOpLambda  (None, 4, 1, 256)   0           ['multiply[0][0]']
#  )
#
#  tf.math.multiply (TFOpLambda)  (None, 4, 49, 256)   0           ['tf.nn.relu[0][0]',
#                                                                   'tf.math.reduce_sum[0][0]']
#
#  stack3_block2_attn_mhsa_output  (None, 4, 49, 256)  65792       ['tf.math.multiply[0][0]']
#  conv (Conv2D)
#
#  stack3_block2_attn_out (Add)   (None, 4, 49, 256)   0           ['tf.reshape_2[0][0]',
#                                                                   'stack3_block2_attn_mhsa_outputc
#                                                                  onv[0][0]']
#
#  stack3_block2_mlp_group_norm (  (None, 4, 49, 256)  512         ['stack3_block2_attn_out[0][0]']
#  GroupNormalization)
#
#  reshape_1 (Reshape)            (None, 4, 49, 256)   0           ['stack3_block2_mlp_group_norm[0]
#                                                                  [0]']
#
#  stack3_block2_mlp_Conv_0 (Conv  (None, 4, 49, 512)  131584      ['reshape_1[0][0]']
#  2D)
#
#  stack3_block2_mlp_swish (Activ  (None, 4, 49, 512)  0           ['stack3_block2_mlp_Conv_0[0][0]'
#  ation)                                                          ]
#
#  stack3_block2_mlp_Conv_1 (Conv  (None, 4, 49, 256)  131328      ['stack3_block2_mlp_swish[0][0]']
#  2D)
#
#  stack3_block2_out (Add)        (None, 4, 49, 256)   0           ['stack3_block2_attn_out[0][0]',
#                                                                   'stack3_block2_mlp_Conv_1[0][0]'
#                                                                  ]
#
#  stack3_block3_attn_group_norm   (None, 4, 49, 256)  512         ['stack3_block2_out[0][0]']
#  (GroupNormalization)
#
#  reshape_2 (Reshape)            (None, 4, 49, 256)   0           ['stack3_block3_attn_group_norm[0
#                                                                  ][0]']
#
#  stack3_block3_attn_mhsa_qkv_co  (None, 4, 49, 513)  131841      ['reshape_2[0][0]']
#  nv (Conv2D)
#
#  tf.split_1 (TFOpLambda)        [(None, 4, 49, 1),   0           ['stack3_block3_attn_mhsa_qkv_con
#                                  (None, 4, 49, 256)              v[0][0]']
#                                 , (None, 4, 49, 256
#                                 )]
#
#  stack3_block3_attn_mhsa_attent  (None, 4, 49, 1)    0           ['tf.split_1[0][0]']
#  ion_scores (Softmax)
#
#  multiply_1 (Multiply)          (None, 4, 49, 256)   0           ['tf.split_1[0][1]',
#                                                                   'stack3_block3_attn_mhsa_attenti
#                                                                  on_scores[0][0]']
#
#  tf.nn.relu_1 (TFOpLambda)      (None, 4, 49, 256)   0           ['tf.split_1[0][2]']
#
#  tf.math.reduce_sum_1 (TFOpLamb  (None, 4, 1, 256)   0           ['multiply_1[0][0]']
#  da)
#
#  tf.math.multiply_1 (TFOpLambda  (None, 4, 49, 256)  0           ['tf.nn.relu_1[0][0]',
#  )                                                                'tf.math.reduce_sum_1[0][0]']
#
#  stack3_block3_attn_mhsa_output  (None, 4, 49, 256)  65792       ['tf.math.multiply_1[0][0]']
#  conv (Conv2D)
#
#  stack3_block3_attn_out (Add)   (None, 4, 49, 256)   0           ['stack3_block2_out[0][0]',
#                                                                   'stack3_block3_attn_mhsa_outputc
#                                                                  onv[0][0]']
#
#  stack3_block3_mlp_group_norm (  (None, 4, 49, 256)  512         ['stack3_block3_attn_out[0][0]']
#  GroupNormalization)
#
#  reshape_3 (Reshape)            (None, 4, 49, 256)   0           ['stack3_block3_mlp_group_norm[0]
#                                                                  [0]']
#
#  stack3_block3_mlp_Conv_0 (Conv  (None, 4, 49, 512)  131584      ['reshape_3[0][0]']
#  2D)
#
#  stack3_block3_mlp_swish (Activ  (None, 4, 49, 512)  0           ['stack3_block3_mlp_Conv_0[0][0]'
#  ation)                                                          ]
#
#  stack3_block3_mlp_Conv_1 (Conv  (None, 4, 49, 256)  131328      ['stack3_block3_mlp_swish[0][0]']
#  2D)
#
#  stack3_block3_out (Add)        (None, 4, 49, 256)   0           ['stack3_block3_attn_out[0][0]',
#                                                                   'stack3_block3_mlp_Conv_1[0][0]'
#                                                                  ]
#
#  stack3_block3_post_group_norm   (None, 4, 49, 256)  512         ['stack3_block3_out[0][0]']
#  (GroupNormalization)
#
#  tf.reshape_3 (TFOpLambda)      (None, 4, 7, 1792)   0           ['stack3_block3_post_group_norm[0
#                                                                  ][0]']
#
#  tf.compat.v1.transpose_2 (TFOp  (None, 7, 4, 1792)  0           ['tf.reshape_3[0][0]']
#  Lambda)
#
#  tf.reshape_4 (TFOpLambda)      (None, 2, 7, 256)    0           ['tf.compat.v1.transpose_2[0][0]'
#                                                                  ]
#
#  tf.compat.v1.transpose_3 (TFOp  (None, 7, 2, 256)   0           ['tf.reshape_4[0][0]']
#  Lambda)
#
#  tf.reshape_5 (TFOpLambda)      (None, 14, 14, 256)  0           ['tf.compat.v1.transpose_3[0][0]'
#                                                                  ]
#
#  stack3_block3_post_1_conv (Con  (None, 14, 14, 512)  131072     ['tf.reshape_5[0][0]']
#  v2D)
#
#  stack3_block3_post_1_bn (Batch  (None, 14, 14, 512)  2048       ['stack3_block3_post_1_conv[0][0]
#  Normalization)                                                  ']
#
#  stack3_block3_output (Activati  (None, 14, 14, 512)  0          ['stack3_block3_post_1_bn[0][0]']
#  on)
#
#  stack4_block1_deep_1_conv (Con  (None, 14, 14, 1024  524288     ['stack3_block3_output[0][0]']
#  v2D)                           )
#
#  stack4_block1_deep_1_bn (Batch  (None, 14, 14, 1024  4096       ['stack4_block1_deep_1_conv[0][0]
#  Normalization)                 )                                ']
#
#  stack4_block1_deep_1_swish (Ac  (None, 14, 14, 1024  0          ['stack4_block1_deep_1_bn[0][0]']
#  tivation)                      )
#
#  stack4_block1_deep_2_dw_pad (Z  (None, 16, 16, 1024  0          ['stack4_block1_deep_1_swish[0][0
#  eroPadding2D)                  )                                ]']
#
#  stack4_block1_deep_2_dw_conv (  (None, 7, 7, 1024)  9216        ['stack4_block1_deep_2_dw_pad[0][
#  DepthwiseConv2D)                                                0]']
#
#  stack4_block1_deep_2_bn (Batch  (None, 7, 7, 1024)  4096        ['stack4_block1_deep_2_dw_conv[0]
#  Normalization)                                                  [0]']
#
#  stack4_block1_deep_2_swish (Ac  (None, 7, 7, 1024)  0           ['stack4_block1_deep_2_bn[0][0]']
#  tivation)
#
#  stack4_block1_deep_3_conv (Con  (None, 7, 7, 768)   786432      ['stack4_block1_deep_2_swish[0][0
#  v2D)                                                            ]']
#
#  stack4_block1_deep_3_bn (Batch  (None, 7, 7, 768)   3072        ['stack4_block1_deep_3_conv[0][0]
#  Normalization)                                                  ']
#
#  stack4_block1_deep_drop (Dropo  (None, 7, 7, 768)   0           ['stack4_block1_deep_3_bn[0][0]']
#  ut)
#
#  tf.image.resize (TFOpLambda)   (None, 8, 8, 768)    0           ['stack4_block1_deep_drop[0][0]']
#  stack4_block2_pre_1_dw_pad (Ze  (None, 10, 10, 768)  0          ['tf.image.resize[0][0]']
#  roPadding2D)
#
#  stack4_block2_pre_1_dw_conv (D  (None, 8, 8, 768)   6912        ['stack4_block2_pre_1_dw_pad[0][0
#  epthwiseConv2D)                                                 ]']
#
#  stack4_block2_pre_1_bn (BatchN  (None, 8, 8, 768)   3072        ['stack4_block2_pre_1_dw_conv[0][
#  ormalization)                                                   0]']
#
#  stack4_block2_pre_1_swish (Act  (None, 8, 8, 768)   0           ['stack4_block2_pre_1_bn[0][0]']
#  ivation)
#
#  stack4_block2_pre_2_conv (Conv  (None, 8, 8, 384)   294912      ['stack4_block2_pre_1_swish[0][0]
#  2D)                                                             ']
#
#  tf.reshape_6 (TFOpLambda)      (None, 4, 2, 384)    0           ['stack4_block2_pre_2_conv[0][0]'
#                                                                  ]
#
#  tf.compat.v1.transpose_4 (TFOp  (None, 2, 4, 384)   0           ['tf.reshape_6[0][0]']
#  Lambda)
#
#  tf.reshape_7 (TFOpLambda)      (None, 4, 4, 1536)   0           ['tf.compat.v1.transpose_4[0][0]'
#                                                                  ]
#
#  tf.compat.v1.transpose_5 (TFOp  (None, 4, 4, 1536)  0           ['tf.reshape_7[0][0]']
#  Lambda)
#
#  tf.reshape_8 (TFOpLambda)      (None, 4, 16, 384)   0           ['tf.compat.v1.transpose_5[0][0]'
#                                                                  ]
#
#  stack4_block2_attn_group_norm   (None, 4, 16, 384)  768         ['tf.reshape_8[0][0]']
#  (GroupNormalization)
#
#  reshape_4 (Reshape)            (None, 4, 16, 384)   0           ['stack4_block2_attn_group_norm[0
#                                                                  ][0]']
#
#  stack4_block2_attn_mhsa_qkv_co  (None, 4, 16, 769)  296065      ['reshape_4[0][0]']
#  nv (Conv2D)
#
#  tf.split_2 (TFOpLambda)        [(None, 4, 16, 1),   0           ['stack4_block2_attn_mhsa_qkv_con
#                                  (None, 4, 16, 384)              v[0][0]']
#                                 , (None, 4, 16, 384
#                                 )]
#
#  stack4_block2_attn_mhsa_attent  (None, 4, 16, 1)    0           ['tf.split_2[0][0]']
#  ion_scores (Softmax)
#
#  multiply_2 (Multiply)          (None, 4, 16, 384)   0           ['tf.split_2[0][1]',
#                                                                   'stack4_block2_attn_mhsa_attenti
#                                                                  on_scores[0][0]']
#
#  tf.nn.relu_2 (TFOpLambda)      (None, 4, 16, 384)   0           ['tf.split_2[0][2]']
#
#  tf.math.reduce_sum_2 (TFOpLamb  (None, 4, 1, 384)   0           ['multiply_2[0][0]']
#  da)
#
#  tf.math.multiply_2 (TFOpLambda  (None, 4, 16, 384)  0           ['tf.nn.relu_2[0][0]',
#  )                                                                'tf.math.reduce_sum_2[0][0]']
#
#  stack4_block2_attn_mhsa_output  (None, 4, 16, 384)  147840      ['tf.math.multiply_2[0][0]']
#  conv (Conv2D)
#
#  stack4_block2_attn_out (Add)   (None, 4, 16, 384)   0           ['tf.reshape_8[0][0]',
#                                                                   'stack4_block2_attn_mhsa_outputc
#                                                                  onv[0][0]']
#
#  stack4_block2_mlp_group_norm (  (None, 4, 16, 384)  768         ['stack4_block2_attn_out[0][0]']
#  GroupNormalization)
#
#  reshape_5 (Reshape)            (None, 4, 16, 384)   0           ['stack4_block2_mlp_group_norm[0]
#                                                                  [0]']
#
#  stack4_block2_mlp_Conv_0 (Conv  (None, 4, 16, 768)  295680      ['reshape_5[0][0]']
#  2D)
#
#  stack4_block2_mlp_swish (Activ  (None, 4, 16, 768)  0           ['stack4_block2_mlp_Conv_0[0][0]'
#  ation)                                                          ]
#
#  stack4_block2_mlp_Conv_1 (Conv  (None, 4, 16, 384)  295296      ['stack4_block2_mlp_swish[0][0]']
#  2D)
#
#  stack4_block2_out (Add)        (None, 4, 16, 384)   0           ['stack4_block2_attn_out[0][0]',
#                                                                   'stack4_block2_mlp_Conv_1[0][0]'
#                                                                  ]
#
#  stack4_block3_attn_group_norm   (None, 4, 16, 384)  768         ['stack4_block2_out[0][0]']
#  (GroupNormalization)
#
#  reshape_6 (Reshape)            (None, 4, 16, 384)   0           ['stack4_block3_attn_group_norm[0
#                                                                  ][0]']
#
#  stack4_block3_attn_mhsa_qkv_co  (None, 4, 16, 769)  296065      ['reshape_6[0][0]']
#  nv (Conv2D)
#
#  tf.split_3 (TFOpLambda)        [(None, 4, 16, 1),   0           ['stack4_block3_attn_mhsa_qkv_con
#                                  (None, 4, 16, 384)              v[0][0]']
#                                 , (None, 4, 16, 384
#                                 )]
#
#  stack4_block3_attn_mhsa_attent  (None, 4, 16, 1)    0           ['tf.split_3[0][0]']
#  ion_scores (Softmax)
#
#  multiply_3 (Multiply)          (None, 4, 16, 384)   0           ['tf.split_3[0][1]',
#                                                                   'stack4_block3_attn_mhsa_attenti
#                                                                  on_scores[0][0]']
#
#  tf.nn.relu_3 (TFOpLambda)      (None, 4, 16, 384)   0           ['tf.split_3[0][2]']
#
#  tf.math.reduce_sum_3 (TFOpLamb  (None, 4, 1, 384)   0           ['multiply_3[0][0]']
#  da)
#
#  tf.math.multiply_3 (TFOpLambda  (None, 4, 16, 384)  0           ['tf.nn.relu_3[0][0]',
#  )                                                                'tf.math.reduce_sum_3[0][0]']
#
#  stack4_block3_attn_mhsa_output  (None, 4, 16, 384)  147840      ['tf.math.multiply_3[0][0]']
#  conv (Conv2D)
#
#  stack4_block3_attn_out (Add)   (None, 4, 16, 384)   0           ['stack4_block2_out[0][0]',
#                                                                   'stack4_block3_attn_mhsa_outputc
#                                                                  onv[0][0]']
#
#  stack4_block3_mlp_group_norm (  (None, 4, 16, 384)  768         ['stack4_block3_attn_out[0][0]']
#  GroupNormalization)
#
#  reshape_7 (Reshape)            (None, 4, 16, 384)   0           ['stack4_block3_mlp_group_norm[0]
#                                                                  [0]']
#
#  stack4_block3_mlp_Conv_0 (Conv  (None, 4, 16, 768)  295680      ['reshape_7[0][0]']
#  2D)
#
#  stack4_block3_mlp_swish (Activ  (None, 4, 16, 768)  0           ['stack4_block3_mlp_Conv_0[0][0]'
#  ation)                                                          ]
#
#  stack4_block3_mlp_Conv_1 (Conv  (None, 4, 16, 384)  295296      ['stack4_block3_mlp_swish[0][0]']
#  2D)
#
#  stack4_block3_out (Add)        (None, 4, 16, 384)   0           ['stack4_block3_attn_out[0][0]',
#                                                                   'stack4_block3_mlp_Conv_1[0][0]'
#                                                                  ]
#
#  stack4_block4_attn_group_norm   (None, 4, 16, 384)  768         ['stack4_block3_out[0][0]']
#  (GroupNormalization)
#
#  reshape_8 (Reshape)            (None, 4, 16, 384)   0           ['stack4_block4_attn_group_norm[0
#                                                                  ][0]']
#
#  stack4_block4_attn_mhsa_qkv_co  (None, 4, 16, 769)  296065      ['reshape_8[0][0]']
#  nv (Conv2D)
#
#  tf.split_4 (TFOpLambda)        [(None, 4, 16, 1),   0           ['stack4_block4_attn_mhsa_qkv_con
#                                  (None, 4, 16, 384)              v[0][0]']
#                                 , (None, 4, 16, 384
#                                 )]
#
#  stack4_block4_attn_mhsa_attent  (None, 4, 16, 1)    0           ['tf.split_4[0][0]']
#  ion_scores (Softmax)
#
# ...
#
#  stack5_block2_mlp_group_norm (  (None, 4, 4, 512)   1024        ['stack5_block2_attn_out[0][0]']
#  GroupNormalization)
#
#  reshape_13 (Reshape)           (None, 4, 4, 512)    0           ['stack5_block2_mlp_group_norm[0]
#                                                                  [0]']
#
#  stack5_block2_mlp_Conv_0 (Conv  (None, 4, 4, 1024)  525312      ['reshape_13[0][0]']
#  2D)
#
#  stack5_block2_mlp_swish (Activ  (None, 4, 4, 1024)  0           ['stack5_block2_mlp_Conv_0[0][0]'
#  ation)                                                          ]
#
#  stack5_block2_mlp_Conv_1 (Conv  (None, 4, 4, 512)   524800      ['stack5_block2_mlp_swish[0][0]']
#  2D)
#
#  stack5_block2_out (Add)        (None, 4, 4, 512)    0           ['stack5_block2_attn_out[0][0]',
#                                                                   'stack5_block2_mlp_Conv_1[0][0]'
#                                                                  ]
#
#  stack5_block3_attn_group_norm   (None, 4, 4, 512)   1024        ['stack5_block2_out[0][0]']
#  (GroupNormalization)
#
#  reshape_14 (Reshape)           (None, 4, 4, 512)    0           ['stack5_block3_attn_group_norm[0
#                                                                  ][0]']
#
#  stack5_block3_attn_mhsa_qkv_co  (None, 4, 4, 1025)  525825      ['reshape_14[0][0]']
#  nv (Conv2D)
#
#  tf.split_7 (TFOpLambda)        [(None, 4, 4, 1),    0           ['stack5_block3_attn_mhsa_qkv_con
#                                  (None, 4, 4, 512),              v[0][0]']
#                                  (None, 4, 4, 512)]
#
#  stack5_block3_attn_mhsa_attent  (None, 4, 4, 1)     0           ['tf.split_7[0][0]']
#  ion_scores (Softmax)
#
#  multiply_7 (Multiply)          (None, 4, 4, 512)    0           ['tf.split_7[0][1]',
#                                                                   'stack5_block3_attn_mhsa_attenti
#                                                                  on_scores[0][0]']
#
#  tf.nn.relu_7 (TFOpLambda)      (None, 4, 4, 512)    0           ['tf.split_7[0][2]']
#
#  tf.math.reduce_sum_7 (TFOpLamb  (None, 4, 1, 512)   0           ['multiply_7[0][0]']
#  da)
#
#  tf.math.multiply_7 (TFOpLambda  (None, 4, 4, 512)   0           ['tf.nn.relu_7[0][0]',
#  )                                                                'tf.math.reduce_sum_7[0][0]']
#
#  stack5_block3_attn_mhsa_output  (None, 4, 4, 512)   262656      ['tf.math.multiply_7[0][0]']
#  conv (Conv2D)
#
#  stack5_block3_attn_out (Add)   (None, 4, 4, 512)    0           ['stack5_block2_out[0][0]',
#                                                                   'stack5_block3_attn_mhsa_outputc
#                                                                  onv[0][0]']
#
#  stack5_block3_mlp_group_norm (  (None, 4, 4, 512)   1024        ['stack5_block3_attn_out[0][0]']
#  GroupNormalization)
#
#  reshape_15 (Reshape)           (None, 4, 4, 512)    0           ['stack5_block3_mlp_group_norm[0]
#                                                                  [0]']
#
#  stack5_block3_mlp_Conv_0 (Conv  (None, 4, 4, 1024)  525312      ['reshape_15[0][0]']
#  2D)
#
#  stack5_block3_mlp_swish (Activ  (None, 4, 4, 1024)  0           ['stack5_block3_mlp_Conv_0[0][0]'
#  ation)                                                          ]
#
#  stack5_block3_mlp_Conv_1 (Conv  (None, 4, 4, 512)   524800      ['stack5_block3_mlp_swish[0][0]']
#  2D)
#
#  stack5_block3_out (Add)        (None, 4, 4, 512)    0           ['stack5_block3_attn_out[0][0]',
#                                                                   'stack5_block3_mlp_Conv_1[0][0]'
#                                                                  ]
#
#  stack5_block4_attn_group_norm   (None, 4, 4, 512)   1024        ['stack5_block3_out[0][0]']
#  (GroupNormalization)
#
#  reshape_16 (Reshape)           (None, 4, 4, 512)    0           ['stack5_block4_attn_group_norm[0
#                                                                  ][0]']
#
#  stack5_block4_attn_mhsa_qkv_co  (None, 4, 4, 1025)  525825      ['reshape_16[0][0]']
#  nv (Conv2D)
#
#  tf.split_8 (TFOpLambda)        [(None, 4, 4, 1),    0           ['stack5_block4_attn_mhsa_qkv_con
#                                  (None, 4, 4, 512),              v[0][0]']
#                                  (None, 4, 4, 512)]
#
#  stack5_block4_attn_mhsa_attent  (None, 4, 4, 1)     0           ['tf.split_8[0][0]']
#  ion_scores (Softmax)
#
#  multiply_8 (Multiply)          (None, 4, 4, 512)    0           ['tf.split_8[0][1]',
#                                                                   'stack5_block4_attn_mhsa_attenti
#                                                                  on_scores[0][0]']
#
#  tf.nn.relu_8 (TFOpLambda)      (None, 4, 4, 512)    0           ['tf.split_8[0][2]']
#
#  tf.math.reduce_sum_8 (TFOpLamb  (None, 4, 1, 512)   0           ['multiply_8[0][0]']
#  da)
#
#  tf.math.multiply_8 (TFOpLambda  (None, 4, 4, 512)   0           ['tf.nn.relu_8[0][0]',
#  )                                                                'tf.math.reduce_sum_8[0][0]']
#
#  stack5_block4_attn_mhsa_output  (None, 4, 4, 512)   262656      ['tf.math.multiply_8[0][0]']
#  conv (Conv2D)
#
#  stack5_block4_attn_out (Add)   (None, 4, 4, 512)    0           ['stack5_block3_out[0][0]',
#                                                                   'stack5_block4_attn_mhsa_outputc
#                                                                  onv[0][0]']
#
#  stack5_block4_mlp_group_norm (  (None, 4, 4, 512)   1024        ['stack5_block4_attn_out[0][0]']
#  GroupNormalization)
#
#  reshape_17 (Reshape)           (None, 4, 4, 512)    0           ['stack5_block4_mlp_group_norm[0]
#                                                                  [0]']
#
#  stack5_block4_mlp_Conv_0 (Conv  (None, 4, 4, 1024)  525312      ['reshape_17[0][0]']
#  2D)
#
#  stack5_block4_mlp_swish (Activ  (None, 4, 4, 1024)  0           ['stack5_block4_mlp_Conv_0[0][0]'
#  ation)                                                          ]
#
#  stack5_block4_mlp_Conv_1 (Conv  (None, 4, 4, 512)   524800      ['stack5_block4_mlp_swish[0][0]']
#  2D)
#
#  stack5_block4_out (Add)        (None, 4, 4, 512)    0           ['stack5_block4_attn_out[0][0]',
#                                                                   'stack5_block4_mlp_Conv_1[0][0]'
#                                                                  ]
#
#  stack5_block4_post_group_norm   (None, 4, 4, 512)   1024        ['stack5_block4_out[0][0]']
#  (GroupNormalization)
#
#  tf.reshape_15 (TFOpLambda)     (None, 4, 2, 1024)   0           ['stack5_block4_post_group_norm[0
#                                                                  ][0]']
#
#  tf.compat.v1.transpose_10 (TFO  (None, 2, 4, 1024)  0           ['tf.reshape_15[0][0]']
#  pLambda)
#
#  tf.reshape_16 (TFOpLambda)     (None, 2, 2, 512)    0           ['tf.compat.v1.transpose_10[0][0]
#                                                                  ']
#
#  tf.compat.v1.transpose_11 (TFO  (None, 2, 2, 512)   0           ['tf.reshape_16[0][0]']
#  pLambda)
#
#  tf.reshape_17 (TFOpLambda)     (None, 4, 4, 512)    0           ['tf.compat.v1.transpose_11[0][0]
#                                                                  ']
#
#  stack5_block4_post_1_conv (Con  (None, 4, 4, 1024)  524288      ['tf.reshape_17[0][0]']
#  v2D)
#
#  stack5_block4_post_1_bn (Batch  (None, 4, 4, 1024)  4096        ['stack5_block4_post_1_conv[0][0]
#  Normalization)                                                  ']
#
#  stack5_block4_output (Activati  (None, 4, 4, 1024)  0           ['stack5_block4_post_1_bn[0][0]']
#  on)
#
#  avg_pool (GlobalAveragePooling  (None, 1024)        0           ['stack5_block4_output[0][0]']
#  2D)
#
#  predictions (Dense)            (None, 2)            2050        ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 17,457,483
# Trainable params: 17,426,379
# Non-trainable params: 31,104
# __________________________________________________________________________________________________

# %%
epochs = 50
history = model.fit_generator(generator=generator_train, epochs=epochs,steps_per_epoch=steps_per_epoch,
                                  validation_data=generator_test, validation_steps=steps_test,
                                 callbacks= callbacks, class_weight =class_weights)
# Out:
# C:\Users\sakib\AppData\Local\Temp\ipykernel_14140\3578285518.py:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(generator=generator_train, epochs=epochs,steps_per_epoch=steps_per_epoch,
# Epoch 1/50
# 46/45 [==============================] - ETA: 0s - loss: 0.8356 - accuracy: 0.4317 - categorical_accuracy: 0.4317 - auc: 0.4219 - precision: 0.4317 - recall: 0.4317 - true_positives: 158.0000 - true_negatives: 158.0000 - false_positives: 208.0000 - false_negatives: 208.0000 - cohen_kappa: -0.9442 - f1_score: 0.4149
# D:\anaconda\envs\tf_gpu\lib\site-packages\keras\engine\training.py:2034: UserWarning: Metric CohenKappa implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
# D:\anaconda\envs\tf_gpu\lib\site-packages\keras\engine\training.py:2034: UserWarning: Metric F1Score implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
# Epoch 1: val_accuracy improved from -inf to 0.57831, saving model to MobileViT.h5
# 45/45 [==============================] - 24s 222ms/step - loss: 0.8356 - accuracy: 0.4317 - categorical_accuracy: 0.4317 - auc: 0.4219 - precision: 0.4317 - recall: 0.4317 - true_positives: 158.0000 - true_negatives: 158.0000 - false_positives: 208.0000 - false_negatives: 208.0000 - cohen_kappa: -0.9442 - f1_score: 0.4149 - val_loss: 0.6923 - val_accuracy: 0.5783 - val_categorical_accuracy: 0.5783 - val_auc: 0.6168 - val_precision: 0.5783 - val_recall: 0.5783 - val_true_positives: 48.0000 - val_true_negatives: 48.0000 - val_false_positives: 35.0000 - val_false_negatives: 35.0000 - val_cohen_kappa: -0.6534 - val_f1_score: 0.4665 - lr: 2.6000e-06
# Epoch 2/50
# 46/45 [==============================] - ETA: 0s - loss: 0.7113 - accuracy: 0.5191 - categorical_accuracy: 0.5191 - auc: 0.5496 - precision: 0.5191 - recall: 0.5191 - true_positives: 190.0000 - true_negatives: 190.0000 - false_positives: 176.0000 - false_negatives: 176.0000 - cohen_kappa: -0.9442 - f1_score: 0.5049
# Epoch 2: val_accuracy did not improve from 0.57831
# 45/45 [==============================] - 11s 229ms/step - loss: 0.7113 - accuracy: 0.5191 - categorical_accuracy: 0.5191 - auc: 0.5496 - precision: 0.5191 - recall: 0.5191 - true_positives: 190.0000 - true_negatives: 190.0000 - false_positives: 176.0000 - false_negatives: 176.0000 - cohen_kappa: -0.9442 - f1_score: 0.5049 - val_loss: 0.7192 - val_accuracy: 0.5060 - val_categorical_accuracy: 0.5060 - val_auc: 0.5345 - val_precision: 0.5060 - val_recall: 0.5060 - val_true_positives: 42.0000 - val_true_negatives: 42.0000 - val_false_positives: 41.0000 - val_false_negatives: 41.0000 - val_cohen_kappa: -0.7689 - val_f1_score: 0.4318 - lr: 2.6000e-06
# Epoch 3/50
# 46/45 [==============================] - ETA: 0s - loss: 0.7320 - accuracy: 0.5301 - categorical_accuracy: 0.5301 - auc: 0.5286 - precision: 0.5301 - recall: 0.5301 - true_positives: 194.0000 - true_negatives: 194.0000 - false_positives: 172.0000 - false_negatives: 172.0000 - cohen_kappa: -0.9215 - f1_score: 0.5100
# Epoch 3: val_accuracy did not improve from 0.57831
# 45/45 [==============================] - 10s 227ms/step - loss: 0.7320 - accuracy: 0.5301 - categorical_accuracy: 0.5301 - auc: 0.5286 - precision: 0.5301 - recall: 0.5301 - true_positives: 194.0000 - true_negatives: 194.0000 - false_positives: 172.0000 - false_negatives: 172.0000 - cohen_kappa: -0.9215 - f1_score: 0.5100 - val_loss: 0.7033 - val_accuracy: 0.5422 - val_categorical_accuracy: 0.5422 - val_auc: 0.5617 - val_precision: 0.5422 - val_recall: 0.5422 - val_true_positives: 45.0000 - val_true_negatives: 45.0000 - val_false_positives: 38.0000 - val_false_negatives: 38.0000 - val_cohen_kappa: -0.7824 - val_f1_score: 0.4785 - lr: 2.6000e-06
# Epoch 4/50
# 46/45 [==============================] - ETA: 0s - loss: 0.7112 - accuracy: 0.5410 - categorical_accuracy: 0.5410 - auc: 0.5681 - precision: 0.5410 - recall: 0.5410 - true_positives: 198.0000 - true_negatives: 198.0000 - false_positives: 168.0000 - false_negatives: 168.0000 - cohen_kappa: -0.9333 - f1_score: 0.5246
# Epoch 4: val_accuracy improved from 0.57831 to 0.60241, saving model to MobileViT.h5
# 45/45 [==============================] - 11s 238ms/step - loss: 0.7112 - accuracy: 0.5410 - categorical_accuracy: 0.5410 - auc: 0.5681 - precision: 0.5410 - recall: 0.5410 - true_positives: 198.0000 - true_negatives: 198.0000 - false_positives: 168.0000 - false_negatives: 168.0000 - cohen_kappa: -0.9333 - f1_score: 0.5246 - val_loss: 0.6475 - val_accuracy: 0.6024 - val_categorical_accuracy: 0.6024 - val_auc: 0.6489 - val_precision: 0.6024 - val_recall: 0.6024 - val_true_positives: 50.0000 - val_true_negatives: 50.0000 - val_false_positives: 33.0000 - val_false_negatives: 33.0000 - val_cohen_kappa: -0.7126 - val_f1_score: 0.5222 - lr: 2.6000e-06
# Epoch 5/50
# 46/45 [==============================] - ETA: 0s - loss: 0.6165 - accuracy: 0.6311 - categorical_accuracy: 0.6311 - auc: 0.7181 - precision: 0.6311 - recall: 0.6311 - true_positives: 231.0000 - true_negatives: 231.0000 - false_positives: 135.0000 - false_negatives: 135.0000 - cohen_kappa: -0.9676 - f1_score: 0.6250
# Epoch 5: val_accuracy improved from 0.60241 to 0.61446, saving model to MobileViT.h5
# 45/45 [==============================] - 11s 242ms/step - loss: 0.6165 - accuracy: 0.6311 - categorical_accuracy: 0.6311 - auc: 0.7181 - precision: 0.6311 - recall: 0.6311 - true_positives: 231.0000 - true_negatives: 231.0000 - false_positives: 135.0000 - false_negatives: 135.0000 - cohen_kappa: -0.9676 - f1_score: 0.6250 - val_loss: 0.6597 - val_accuracy: 0.6145 - val_categorical_accuracy: 0.6145 - val_auc: 0.6452 - val_precision: 0.6145 - val_recall: 0.6145 - val_true_positives: 51.0000 - val_true_negatives: 51.0000 - val_false_positives: 32.0000 - val_false_negatives: 32.0000 - val_cohen_kappa: -0.8336 - val_f1_score: 0.5760 - lr: 2.6000e-06
# Epoch 6/50
# 46/45 [==============================] - ETA: 0s - loss: 0.6440 - accuracy: 0.6230 - categorical_accuracy: 0.6230 - auc: 0.6673 - precision: 0.6230 - recall: 0.6230 - true_positives: 228.0000 - true_negatives: 228.0000 - false_positives: 138.0000 - false_negatives: 138.0000 - cohen_kappa: -0.9442 - f1_score: 0.6118
# Epoch 6: val_accuracy improved from 0.61446 to 0.65060, saving model to MobileViT.h5
# 45/45 [==============================] - 11s 239ms/step - loss: 0.6440 - accuracy: 0.6230 - categorical_accuracy: 0.6230 - auc: 0.6673 - precision: 0.6230 - recall: 0.6230 - true_positives: 228.0000 - true_negatives: 228.0000 - false_positives: 138.0000 - false_negatives: 138.0000 - cohen_kappa: -0.9442 - f1_score: 0.6118 - val_loss: 0.6453 - val_accuracy: 0.6506 - val_categorical_accuracy: 0.6506 - val_auc: 0.6792 - val_precision: 0.6506 - val_recall: 0.6506 - val_true_positives: 54.0000 - val_true_negatives: 54.0000 - val_false_positives: 29.0000 - val_false_negatives: 29.0000 - val_cohen_kappa: -0.8213 - val_f1_score: 0.6126 - lr: 2.6000e-06
# Epoch 7/50
# 46/45 [==============================] - ETA: 0s - loss: 0.6361 - accuracy: 0.6175 - categorical_accuracy: 0.6175 - auc: 0.6849 - precision: 0.6175 - recall: 0.6175 - true_positives: 226.0000 - true_negatives: 226.0000 - false_positives: 140.0000 - false_negatives: 140.0000 - cohen_kappa: -0.9662 - f1_score: 0.6108
# Epoch 7: val_accuracy improved from 0.65060 to 0.68675, saving model to MobileViT.h5
# 45/45 [==============================] - 11s 241ms/step - loss: 0.6361 - accuracy: 0.6175 - categorical_accuracy: 0.6175 - auc: 0.6849 - precision: 0.6175 - recall: 0.6175 - true_positives: 226.0000 - true_negatives: 226.0000 - false_positives: 140.0000 - false_negatives: 140.0000 - cohen_kappa: -0.9662 - f1_score: 0.6108 - val_loss: 0.6375 - val_accuracy: 0.6867 - val_categorical_accuracy: 0.6867 - val_auc: 0.6928 - val_precision: 0.6867 - val_recall: 0.6867 - val_true_positives: 57.0000 - val_true_negatives: 57.0000 - val_false_positives: 26.0000 - val_false_negatives: 26.0000 - val_cohen_kappa: -0.8797 - val_f1_score: 0.6653 - lr: 2.6000e-06
# Epoch 8/50
# 46/45 [==============================] - ETA: 0s - loss: 0.6276 - accuracy: 0.6612 - categorical_accuracy: 0.6612 - auc: 0.7068 - precision: 0.6612 - recall: 0.6612 - true_positives: 242.0000 - true_negatives: 242.0000 - false_positives: 124.0000 - false_negatives: 124.0000 - cohen_kappa: -0.9255 - f1_score: 0.6476
# Epoch 8: val_accuracy did not improve from 0.68675
# 45/45 [==============================] - 11s 232ms/step - loss: 0.6276 - accuracy: 0.6612 - categorical_accuracy: 0.6612 - auc: 0.7068 - precision: 0.6612 - recall: 0.6612 - true_positives: 242.0000 - true_negatives: 242.0000 - false_positives: 124.0000 - false_negatives: 124.0000 - cohen_kappa: -0.9255 - f1_score: 0.6476 - val_loss: 0.5919 - val_accuracy: 0.6506 - val_categorical_accuracy: 0.6506 - val_auc: 0.7577 - val_precision: 0.6506 - val_recall: 0.6506 - val_true_positives: 54.0000 - val_true_negatives: 54.0000 - val_false_positives: 29.0000 - val_false_negatives: 29.0000 - val_cohen_kappa: -0.8687 - val_f1_score: 0.6242 - lr: 2.6000e-06
# Epoch 9/50
# 46/45 [==============================] - ETA: 0s - loss: 0.6093 - accuracy: 0.6475 - categorical_accuracy: 0.6475 - auc: 0.7228 - precision: 0.6475 - recall: 0.6475 - true_positives: 237.0000 - true_negatives: 237.0000 - false_positives: 129.0000 - false_negatives: 129.0000 - cohen_kappa: -0.9424 - f1_score: 0.6368
# Epoch 9: val_accuracy did not improve from 0.68675
# 45/45 [==============================] - 11s 226ms/step - loss: 0.6093 - accuracy: 0.6475 - categorical_accuracy: 0.6475 - auc: 0.7228 - precision: 0.6475 - recall: 0.6475 - true_positives: 237.0000 - true_negatives: 237.0000 - false_positives: 129.0000 - false_negatives: 129.0000 - cohen_kappa: -0.9424 - f1_score: 0.6368 - val_loss: 0.6161 - val_accuracy: 0.6506 - val_categorical_accuracy: 0.6506 - val_auc: 0.7307 - val_precision: 0.6506 - val_recall: 0.6506 - val_true_positives: 54.0000 - val_true_negatives: 54.0000 - val_false_positives: 29.0000 - val_false_negatives: 29.0000 - val_cohen_kappa: -0.9447 - val_f1_score: 0.6404 - lr: 2.6000e-06
# Epoch 10/50
# 46/45 [==============================] - ETA: 0s - loss: 0.5743 - accuracy: 0.7022 - categorical_accuracy: 0.7022 - auc: 0.7756 - precision: 0.7022 - recall: 0.7022 - true_positives: 257.0000 - true_negatives: 257.0000 - false_positives: 109.0000 - false_negatives: 109.0000 - cohen_kappa: -0.9275 - f1_score: 0.6905
# Epoch 10: val_accuracy improved from 0.68675 to 0.72289, saving model to MobileViT.h5
# 45/45 [==============================] - 11s 240ms/step - loss: 0.5743 - accuracy: 0.7022 - categorical_accuracy: 0.7022 - auc: 0.7756 - precision: 0.7022 - recall: 0.7022 - true_positives: 257.0000 - true_negatives: 257.0000 - false_positives: 109.0000 - false_negatives: 109.0000 - cohen_kappa: -0.9275 - f1_score: 0.6905 - val_loss: 0.5789 - val_accuracy: 0.7229 - val_categorical_accuracy: 0.7229 - val_auc: 0.7794 - val_precision: 0.7229 - val_recall: 0.7229 - val_true_positives: 60.0000 - val_true_negatives: 60.0000 - val_false_positives: 23.0000 - val_false_negatives: 23.0000 - val_cohen_kappa: -0.9102 - val_f1_score: 0.7092 - lr: 2.6000e-06
# Epoch 11/50
# 46/45 [==============================] - ETA: 0s - loss: 0.5752 - accuracy: 0.7240 - categorical_accuracy: 0.7240 - auc: 0.7761 - precision: 0.7240 - recall: 0.7240 - true_positives: 265.0000 - true_negatives: 265.0000 - false_positives: 101.0000 - false_negatives: 101.0000 - cohen_kappa: -0.9022 - f1_score: 0.7091
# Epoch 11: val_accuracy did not improve from 0.72289
# 45/45 [==============================] - 11s 231ms/step - loss: 0.5752 - accuracy: 0.7240 - categorical_accuracy: 0.7240 - auc: 0.7761 - precision: 0.7240 - recall: 0.7240 - true_positives: 265.0000 - true_negatives: 265.0000 - false_positives: 101.0000 - false_negatives: 101.0000 - cohen_kappa: -0.9022 - f1_score: 0.7091 - val_loss: 0.6057 - val_accuracy: 0.6747 - val_categorical_accuracy: 0.6747 - val_auc: 0.7383 - val_precision: 0.6747 - val_recall: 0.6747 - val_true_positives: 56.0000 - val_true_negatives: 56.0000 - val_false_positives: 27.0000 - val_false_negatives: 27.0000 - val_cohen_kappa: -0.9591 - val_f1_score: 0.6678 - lr: 2.6000e-06
# Epoch 12/50
# 46/45 [==============================] - ETA: 0s - loss: 0.5561 - accuracy: 0.6885 - categorical_accuracy: 0.6885 - auc: 0.7883 - precision: 0.6885 - recall: 0.6885 - true_positives: 252.0000 - true_negatives: 252.0000 - false_positives: 114.0000 - false_negatives: 114.0000 - cohen_kappa: -0.9542 - f1_score: 0.6811
# Epoch 12: val_accuracy improved from 0.72289 to 0.77108, saving model to MobileViT.h5
# 45/45 [==============================] - 11s 245ms/step - loss: 0.5561 - accuracy: 0.6885 - categorical_accuracy: 0.6885 - auc: 0.7883 - precision: 0.6885 - recall: 0.6885 - true_positives: 252.0000 - true_negatives: 252.0000 - false_positives: 114.0000 - false_negatives: 114.0000 - cohen_kappa: -0.9542 - f1_score: 0.6811 - val_loss: 0.5393 - val_accuracy: 0.7711 - val_categorical_accuracy: 0.7711 - val_auc: 0.8285 - val_precision: 0.7711 - val_recall: 0.7711 - val_true_positives: 64.0000 - val_true_negatives: 64.0000 - val_false_positives: 19.0000 - val_false_negatives: 19.0000 - val_cohen_kappa: -0.9102 - val_f1_score: 0.7598 - lr: 2.6000e-06
# Epoch 13/50
# 46/45 [==============================] - ETA: 0s - loss: 0.5505 - accuracy: 0.6967 - categorical_accuracy: 0.6967 - auc: 0.7918 - precision: 0.6967 - recall: 0.6967 - true_positives: 255.0000 - true_negatives: 255.0000 - false_positives: 111.0000 - false_negatives: 111.0000 - cohen_kappa: -0.9526 - f1_score: 0.6892
# Epoch 13: val_accuracy did not improve from 0.77108
# 45/45 [==============================] - 11s 232ms/step - loss: 0.5505 - accuracy: 0.6967 - categorical_accuracy: 0.6967 - auc: 0.7918 - precision: 0.6967 - recall: 0.6967 - true_positives: 255.0000 - true_negatives: 255.0000 - false_positives: 111.0000 - false_negatives: 111.0000 - cohen_kappa: -0.9526 - f1_score: 0.6892 - val_loss: 0.5604 - val_accuracy: 0.7470 - val_categorical_accuracy: 0.7470 - val_auc: 0.8024 - val_precision: 0.7470 - val_recall: 0.7470 - val_true_positives: 62.0000 - val_true_negatives: 62.0000 - val_false_positives: 21.0000 - val_false_negatives: 21.0000 - val_cohen_kappa: -0.9283 - val_f1_score: 0.7372 - lr: 2.6000e-06
# Epoch 14/50
# 46/45 [==============================] - ETA: 0s - loss: 0.5446 - accuracy: 0.7077 - categorical_accuracy: 0.7077 - auc: 0.7952 - precision: 0.7077 - recall: 0.7077 - true_positives: 259.0000 - true_negatives: 259.0000 - false_positives: 107.0000 - false_negatives: 107.0000 - cohen_kappa: -0.9619 - f1_score: 0.7019
# Epoch 14: val_accuracy did not improve from 0.77108
# 45/45 [==============================] - 11s 236ms/step - loss: 0.5446 - accuracy: 0.7077 - categorical_accuracy: 0.7077 - auc: 0.7952 - precision: 0.7077 - recall: 0.7077 - true_positives: 259.0000 - true_negatives: 259.0000 - false_positives: 107.0000 - false_negatives: 107.0000 - cohen_kappa: -0.9619 - f1_score: 0.7019 - val_loss: 0.5264 - val_accuracy: 0.7470 - val_categorical_accuracy: 0.7470 - val_auc: 0.8346 - val_precision: 0.7470 - val_recall: 0.7470 - val_true_positives: 62.0000 - val_true_negatives: 62.0000 - val_false_positives: 21.0000 - val_false_negatives: 21.0000 - val_cohen_kappa: -0.9591 - val_f1_score: 0.7416 - lr: 2.6000e-06
# Epoch 15/50
# 46/45 [==============================] - ETA: 0s - loss: 0.5070 - accuracy: 0.7486 - categorical_accuracy: 0.7486 - auc: 0.8361 - precision: 0.7486 - recall: 0.7486 - true_positives: 274.0000 - true_negatives: 274.0000 - false_positives: 92.0000 - false_negatives: 92.0000 - cohen_kappa: -0.9604 - f1_score: 0.7435
# Epoch 15: val_accuracy did not improve from 0.77108
# 45/45 [==============================] - 11s 236ms/step - loss: 0.5070 - accuracy: 0.7486 - categorical_accuracy: 0.7486 - auc: 0.8361 - precision: 0.7486 - recall: 0.7486 - true_positives: 274.0000 - true_negatives: 274.0000 - false_positives: 92.0000 - false_negatives: 92.0000 - cohen_kappa: -0.9604 - f1_score: 0.7435 - val_loss: 0.5363 - val_accuracy: 0.7470 - val_categorical_accuracy: 0.7470 - val_auc: 0.8196 - val_precision: 0.7470 - val_recall: 0.7470 - val_true_positives: 62.0000 - val_true_negatives: 62.0000 - val_false_positives: 21.0000 - val_false_negatives: 21.0000 - val_cohen_kappa: -0.9447 - val_f1_score: 0.7396 - lr: 2.6000e-06
# Epoch 16/50
# 46/45 [==============================] - ETA: 0s - loss: 0.4848 - accuracy: 0.7514 - categorical_accuracy: 0.7514 - auc: 0.8507 - precision: 0.7514 - recall: 0.7514 - true_positives: 275.0000 - true_negatives: 275.0000 - false_positives: 91.0000 - false_negatives: 91.0000 - cohen_kappa: -0.9526 - f1_score: 0.7452
# Epoch 16: val_accuracy did not improve from 0.77108
# 45/45 [==============================] - 11s 239ms/step - loss: 0.4848 - accuracy: 0.7514 - categorical_accuracy: 0.7514 - auc: 0.8507 - precision: 0.7514 - recall: 0.7514 - true_positives: 275.0000 - true_negatives: 275.0000 - false_positives: 91.0000 - false_negatives: 91.0000 - cohen_kappa: -0.9526 - f1_score: 0.7452 - val_loss: 0.5454 - val_accuracy: 0.7470 - val_categorical_accuracy: 0.7470 - val_auc: 0.8129 - val_precision: 0.7470 - val_recall: 0.7470 - val_true_positives: 62.0000 - val_true_negatives: 62.0000 - val_false_positives: 21.0000 - val_false_negatives: 21.0000 - val_cohen_kappa: -0.9447 - val_f1_score: 0.7396 - lr: 2.6000e-06
# Epoch 17/50
# 46/45 [==============================] - ETA: 0s - loss: 0.5088 - accuracy: 0.7486 - categorical_accuracy: 0.7486 - auc: 0.8219 - precision: 0.7486 - recall: 0.7486 - true_positives: 274.0000 - true_negatives: 274.0000 - false_positives: 92.0000 - false_negatives: 92.0000 - cohen_kappa: -0.9662 - f1_score: 0.7442
# Epoch 17: val_accuracy improved from 0.77108 to 0.78313, saving model to MobileViT.h5
# 45/45 [==============================] - 11s 244ms/step - loss: 0.5088 - accuracy: 0.7486 - categorical_accuracy: 0.7486 - auc: 0.8219 - precision: 0.7486 - recall: 0.7486 - true_positives: 274.0000 - true_negatives: 274.0000 - false_positives: 92.0000 - false_negatives: 92.0000 - cohen_kappa: -0.9662 - f1_score: 0.7442 - val_loss: 0.4912 - val_accuracy: 0.7831 - val_categorical_accuracy: 0.7831 - val_auc: 0.8747 - val_precision: 0.7831 - val_recall: 0.7831 - val_true_positives: 65.0000 - val_true_negatives: 65.0000 - val_false_positives: 18.0000 - val_false_negatives: 18.0000 - val_cohen_kappa: -0.9367 - val_f1_score: 0.7758 - lr: 2.6000e-06
# Epoch 18/50
# 46/45 [==============================] - ETA: 0s - loss: 0.4713 - accuracy: 0.7732 - categorical_accuracy: 0.7732 - auc: 0.8650 - precision: 0.7732 - recall: 0.7732 - true_positives: 283.0000 - true_negatives: 283.0000 - false_positives: 83.0000 - false_negatives: 83.0000 - cohen_kappa: -0.9459 - f1_score: 0.7667
# Epoch 18: val_accuracy did not improve from 0.78313
# 45/45 [==============================] - 11s 233ms/step - loss: 0.4713 - accuracy: 0.7732 - categorical_accuracy: 0.7732 - auc: 0.8650 - precision: 0.7732 - recall: 0.7732 - true_positives: 283.0000 - true_negatives: 283.0000 - false_positives: 83.0000 - false_negatives: 83.0000 - cohen_kappa: -0.9459 - f1_score: 0.7667 - val_loss: 0.5335 - val_accuracy: 0.7470 - val_categorical_accuracy: 0.7470 - val_auc: 0.8200 - val_precision: 0.7470 - val_recall: 0.7470 - val_true_positives: 62.0000 - val_true_negatives: 62.0000 - val_false_positives: 21.0000 - val_false_negatives: 21.0000 - val_cohen_kappa: -0.9591 - val_f1_score: 0.7416 - lr: 2.6000e-06
# Epoch 19/50
# 46/45 [==============================] - ETA: 0s - loss: 0.4762 - accuracy: 0.7623 - categorical_accuracy: 0.7623 - auc: 0.8584 - precision: 0.7623 - recall: 0.7623 - true_positives: 279.0000 - true_negatives: 279.0000 - false_positives: 87.0000 - false_negatives: 87.0000 - cohen_kappa: -0.9676 - f1_score: 0.7583
# Epoch 19: val_accuracy did not improve from 0.78313
# 45/45 [==============================] - 11s 234ms/step - loss: 0.4762 - accuracy: 0.7623 - categorical_accuracy: 0.7623 - auc: 0.8584 - precision: 0.7623 - recall: 0.7623 - true_positives: 279.0000 - true_negatives: 279.0000 - false_positives: 87.0000 - false_negatives: 87.0000 - cohen_kappa: -0.9676 - f1_score: 0.7583 - val_loss: 0.5447 - val_accuracy: 0.7229 - val_categorical_accuracy: 0.7229 - val_auc: 0.7988 - val_precision: 0.7229 - val_recall: 0.7229 - val_true_positives: 60.0000 - val_true_negatives: 60.0000 - val_false_positives: 23.0000 - val_false_negatives: 23.0000 - val_cohen_kappa: -0.9896 - val_f1_score: 0.7214 - lr: 2.6000e-06
# Epoch 20/50
# 46/45 [==============================] - ETA: 0s - loss: 0.4477 - accuracy: 0.7814 - categorical_accuracy: 0.7814 - auc: 0.8771 - precision: 0.7814 - recall: 0.7814 - true_positives: 286.0000 - true_negatives: 286.0000 - false_positives: 80.0000 - false_negatives: 80.0000 - cohen_kappa: -0.9574 - f1_score: 0.7766
# Epoch 20: val_accuracy did not improve from 0.78313
# 45/45 [==============================] - 11s 238ms/step - loss: 0.4477 - accuracy: 0.7814 - categorical_accuracy: 0.7814 - auc: 0.8771 - precision: 0.7814 - recall: 0.7814 - true_positives: 286.0000 - true_negatives: 286.0000 - false_positives: 80.0000 - false_negatives: 80.0000 - cohen_kappa: -0.9574 - f1_score: 0.7766 - val_loss: 0.4889 - val_accuracy: 0.7711 - val_categorical_accuracy: 0.7711 - val_auc: 0.8700 - val_precision: 0.7711 - val_recall: 0.7711 - val_true_positives: 64.0000 - val_true_negatives: 64.0000 - val_false_positives: 19.0000 - val_false_negatives: 19.0000 - val_cohen_kappa: -0.9591 - val_f1_score: 0.7662 - lr: 2.6000e-06
# Epoch 21/50
# 46/45 [==============================] - ETA: 0s - loss: 0.5094 - accuracy: 0.7459 - categorical_accuracy: 0.7459 - auc: 0.8204 - precision: 0.7459 - recall: 0.7459 - true_positives: 273.0000 - true_negatives: 273.0000 - false_positives: 93.0000 - false_negatives: 93.0000 - cohen_kappa: -0.9314 - f1_score: 0.7365
# Epoch 21: val_accuracy improved from 0.78313 to 0.80723, saving model to MobileViT.h5
# 45/45 [==============================] - 11s 246ms/step - loss: 0.5094 - accuracy: 0.7459 - categorical_accuracy: 0.7459 - auc: 0.8204 - precision: 0.7459 - recall: 0.7459 - true_positives: 273.0000 - true_negatives: 273.0000 - false_positives: 93.0000 - false_negatives: 93.0000 - cohen_kappa: -0.9314 - f1_score: 0.7365 - val_loss: 0.4790 - val_accuracy: 0.8072 - val_categorical_accuracy: 0.8072 - val_auc: 0.8691 - val_precision: 0.8072 - val_recall: 0.8072 - val_true_positives: 67.0000 - val_true_negatives: 67.0000 - val_false_positives: 16.0000 - val_false_negatives: 16.0000 - val_cohen_kappa: -0.9367 - val_f1_score: 0.8007 - lr: 2.6000e-06
# Epoch 22/50
# 46/45 [==============================] - ETA: 0s - loss: 0.4612 - accuracy: 0.7814 - categorical_accuracy: 0.7814 - auc: 0.8587 - precision: 0.7814 - recall: 0.7814 - true_positives: 286.0000 - true_negatives: 286.0000 - false_positives: 80.0000 - false_negatives: 80.0000 - cohen_kappa: -0.9689 - f1_score: 0.7779
# Epoch 22: val_accuracy did not improve from 0.80723
# 45/45 [==============================] - 11s 233ms/step - loss: 0.4612 - accuracy: 0.7814 - categorical_accuracy: 0.7814 - auc: 0.8587 - precision: 0.7814 - recall: 0.7814 - true_positives: 286.0000 - true_negatives: 286.0000 - false_positives: 80.0000 - false_negatives: 80.0000 - cohen_kappa: -0.9689 - f1_score: 0.7779 - val_loss: 0.4830 - val_accuracy: 0.7831 - val_categorical_accuracy: 0.7831 - val_auc: 0.8684 - val_precision: 0.7831 - val_recall: 0.7831 - val_true_positives: 65.0000 - val_true_negatives: 65.0000 - val_false_positives: 18.0000 - val_false_negatives: 18.0000 - val_cohen_kappa: -0.9521 - val_f1_score: 0.7777 - lr: 2.6000e-06
# Epoch 23/50
# 46/45 [==============================] - ETA: 0s - loss: 0.4530 - accuracy: 0.7650 - categorical_accuracy: 0.7650 - auc: 0.8596 - precision: 0.7650 - recall: 0.7650 - true_positives: 280.0000 - true_negatives: 280.0000 - false_positives: 86.0000 - false_negatives: 86.0000 - cohen_kappa: -0.9574 - f1_score: 0.7598
# Epoch 23: val_accuracy did not improve from 0.80723
# 45/45 [==============================] - 11s 236ms/step - loss: 0.4530 - accuracy: 0.7650 - categorical_accuracy: 0.7650 - auc: 0.8596 - precision: 0.7650 - recall: 0.7650 - true_positives: 280.0000 - true_negatives: 280.0000 - false_positives: 86.0000 - false_negatives: 86.0000 - cohen_kappa: -0.9574 - f1_score: 0.7598 - val_loss: 0.4977 - val_accuracy: 0.7590 - val_categorical_accuracy: 0.7590 - val_auc: 0.8475 - val_precision: 0.7590 - val_recall: 0.7590 - val_true_positives: 63.0000 - val_true_negatives: 63.0000 - val_false_positives: 20.0000 - val_false_negatives: 20.0000 - val_cohen_kappa: -0.9768 - val_f1_score: 0.7562 - lr: 2.6000e-06
# Epoch 24/50
# 46/45 [==============================] - ETA: 0s - loss: 0.4456 - accuracy: 0.7842 - categorical_accuracy: 0.7842 - auc: 0.8729 - precision: 0.7842 - recall: 0.7842 - true_positives: 287.0000 - true_negatives: 287.0000 - false_positives: 79.0000 - false_negatives: 79.0000 - cohen_kappa: -0.9558 - f1_score: 0.7792
# Epoch 24: val_accuracy did not improve from 0.80723
# 45/45 [==============================] - 11s 236ms/step - loss: 0.4456 - accuracy: 0.7842 - categorical_accuracy: 0.7842 - auc: 0.8729 - precision: 0.7842 - recall: 0.7842 - true_positives: 287.0000 - true_negatives: 287.0000 - false_positives: 79.0000 - false_negatives: 79.0000 - cohen_kappa: -0.9558 - f1_score: 0.7792 - val_loss: 0.4745 - val_accuracy: 0.7711 - val_categorical_accuracy: 0.7711 - val_auc: 0.8676 - val_precision: 0.7711 - val_recall: 0.7711 - val_true_positives: 64.0000 - val_true_negatives: 64.0000 - val_false_positives: 19.0000 - val_false_negatives: 19.0000 - val_cohen_kappa: -0.9714 - val_f1_score: 0.7677 - lr: 2.6000e-06
# Epoch 25/50
# 46/45 [==============================] - ETA: 0s - loss: 0.4318 - accuracy: 0.7732 - categorical_accuracy: 0.7732 - auc: 0.8744 - precision: 0.7732 - recall: 0.7732 - true_positives: 283.0000 - true_negatives: 283.0000 - false_positives: 83.0000 - false_negatives: 83.0000 - cohen_kappa: -0.9648 - f1_score: 0.7691
# Epoch 25: val_accuracy improved from 0.80723 to 0.83133, saving model to MobileViT.h5
# 45/45 [==============================] - 12s 261ms/step - loss: 0.4318 - accuracy: 0.7732 - categorical_accuracy: 0.7732 - auc: 0.8744 - precision: 0.7732 - recall: 0.7732 - true_positives: 283.0000 - true_negatives: 283.0000 - false_positives: 83.0000 - false_negatives: 83.0000 - cohen_kappa: -0.9648 - f1_score: 0.7691 - val_loss: 0.4462 - val_accuracy: 0.8313 - val_categorical_accuracy: 0.8313 - val_auc: 0.8916 - val_precision: 0.8313 - val_recall: 0.8313 - val_true_positives: 69.0000 - val_true_negatives: 69.0000 - val_false_positives: 14.0000 - val_false_negatives: 14.0000 - val_cohen_kappa: -0.9367 - val_f1_score: 0.8256 - lr: 2.6000e-06
# Epoch 26/50
# 46/45 [==============================] - ETA: 0s - loss: 0.4458 - accuracy: 0.7596 - categorical_accuracy: 0.7596 - auc: 0.8616 - precision: 0.7596 - recall: 0.7596 - true_positives: 278.0000 - true_negatives: 278.0000 - false_positives: 88.0000 - false_negatives: 88.0000 - cohen_kappa: -0.9634 - f1_score: 0.7550
# Epoch 26: val_accuracy did not improve from 0.83133
# 45/45 [==============================] - 11s 245ms/step - loss: 0.4458 - accuracy: 0.7596 - categorical_accuracy: 0.7596 - auc: 0.8616 - precision: 0.7596 - recall: 0.7596 - true_positives: 278.0000 - true_negatives: 278.0000 - false_positives: 88.0000 - false_negatives: 88.0000 - cohen_kappa: -0.9634 - f1_score: 0.7550 - val_loss: 0.4697 - val_accuracy: 0.7831 - val_categorical_accuracy: 0.7831 - val_auc: 0.8691 - val_precision: 0.7831 - val_recall: 0.7831 - val_true_positives: 65.0000 - val_true_negatives: 65.0000 - val_false_positives: 18.0000 - val_false_negatives: 18.0000 - val_cohen_kappa: -0.9655 - val_f1_score: 0.7793 - lr: 2.6000e-06
# Epoch 27/50
# 46/45 [==============================] - ETA: 0s - loss: 0.4167 - accuracy: 0.8005 - categorical_accuracy: 0.8005 - auc: 0.8898 - precision: 0.8005 - recall: 0.8005 - true_positives: 293.0000 - true_negatives: 293.0000 - false_positives: 73.0000 - false_negatives: 73.0000 - cohen_kappa: -0.9493 - f1_score: 0.7952
# Epoch 27: val_accuracy did not improve from 0.83133
# 45/45 [==============================] - 11s 236ms/step - loss: 0.4167 - accuracy: 0.8005 - categorical_accuracy: 0.8005 - auc: 0.8898 - precision: 0.8005 - recall: 0.8005 - true_positives: 293.0000 - true_negatives: 293.0000 - false_positives: 73.0000 - false_negatives: 73.0000 - cohen_kappa: -0.9493 - f1_score: 0.7952 - val_loss: 0.4579 - val_accuracy: 0.8193 - val_categorical_accuracy: 0.8193 - val_auc: 0.8870 - val_precision: 0.8193 - val_recall: 0.8193 - val_true_positives: 68.0000 - val_true_negatives: 68.0000 - val_false_positives: 15.0000 - val_false_negatives: 15.0000 - val_cohen_kappa: -0.9283 - val_f1_score: 0.8123 - lr: 2.6000e-06
# Epoch 28/50
# 46/45 [==============================] - ETA: 0s - loss: 0.4229 - accuracy: 0.8060 - categorical_accuracy: 0.8060 - auc: 0.8830 - precision: 0.8060 - recall: 0.8060 - true_positives: 295.0000 - true_negatives: 295.0000 - false_positives: 71.0000 - false_negatives: 71.0000 - cohen_kappa: -0.9352 - f1_score: 0.7993
# Epoch 28: val_accuracy did not improve from 0.83133
# 45/45 [==============================] - 11s 239ms/step - loss: 0.4229 - accuracy: 0.8060 - categorical_accuracy: 0.8060 - auc: 0.8830 - precision: 0.8060 - recall: 0.8060 - true_positives: 295.0000 - true_negatives: 295.0000 - false_positives: 71.0000 - false_negatives: 71.0000 - cohen_kappa: -0.9352 - f1_score: 0.7993 - val_loss: 0.4366 - val_accuracy: 0.8193 - val_categorical_accuracy: 0.8193 - val_auc: 0.8978 - val_precision: 0.8193 - val_recall: 0.8193 - val_true_positives: 68.0000 - val_true_negatives: 68.0000 - val_false_positives: 15.0000 - val_false_negatives: 15.0000 - val_cohen_kappa: -0.9447 - val_f1_score: 0.8140 - lr: 2.6000e-06
# Epoch 29/50
# 46/45 [==============================] - ETA: 0s - loss: 0.4182 - accuracy: 0.7705 - categorical_accuracy: 0.7705 - auc: 0.8777 - precision: 0.7705 - recall: 0.7705 - true_positives: 282.0000 - true_negatives: 282.0000 - false_positives: 84.0000 - false_negatives: 84.0000 - cohen_kappa: -0.9574 - f1_score: 0.7654
# Epoch 29: val_accuracy did not improve from 0.83133
# 45/45 [==============================] - 11s 238ms/step - loss: 0.4182 - accuracy: 0.7705 - categorical_accuracy: 0.7705 - auc: 0.8777 - precision: 0.7705 - recall: 0.7705 - true_positives: 282.0000 - true_negatives: 282.0000 - false_positives: 84.0000 - false_negatives: 84.0000 - cohen_kappa: -0.9574 - f1_score: 0.7654 - val_loss: 0.4155 - val_accuracy: 0.8193 - val_categorical_accuracy: 0.8193 - val_auc: 0.9181 - val_precision: 0.8193 - val_recall: 0.8193 - val_true_positives: 68.0000 - val_true_negatives: 68.0000 - val_false_positives: 15.0000 - val_false_negatives: 15.0000 - val_cohen_kappa: -0.9447 - val_f1_score: 0.8140 - lr: 2.6000e-06
# Epoch 30/50
# 46/45 [==============================] - ETA: 0s - loss: 0.3848 - accuracy: 0.8306 - categorical_accuracy: 0.8306 - auc: 0.9062 - precision: 0.8306 - recall: 0.8306 - true_positives: 304.0000 - true_negatives: 304.0000 - false_positives: 62.0000 - false_negatives: 62.0000 - cohen_kappa: -0.9215 - f1_score: 0.8234
# Epoch 30: val_accuracy did not improve from 0.83133
# 45/45 [==============================] - 11s 237ms/step - loss: 0.3848 - accuracy: 0.8306 - categorical_accuracy: 0.8306 - auc: 0.9062 - precision: 0.8306 - recall: 0.8306 - true_positives: 304.0000 - true_negatives: 304.0000 - false_positives: 62.0000 - false_negatives: 62.0000 - cohen_kappa: -0.9215 - f1_score: 0.8234 - val_loss: 0.4722 - val_accuracy: 0.7711 - val_categorical_accuracy: 0.7711 - val_auc: 0.8585 - val_precision: 0.7711 - val_recall: 0.7711 - val_true_positives: 64.0000 - val_true_negatives: 64.0000 - val_false_positives: 19.0000 - val_false_negatives: 19.0000 - val_cohen_kappa: -0.9714 - val_f1_score: 0.7677 - lr: 2.6000e-06
# Epoch 31/50
# 46/45 [==============================] - ETA: 0s - loss: 0.4471 - accuracy: 0.7678 - categorical_accuracy: 0.7678 - auc: 0.8607 - precision: 0.7678 - recall: 0.7678 - true_positives: 281.0000 - true_negatives: 281.0000 - false_positives: 85.0000 - false_negatives: 85.0000 - cohen_kappa: -0.9493 - f1_score: 0.7616
# Epoch 31: val_accuracy did not improve from 0.83133
# 45/45 [==============================] - 11s 233ms/step - loss: 0.4471 - accuracy: 0.7678 - categorical_accuracy: 0.7678 - auc: 0.8607 - precision: 0.7678 - recall: 0.7678 - true_positives: 281.0000 - true_negatives: 281.0000 - false_positives: 85.0000 - false_negatives: 85.0000 - cohen_kappa: -0.9493 - f1_score: 0.7616 - val_loss: 0.4432 - val_accuracy: 0.8072 - val_categorical_accuracy: 0.8072 - val_auc: 0.8876 - val_precision: 0.8072 - val_recall: 0.8072 - val_true_positives: 67.0000 - val_true_negatives: 67.0000 - val_false_positives: 16.0000 - val_false_negatives: 16.0000 - val_cohen_kappa: -0.9521 - val_f1_score: 0.8024 - lr: 2.6000e-06
# Epoch 32/50
# 46/45 [==============================] - ETA: 0s - loss: 0.4180 - accuracy: 0.7760 - categorical_accuracy: 0.7760 - auc: 0.8743 - precision: 0.7760 - recall: 0.7760 - true_positives: 284.0000 - true_negatives: 284.0000 - false_positives: 82.0000 - false_negatives: 82.0000 - cohen_kappa: -0.9510 - f1_score: 0.7702
# Epoch 32: val_accuracy did not improve from 0.83133
# 45/45 [==============================] - 11s 237ms/step - loss: 0.4180 - accuracy: 0.7760 - categorical_accuracy: 0.7760 - auc: 0.8743 - precision: 0.7760 - recall: 0.7760 - true_positives: 284.0000 - true_negatives: 284.0000 - false_positives: 82.0000 - false_negatives: 82.0000 - cohen_kappa: -0.9510 - f1_score: 0.7702 - val_loss: 0.4570 - val_accuracy: 0.7711 - val_categorical_accuracy: 0.7711 - val_auc: 0.8692 - val_precision: 0.7711 - val_recall: 0.7711 - val_true_positives: 64.0000 - val_true_negatives: 64.0000 - val_false_positives: 19.0000 - val_false_negatives: 19.0000 - val_cohen_kappa: -0.9714 - val_f1_score: 0.7677 - lr: 2.6000e-06
# Epoch 33/50
# 46/45 [==============================] - ETA: 0s - loss: 0.4404 - accuracy: 0.7596 - categorical_accuracy: 0.7596 - auc: 0.8683 - precision: 0.7596 - recall: 0.7596 - true_positives: 278.0000 - true_negatives: 278.0000 - false_positives: 88.0000 - false_negatives: 88.0000 - cohen_kappa: -0.9294 - f1_score: 0.7504
# Epoch 33: val_accuracy did not improve from 0.83133
# 45/45 [==============================] - 11s 239ms/step - loss: 0.4404 - accuracy: 0.7596 - categorical_accuracy: 0.7596 - auc: 0.8683 - precision: 0.7596 - recall: 0.7596 - true_positives: 278.0000 - true_negatives: 278.0000 - false_positives: 88.0000 - false_negatives: 88.0000 - cohen_kappa: -0.9294 - f1_score: 0.7504 - val_loss: 0.4479 - val_accuracy: 0.7711 - val_categorical_accuracy: 0.7711 - val_auc: 0.8761 - val_precision: 0.7711 - val_recall: 0.7711 - val_true_positives: 64.0000 - val_true_negatives: 64.0000 - val_false_positives: 19.0000 - val_false_negatives: 19.0000 - val_cohen_kappa: -0.9714 - val_f1_score: 0.7677 - lr: 2.6000e-06
# Epoch 34/50
# 46/45 [==============================] - ETA: 0s - loss: 0.3787 - accuracy: 0.8005 - categorical_accuracy: 0.8005 - auc: 0.9071 - precision: 0.8005 - recall: 0.8005 - true_positives: 293.0000 - true_negatives: 293.0000 - false_positives: 73.0000 - false_negatives: 73.0000 - cohen_kappa: -0.9619 - f1_score: 0.7966
# Epoch 34: val_accuracy improved from 0.83133 to 0.84337, saving model to MobileViT.h5
# 45/45 [==============================] - 12s 250ms/step - loss: 0.3787 - accuracy: 0.8005 - categorical_accuracy: 0.8005 - auc: 0.9071 - precision: 0.8005 - recall: 0.8005 - true_positives: 293.0000 - true_negatives: 293.0000 - false_positives: 73.0000 - false_negatives: 73.0000 - cohen_kappa: -0.9619 - f1_score: 0.7966 - val_loss: 0.4098 - val_accuracy: 0.8434 - val_categorical_accuracy: 0.8434 - val_auc: 0.9091 - val_precision: 0.8434 - val_recall: 0.8434 - val_true_positives: 70.0000 - val_true_negatives: 70.0000 - val_false_positives: 13.0000 - val_false_negatives: 13.0000 - val_cohen_kappa: -0.9283 - val_f1_score: 0.8373 - lr: 2.6000e-06
# Epoch 35/50
# 46/45 [==============================] - ETA: 0s - loss: 0.4622 - accuracy: 0.7404 - categorical_accuracy: 0.7404 - auc: 0.8435 - precision: 0.7404 - recall: 0.7404 - true_positives: 271.0000 - true_negatives: 271.0000 - false_positives: 95.0000 - false_negatives: 95.0000 - cohen_kappa: -0.9589 - f1_score: 0.7349
# Epoch 35: val_accuracy improved from 0.84337 to 0.89157, saving model to MobileViT.h5
# 45/45 [==============================] - 11s 247ms/step - loss: 0.4622 - accuracy: 0.7404 - categorical_accuracy: 0.7404 - auc: 0.8435 - precision: 0.7404 - recall: 0.7404 - true_positives: 271.0000 - true_negatives: 271.0000 - false_positives: 95.0000 - false_negatives: 95.0000 - cohen_kappa: -0.9589 - f1_score: 0.7349 - val_loss: 0.3546 - val_accuracy: 0.8916 - val_categorical_accuracy: 0.8916 - val_auc: 0.9471 - val_precision: 0.8916 - val_recall: 0.8916 - val_true_positives: 74.0000 - val_true_negatives: 74.0000 - val_false_positives: 9.0000 - val_false_negatives: 9.0000 - val_cohen_kappa: -0.8902 - val_f1_score: 0.8849 - lr: 2.6000e-06
# Epoch 36/50
# 46/45 [==============================] - ETA: 0s - loss: 0.4156 - accuracy: 0.7541 - categorical_accuracy: 0.7541 - auc: 0.8740 - precision: 0.7541 - recall: 0.7541 - true_positives: 276.0000 - true_negatives: 276.0000 - false_positives: 90.0000 - false_negatives: 90.0000 - cohen_kappa: -0.9662 - f1_score: 0.7498
# Epoch 36: val_accuracy did not improve from 0.89157
# 45/45 [==============================] - 11s 238ms/step - loss: 0.4156 - accuracy: 0.7541 - categorical_accuracy: 0.7541 - auc: 0.8740 - precision: 0.7541 - recall: 0.7541 - true_positives: 276.0000 - true_negatives: 276.0000 - false_positives: 90.0000 - false_negatives: 90.0000 - cohen_kappa: -0.9662 - f1_score: 0.7498 - val_loss: 0.4340 - val_accuracy: 0.7952 - val_categorical_accuracy: 0.7952 - val_auc: 0.8837 - val_precision: 0.7952 - val_recall: 0.7952 - val_true_positives: 66.0000 - val_true_negatives: 66.0000 - val_false_positives: 17.0000 - val_false_negatives: 17.0000 - val_cohen_kappa: -0.9591 - val_f1_score: 0.7908 - lr: 2.6000e-06
# Epoch 37/50
# 46/45 [==============================] - ETA: 0s - loss: 0.3762 - accuracy: 0.8060 - categorical_accuracy: 0.8060 - auc: 0.9035 - precision: 0.8060 - recall: 0.8060 - true_positives: 295.0000 - true_negatives: 295.0000 - false_positives: 71.0000 - false_negatives: 71.0000 - cohen_kappa: -0.9424 - f1_score: 0.8001
# Epoch 37: val_accuracy did not improve from 0.89157
# 45/45 [==============================] - 11s 235ms/step - loss: 0.3762 - accuracy: 0.8060 - categorical_accuracy: 0.8060 - auc: 0.9035 - precision: 0.8060 - recall: 0.8060 - true_positives: 295.0000 - true_negatives: 295.0000 - false_positives: 71.0000 - false_negatives: 71.0000 - cohen_kappa: -0.9424 - f1_score: 0.8001 - val_loss: 0.4141 - val_accuracy: 0.8193 - val_categorical_accuracy: 0.8193 - val_auc: 0.8989 - val_precision: 0.8193 - val_recall: 0.8193 - val_true_positives: 68.0000 - val_true_negatives: 68.0000 - val_false_positives: 15.0000 - val_false_negatives: 15.0000 - val_cohen_kappa: -0.9447 - val_f1_score: 0.8140 - lr: 2.6000e-06
# Epoch 38/50
# 46/45 [==============================] - ETA: 0s - loss: 0.3930 - accuracy: 0.7951 - categorical_accuracy: 0.7951 - auc: 0.8925 - precision: 0.7951 - recall: 0.7951 - true_positives: 291.0000 - true_negatives: 291.0000 - false_positives: 75.0000 - false_negatives: 75.0000 - cohen_kappa: -0.9493 - f1_score: 0.7896
# Epoch 38: val_accuracy did not improve from 0.89157
# 45/45 [==============================] - 11s 236ms/step - loss: 0.3930 - accuracy: 0.7951 - categorical_accuracy: 0.7951 - auc: 0.8925 - precision: 0.7951 - recall: 0.7951 - true_positives: 291.0000 - true_negatives: 291.0000 - false_positives: 75.0000 - false_negatives: 75.0000 - cohen_kappa: -0.9493 - f1_score: 0.7896 - val_loss: 0.3906 - val_accuracy: 0.8434 - val_categorical_accuracy: 0.8434 - val_auc: 0.9202 - val_precision: 0.8434 - val_recall: 0.8434 - val_true_positives: 70.0000 - val_true_negatives: 70.0000 - val_false_positives: 13.0000 - val_false_negatives: 13.0000 - val_cohen_kappa: -0.9283 - val_f1_score: 0.8373 - lr: 2.6000e-06
# Epoch 39/50
# 46/45 [==============================] - ETA: 0s - loss: 0.4268 - accuracy: 0.7951 - categorical_accuracy: 0.7951 - auc: 0.8761 - precision: 0.7951 - recall: 0.7951 - true_positives: 291.0000 - true_negatives: 291.0000 - false_positives: 75.0000 - false_negatives: 75.0000 - cohen_kappa: -0.9194 - f1_score: 0.7861
# Epoch 39: val_accuracy did not improve from 0.89157
# 45/45 [==============================] - 11s 237ms/step - loss: 0.4268 - accuracy: 0.7951 - categorical_accuracy: 0.7951 - auc: 0.8761 - precision: 0.7951 - recall: 0.7951 - true_positives: 291.0000 - true_negatives: 291.0000 - false_positives: 75.0000 - false_negatives: 75.0000 - cohen_kappa: -0.9194 - f1_score: 0.7861 - val_loss: 0.4281 - val_accuracy: 0.7831 - val_categorical_accuracy: 0.7831 - val_auc: 0.8872 - val_precision: 0.7831 - val_recall: 0.7831 - val_true_positives: 65.0000 - val_true_negatives: 65.0000 - val_false_positives: 18.0000 - val_false_negatives: 18.0000 - val_cohen_kappa: -0.9655 - val_f1_score: 0.7793 - lr: 2.6000e-06
# Epoch 40/50
# 46/45 [==============================] - ETA: 0s - loss: 0.3702 - accuracy: 0.8197 - categorical_accuracy: 0.8197 - auc: 0.9053 - precision: 0.8197 - recall: 0.8197 - true_positives: 300.0000 - true_negatives: 300.0000 - false_positives: 66.0000 - false_negatives: 66.0000 - cohen_kappa: -0.9510 - f1_score: 0.8150
# Epoch 40: val_accuracy did not improve from 0.89157
# 45/45 [==============================] - 11s 235ms/step - loss: 0.3702 - accuracy: 0.8197 - categorical_accuracy: 0.8197 - auc: 0.9053 - precision: 0.8197 - recall: 0.8197 - true_positives: 300.0000 - true_negatives: 300.0000 - false_positives: 66.0000 - false_negatives: 66.0000 - cohen_kappa: -0.9510 - f1_score: 0.8150 - val_loss: 0.4886 - val_accuracy: 0.7229 - val_categorical_accuracy: 0.7229 - val_auc: 0.8308 - val_precision: 0.7229 - val_recall: 0.7229 - val_true_positives: 60.0000 - val_true_negatives: 60.0000 - val_false_positives: 23.0000 - val_false_negatives: 23.0000 - val_cohen_kappa: -0.9896 - val_f1_score: 0.7214 - lr: 2.6000e-06
# Epoch 41/50
# 46/45 [==============================] - ETA: 0s - loss: 0.3933 - accuracy: 0.7978 - categorical_accuracy: 0.7978 - auc: 0.8921 - precision: 0.7978 - recall: 0.7978 - true_positives: 292.0000 - true_negatives: 292.0000 - false_positives: 74.0000 - false_negatives: 74.0000 - cohen_kappa: -0.9255 - f1_score: 0.7897
# Epoch 41: val_accuracy did not improve from 0.89157
# 45/45 [==============================] - 11s 237ms/step - loss: 0.3933 - accuracy: 0.7978 - categorical_accuracy: 0.7978 - auc: 0.8921 - precision: 0.7978 - recall: 0.7978 - true_positives: 292.0000 - true_negatives: 292.0000 - false_positives: 74.0000 - false_negatives: 74.0000 - cohen_kappa: -0.9255 - f1_score: 0.7897 - val_loss: 0.3924 - val_accuracy: 0.8313 - val_categorical_accuracy: 0.8313 - val_auc: 0.9170 - val_precision: 0.8313 - val_recall: 0.8313 - val_true_positives: 69.0000 - val_true_negatives: 69.0000 - val_false_positives: 14.0000 - val_false_negatives: 14.0000 - val_cohen_kappa: -0.9367 - val_f1_score: 0.8256 - lr: 2.6000e-06
# Epoch 42/50
# 46/45 [==============================] - ETA: 0s - loss: 0.3813 - accuracy: 0.8251 - categorical_accuracy: 0.8251 - auc: 0.9021 - precision: 0.8251 - recall: 0.8251 - true_positives: 302.0000 - true_negatives: 302.0000 - false_positives: 64.0000 - false_negatives: 64.0000 - cohen_kappa: -0.9215 - f1_score: 0.8177
# Epoch 42: val_accuracy did not improve from 0.89157
# 45/45 [==============================] - 11s 240ms/step - loss: 0.3813 - accuracy: 0.8251 - categorical_accuracy: 0.8251 - auc: 0.9021 - precision: 0.8251 - recall: 0.8251 - true_positives: 302.0000 - true_negatives: 302.0000 - false_positives: 64.0000 - false_negatives: 64.0000 - cohen_kappa: -0.9215 - f1_score: 0.8177 - val_loss: 0.4801 - val_accuracy: 0.7590 - val_categorical_accuracy: 0.7590 - val_auc: 0.8473 - val_precision: 0.7590 - val_recall: 0.7590 - val_true_positives: 63.0000 - val_true_negatives: 63.0000 - val_false_positives: 20.0000 - val_false_negatives: 20.0000 - val_cohen_kappa: -0.9768 - val_f1_score: 0.7562 - lr: 2.6000e-06
# Epoch 43/50
# 46/45 [==============================] - ETA: 0s - loss: 0.4092 - accuracy: 0.7869 - categorical_accuracy: 0.7869 - auc: 0.8800 - precision: 0.7869 - recall: 0.7869 - true_positives: 288.0000 - true_negatives: 288.0000 - false_positives: 78.0000 - false_negatives: 78.0000 - cohen_kappa: -0.9477 - f1_score: 0.7810
# Epoch 43: val_accuracy did not improve from 0.89157
# 45/45 [==============================] - 14s 298ms/step - loss: 0.4092 - accuracy: 0.7869 - categorical_accuracy: 0.7869 - auc: 0.8800 - precision: 0.7869 - recall: 0.7869 - true_positives: 288.0000 - true_negatives: 288.0000 - false_positives: 78.0000 - false_negatives: 78.0000 - cohen_kappa: -0.9477 - f1_score: 0.7810 - val_loss: 0.3544 - val_accuracy: 0.8675 - val_categorical_accuracy: 0.8675 - val_auc: 0.9334 - val_precision: 0.8675 - val_recall: 0.8675 - val_true_positives: 72.0000 - val_true_negatives: 72.0000 - val_false_positives: 11.0000 - val_false_negatives: 11.0000 - val_cohen_kappa: -0.9102 - val_f1_score: 0.8609 - lr: 2.6000e-06
# Epoch 44/50
# 46/45 [==============================] - ETA: 0s - loss: 0.4262 - accuracy: 0.7596 - categorical_accuracy: 0.7596 - auc: 0.8654 - precision: 0.7596 - recall: 0.7596 - true_positives: 278.0000 - true_negatives: 278.0000 - false_positives: 88.0000 - false_negatives: 88.0000 - cohen_kappa: -0.9477 - f1_score: 0.7529
# Epoch 44: val_accuracy did not improve from 0.89157
# 45/45 [==============================] - 12s 263ms/step - loss: 0.4262 - accuracy: 0.7596 - categorical_accuracy: 0.7596 - auc: 0.8654 - precision: 0.7596 - recall: 0.7596 - true_positives: 278.0000 - true_negatives: 278.0000 - false_positives: 88.0000 - false_negatives: 88.0000 - cohen_kappa: -0.9477 - f1_score: 0.7529 - val_loss: 0.3612 - val_accuracy: 0.8675 - val_categorical_accuracy: 0.8675 - val_auc: 0.9312 - val_precision: 0.8675 - val_recall: 0.8675 - val_true_positives: 72.0000 - val_true_negatives: 72.0000 - val_false_positives: 11.0000 - val_false_negatives: 11.0000 - val_cohen_kappa: -0.9102 - val_f1_score: 0.8609 - lr: 2.6000e-06
# Epoch 45/50
# 46/45 [==============================] - ETA: 0s - loss: 0.3589 - accuracy: 0.8142 - categorical_accuracy: 0.8142 - auc: 0.9099 - precision: 0.8142 - recall: 0.8142 - true_positives: 298.0000 - true_negatives: 298.0000 - false_positives: 68.0000 - false_negatives: 68.0000 - cohen_kappa: -0.9542 - f1_score: 0.8098
# Epoch 45: val_accuracy did not improve from 0.89157
# 45/45 [==============================] - 11s 240ms/step - loss: 0.3589 - accuracy: 0.8142 - categorical_accuracy: 0.8142 - auc: 0.9099 - precision: 0.8142 - recall: 0.8142 - true_positives: 298.0000 - true_negatives: 298.0000 - false_positives: 68.0000 - false_negatives: 68.0000 - cohen_kappa: -0.9542 - f1_score: 0.8098 - val_loss: 0.3633 - val_accuracy: 0.8554 - val_categorical_accuracy: 0.8554 - val_auc: 0.9318 - val_precision: 0.8554 - val_recall: 0.8554 - val_true_positives: 71.0000 - val_true_negatives: 71.0000 - val_false_positives: 12.0000 - val_false_negatives: 12.0000 - val_cohen_kappa: -0.9195 - val_f1_score: 0.8491 - lr: 2.6000e-06
# Epoch 46/50
# 46/45 [==============================] - ETA: 0s - loss: 0.3732 - accuracy: 0.7951 - categorical_accuracy: 0.7951 - auc: 0.9022 - precision: 0.7951 - recall: 0.7951 - true_positives: 291.0000 - true_negatives: 291.0000 - false_positives: 75.0000 - false_negatives: 75.0000 - cohen_kappa: -0.9424 - f1_score: 0.7888
# Epoch 46: val_accuracy did not improve from 0.89157
# 45/45 [==============================] - 11s 246ms/step - loss: 0.3732 - accuracy: 0.7951 - categorical_accuracy: 0.7951 - auc: 0.9022 - precision: 0.7951 - recall: 0.7951 - true_positives: 291.0000 - true_negatives: 291.0000 - false_positives: 75.0000 - false_negatives: 75.0000 - cohen_kappa: -0.9424 - f1_score: 0.7888 - val_loss: 0.4021 - val_accuracy: 0.8193 - val_categorical_accuracy: 0.8193 - val_auc: 0.9002 - val_precision: 0.8193 - val_recall: 0.8193 - val_true_positives: 68.0000 - val_true_negatives: 68.0000 - val_false_positives: 15.0000 - val_false_negatives: 15.0000 - val_cohen_kappa: -0.9447 - val_f1_score: 0.8140 - lr: 2.6000e-06
# Epoch 47/50
# 46/45 [==============================] - ETA: 0s - loss: 0.3143 - accuracy: 0.8361 - categorical_accuracy: 0.8361 - auc: 0.9358 - precision: 0.8361 - recall: 0.8361 - true_positives: 306.0000 - true_negatives: 306.0000 - false_positives: 60.0000 - false_negatives: 60.0000 - cohen_kappa: -0.9333 - f1_score: 0.8302
# Epoch 47: val_accuracy did not improve from 0.89157
# 45/45 [==============================] - 12s 259ms/step - loss: 0.3143 - accuracy: 0.8361 - categorical_accuracy: 0.8361 - auc: 0.9358 - precision: 0.8361 - recall: 0.8361 - true_positives: 306.0000 - true_negatives: 306.0000 - false_positives: 60.0000 - false_negatives: 60.0000 - cohen_kappa: -0.9333 - f1_score: 0.8302 - val_loss: 0.3924 - val_accuracy: 0.8313 - val_categorical_accuracy: 0.8313 - val_auc: 0.9099 - val_precision: 0.8313 - val_recall: 0.8313 - val_true_positives: 69.0000 - val_true_negatives: 69.0000 - val_false_positives: 14.0000 - val_false_negatives: 14.0000 - val_cohen_kappa: -0.9367 - val_f1_score: 0.8256 - lr: 2.6000e-06
# Epoch 48/50
# 46/45 [==============================] - ETA: 0s - loss: 0.3913 - accuracy: 0.7842 - categorical_accuracy: 0.7842 - auc: 0.8920 - precision: 0.7842 - recall: 0.7842 - true_positives: 287.0000 - true_negatives: 287.0000 - false_positives: 79.0000 - false_negatives: 79.0000 - cohen_kappa: -0.9194 - f1_score: 0.7747
# Epoch 48: val_accuracy did not improve from 0.89157
# 45/45 [==============================] - 13s 288ms/step - loss: 0.3913 - accuracy: 0.7842 - categorical_accuracy: 0.7842 - auc: 0.8920 - precision: 0.7842 - recall: 0.7842 - true_positives: 287.0000 - true_negatives: 287.0000 - false_positives: 79.0000 - false_negatives: 79.0000 - cohen_kappa: -0.9194 - f1_score: 0.7747 - val_loss: 0.3690 - val_accuracy: 0.8554 - val_categorical_accuracy: 0.8554 - val_auc: 0.9225 - val_precision: 0.8554 - val_recall: 0.8554 - val_true_positives: 71.0000 - val_true_negatives: 71.0000 - val_false_positives: 12.0000 - val_false_negatives: 12.0000 - val_cohen_kappa: -0.9195 - val_f1_score: 0.8491 - lr: 2.6000e-06
# Epoch 49/50
# 46/45 [==============================] - ETA: 0s - loss: 0.3755 - accuracy: 0.7923 - categorical_accuracy: 0.7923 - auc: 0.8949 - precision: 0.7923 - recall: 0.7923 - true_positives: 290.0000 - true_negatives: 290.0000 - false_positives: 76.0000 - false_negatives: 76.0000 - cohen_kappa: -0.9662 - f1_score: 0.7887
# Epoch 49: val_accuracy did not improve from 0.89157
# 45/45 [==============================] - 12s 255ms/step - loss: 0.3755 - accuracy: 0.7923 - categorical_accuracy: 0.7923 - auc: 0.8949 - precision: 0.7923 - recall: 0.7923 - true_positives: 290.0000 - true_negatives: 290.0000 - false_positives: 76.0000 - false_negatives: 76.0000 - cohen_kappa: -0.9662 - f1_score: 0.7887 - val_loss: 0.4206 - val_accuracy: 0.8193 - val_categorical_accuracy: 0.8193 - val_auc: 0.8878 - val_precision: 0.8193 - val_recall: 0.8193 - val_true_positives: 68.0000 - val_true_negatives: 68.0000 - val_false_positives: 15.0000 - val_false_negatives: 15.0000 - val_cohen_kappa: -0.9447 - val_f1_score: 0.8140 - lr: 2.6000e-06
# Epoch 50/50
# 46/45 [==============================] - ETA: 0s - loss: 0.3366 - accuracy: 0.8224 - categorical_accuracy: 0.8224 - auc: 0.9187 - precision: 0.8224 - recall: 0.8224 - true_positives: 301.0000 - true_negatives: 301.0000 - false_positives: 65.0000 - false_negatives: 65.0000 - cohen_kappa: -0.9459 - f1_score: 0.8173
# Epoch 50: val_accuracy did not improve from 0.89157
# 45/45 [==============================] - 11s 241ms/step - loss: 0.3366 - accuracy: 0.8224 - categorical_accuracy: 0.8224 - auc: 0.9187 - precision: 0.8224 - recall: 0.8224 - true_positives: 301.0000 - true_negatives: 301.0000 - false_positives: 65.0000 - false_negatives: 65.0000 - cohen_kappa: -0.9459 - f1_score: 0.8173 - val_loss: 0.3558 - val_accuracy: 0.8434 - val_categorical_accuracy: 0.8434 - val_auc: 0.9280 - val_precision: 0.8434 - val_recall: 0.8434 - val_true_positives: 70.0000 - val_true_negatives: 70.0000 - val_false_positives: 13.0000 - val_false_negatives: 13.0000 - val_cohen_kappa: -0.9283 - val_f1_score: 0.8373 - lr: 2.6000e-06

# %%
model = keras.models.load_model(weight)
evaluate_(model, generator_test)
plot_graphs(history, generator_test)
# Out:
# 11/11 [==============================] - 4s 127ms/step - loss: 0.3546 - accuracy: 0.8916 - categorical_accuracy: 0.8916 - auc: 0.9471 - precision: 0.8916 - recall: 0.8916 - true_positives: 74.0000 - true_negatives: 74.0000 - false_positives: 9.0000 - false_negatives: 9.0000 - cohen_kappa: -0.8902 - f1_score: 0.8849
#               precision    recall  f1-score   support
#
#            0       0.75      1.00      0.86        27
#            1       1.00      0.84      0.91        56
#
#     accuracy                           0.89        83
#    macro avg       0.88      0.92      0.88        83
# weighted avg       0.92      0.89      0.89        83
# C:\Users\sakib\AppData\Local\Temp\ipykernel_14140\4210797192.py:76: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   predictions = model.predict_generator(generator_test)
