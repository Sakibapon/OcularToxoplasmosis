# %%
import sys
import os
from math import log
import numpy as np
import seaborn as sns
import pandas as pd
import scipy as sp
from PIL import Image
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_addons as tfa
from tensorflow import keras
from tensorflow.keras import layers
import cv2 as cv
import pickle
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.models import Model
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.utils import compute_class_weight
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import roc_curve, roc_auc_score, auc

np.random.seed(72)
tf.random.set_seed(72)
sess = tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(log_device_placement=True))
# Out:
# C:\Users\HSSL77\anaconda3\envs\tf_gpu_final\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.3.0 and strictly below 2.6.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.8.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
def get_train_test(train_dir, test_dir):
    datagen_train = ImageDataGenerator(rescale=1./255, width_shift_range=0.1, height_shift_range=0.1,
                                      horizontal_flip=True,  vertical_flip=False)
    datagen_test = ImageDataGenerator(rescale=1./255)

    generator_train = datagen_train.flow_from_directory(directory=train_dir, target_size=(image_size, image_size),
                                                        batch_size=batch_size, shuffle=True)
    generator_test = datagen_test.flow_from_directory(directory=test_dir, target_size=(image_size, image_size),
                                                      batch_size=batch_size, shuffle=False)

    num_classes = generator_train.num_classes
    labels = generator_train.classes
    class_weights = compute_class_weight(class_weight="balanced", classes=np.unique(labels), y=labels)
    class_weights = dict(zip(np.unique(labels), class_weights))
    print(class_weights)
    
    steps_per_epoch = generator_train.n / batch_size
    steps_test = generator_test.n / batch_size
    return generator_train, generator_test, labels, class_weights, num_classes, steps_per_epoch, steps_test

def compile_model(model, weight):
    optimizer = Adam(lr=1e-5) 
    loss = 'categorical_crossentropy'

    metrics = ['accuracy', 'categorical_accuracy', tf.keras.metrics.AUC(), tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), 
               tf.keras.metrics.TruePositives(), tf.keras.metrics.TrueNegatives(), tf.keras.metrics.FalsePositives(), 
               tf.keras.metrics.FalseNegatives(), tfa.metrics.CohenKappa(num_classes = num_classes), 
               tfa.metrics.F1Score(num_classes = num_classes)]

    model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

    lr = tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.1,
        patience=9, mode="max", min_delta=0.0001, min_lr=0.00001, verbose=1)
    checkpoint = ModelCheckpoint(filepath=weight, save_best_only=True, monitor = 'val_accuracy', verbose=1)
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=1, restore_best_weights=True)

    callbacks = [lr, checkpoint, early_stopping]
    return model, callbacks

def evaluate_(model, generator_test):
    model.evaluate(generator_test)
    
    y_pred = model.predict(generator_test)
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_true = generator_test.classes
    class_labels = list(generator_test.class_indices.keys())

    print(classification_report(y_true, y_pred_classes))
    cm = confusion_matrix(y_true, y_pred_classes)
    
    # Plotting the confusion matrix
    plt.figure(figsize=(8, 8))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_labels, yticklabels=class_labels)
    plt.show()
    
def plot_graphs(history, generator_test):
    plt.figure(figsize=(15,7))
    plt.plot(history.history['accuracy'], 'r', linewidth=2.5)
    plt.plot(history.history['val_accuracy'], linewidth=2.5)
    plt.title('Model Accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['Training Accuracy', 'Testing Accuracy'], loc='upper left')
    plt.show()

    plt.figure(figsize=(15,7))
    plt.plot(history.history['loss'], 'r', linewidth=2.5)
    plt.plot(history.history['val_loss'], linewidth=2.5)
    plt.title('Model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['Train Loss', 'Test Loss'], loc='upper left')
    plt.show()
    
    # Generate predictions
    predictions = model.predict_generator(generator_test)
    # Get true labels
    true_labels = generator_test.classes
    # Binarize the true labels
    encoder = OneHotEncoder(sparse=False)
    true_labels = encoder.fit_transform(true_labels.reshape(-1, 1))
    # Calculate ROC curve and ROC AUC for each class
    n_classes = true_labels.shape[1]
    fpr = dict()
    tpr = dict()
    roc_auc = dict()

    for class_idx in range(n_classes):
        fpr[class_idx], tpr[class_idx], _ = roc_curve(true_labels[:, class_idx], predictions[:, class_idx])
        roc_auc[class_idx] = auc(fpr[class_idx], tpr[class_idx])

    # Plot ROC curves for each class
    plt.figure(figsize=(12, 12))
    for class_idx in range(n_classes):

        plt.plot(fpr[class_idx], tpr[class_idx], label='ROC curve (area = %0.2f) for class %d' % (roc_auc[class_idx], class_idx),
                linewidth=2.5)

    plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic per Class')
    plt.legend(loc='lower right')
    plt.show()

# %%
# Params
num_classes = 2
batch_size = 8
image_size = 112
weight = 'MaxVIT.h5'

# %%
from keras_cv_attention_models import maxvit
model = maxvit.MaxViT_Tiny(input_shape=(image_size, image_size, 3) , num_classes=num_classes, 
                         drop_connect_rate=0.2, classifier_activation="softmax")
# Out:
# >>>> Load pretrained from: C:\Users\HSSL77\.keras\models\maxvit_tiny_224_imagenet.h5
# WARNING:tensorflow:Skipping loading weights for layer #33 (named stack_1_block_1/block_window_mhsa/pos_emb) due to mismatch in shape for weight stack_1_block_1/block_window_mhsa/pos_emb/positional_embedding:0. Weight expects shape (2, 49). Received saved weight with shape (2, 169)
# WARNING:tensorflow:Skipping loading weights for layer #64 (named stack_1_block_1/grid_window_mhsa/pos_emb) due to mismatch in shape for weight stack_1_block_1/grid_window_mhsa/pos_emb/positional_embedding:0. Weight expects shape (2, 49). Received saved weight with shape (2, 169)
# WARNING:tensorflow:Skipping loading weights for layer #110 (named stack_1_block_2/block_window_mhsa/pos_emb) due to mismatch in shape for weight stack_1_block_2/block_window_mhsa/pos_emb/positional_embedding:0. Weight expects shape (2, 49). Received saved weight with shape (2, 169)
# WARNING:tensorflow:Skipping loading weights for layer #141 (named stack_1_block_2/grid_window_mhsa/pos_emb) due to mismatch in shape for weight stack_1_block_2/grid_window_mhsa/pos_emb/positional_embedding:0. Weight expects shape (2, 49). Received saved weight with shape (2, 169)
# WARNING:tensorflow:Skipping loading weights for layer #189 (named stack_2_block_1/block_window_mhsa/pos_emb) due to mismatch in shape for weight stack_2_block_1/block_window_mhsa/pos_emb/positional_embedding:0. Weight expects shape (4, 49). Received saved weight with shape (4, 169)
# WARNING:tensorflow:Skipping loading weights for layer #220 (named stack_2_block_1/grid_window_mhsa/pos_emb) due to mismatch in shape for weight stack_2_block_1/grid_window_mhsa/pos_emb/positional_embedding:0. Weight expects shape (4, 49). Received saved weight with shape (4, 169)
# WARNING:tensorflow:Skipping loading weights for layer #266 (named stack_2_block_2/block_window_mhsa/pos_emb) due to mismatch in shape for weight stack_2_block_2/block_window_mhsa/pos_emb/positional_embedding:0. Weight expects shape (4, 49). Received saved weight with shape (4, 169)
# WARNING:tensorflow:Skipping loading weights for layer #297 (named stack_2_block_2/grid_window_mhsa/pos_emb) due to mismatch in shape for weight stack_2_block_2/grid_window_mhsa/pos_emb/positional_embedding:0. Weight expects shape (4, 49). Received saved weight with shape (4, 169)
# WARNING:tensorflow:Skipping loading weights for layer #345 (named stack_3_block_1/block_window_mhsa/pos_emb) due to mismatch in shape for weight stack_3_block_1/block_window_mhsa/pos_emb/positional_embedding:0. Weight expects shape (8, 49). Received saved weight with shape (8, 169)
# WARNING:tensorflow:Skipping loading weights for layer #376 (named stack_3_block_1/grid_window_mhsa/pos_emb) due to mismatch in shape for weight stack_3_block_1/grid_window_mhsa/pos_emb/positional_embedding:0. Weight expects shape (8, 49). Received saved weight with shape (8, 169)
# WARNING:tensorflow:Skipping loading weights for layer #422 (named stack_3_block_2/block_window_mhsa/pos_emb) due to mismatch in shape for weight stack_3_block_2/block_window_mhsa/pos_emb/positional_embedding:0. Weight expects shape (8, 49). Received saved weight with shape (8, 169)
# WARNING:tensorflow:Skipping loading weights for layer #453 (named stack_3_block_2/grid_window_mhsa/pos_emb) due to mismatch in shape for weight stack_3_block_2/grid_window_mhsa/pos_emb/positional_embedding:0. Weight expects shape (8, 49). Received saved weight with shape (8, 169)
# WARNING:tensorflow:Skipping loading weights for layer #499 (named stack_3_block_3/block_window_mhsa/pos_emb) due to mismatch in shape for weight stack_3_block_3/block_window_mhsa/pos_emb/positional_embedding:0. Weight expects shape (8, 49). Received saved weight with shape (8, 169)
# WARNING:tensorflow:Skipping loading weights for layer #530 (named stack_3_block_3/grid_window_mhsa/pos_emb) due to mismatch in shape for weight stack_3_block_3/grid_window_mhsa/pos_emb/positional_embedding:0. Weight expects shape (8, 49). Received saved weight with shape (8, 169)
# WARNING:tensorflow:Skipping loading weights for layer #576 (named stack_3_block_4/block_window_mhsa/pos_emb) due to mismatch in shape for weight stack_3_block_4/block_window_mhsa/pos_emb/positional_embedding:0. Weight expects shape (8, 49). Received saved weight with shape (8, 169)
# WARNING:tensorflow:Skipping loading weights for layer #607 (named stack_3_block_4/grid_window_mhsa/pos_emb) due to mismatch in shape for weight stack_3_block_4/grid_window_mhsa/pos_emb/positional_embedding:0. Weight expects shape (8, 49). Received saved weight with shape (8, 169)
# WARNING:tensorflow:Skipping loading weights for layer #653 (named stack_3_block_5/block_window_mhsa/pos_emb) due to mismatch in shape for weight stack_3_block_5/block_window_mhsa/pos_emb/positional_embedding:0. Weight expects shape (8, 49). Received saved weight with shape (8, 169)
# WARNING:tensorflow:Skipping loading weights for layer #684 (named stack_3_block_5/grid_window_mhsa/pos_emb) due to mismatch in shape for weight stack_3_block_5/grid_window_mhsa/pos_emb/positional_embedding:0. Weight expects shape (8, 49). Received saved weight with shape (8, 169)
# WARNING:tensorflow:Skipping loading weights for layer #732 (named stack_4_block_1/block_window_mhsa/pos_emb) due to mismatch in shape for weight stack_4_block_1/block_window_mhsa/pos_emb/positional_embedding:0. Weight expects shape (16, 49). Received saved weight with shape (16, 169)
# WARNING:tensorflow:Skipping loading weights for layer #763 (named stack_4_block_1/grid_window_mhsa/pos_emb) due to mismatch in shape for weight stack_4_block_1/grid_window_mhsa/pos_emb/positional_embedding:0. Weight expects shape (16, 49). Received saved weight with shape (16, 169)
# WARNING:tensorflow:Skipping loading weights for layer #809 (named stack_4_block_2/block_window_mhsa/pos_emb) due to mismatch in shape for weight stack_4_block_2/block_window_mhsa/pos_emb/positional_embedding:0. Weight expects shape (16, 49). Received saved weight with shape (16, 169)
# WARNING:tensorflow:Skipping loading weights for layer #840 (named stack_4_block_2/grid_window_mhsa/pos_emb) due to mismatch in shape for weight stack_4_block_2/grid_window_mhsa/pos_emb/positional_embedding:0. Weight expects shape (16, 49). Received saved weight with shape (16, 169)
# WARNING:tensorflow:Skipping loading weights for layer #863 (named predictions) due to mismatch in shape for weight predictions/kernel:0. Weight expects shape (512, 2). Received saved weight with shape (512, 1000)
# WARNING:tensorflow:Skipping loading weights for layer #863 (named predictions) due to mismatch in shape for weight predictions/bias:0. Weight expects shape (2,). Received saved weight with shape (1000,)
# >>>> Reload mismatched weights: 224 -> (112, 112)
# >>>> Reload layer: stack_1_block_1/block_window_mhsa/pos_emb
# >>>> Reload layer: stack_1_block_1/grid_window_mhsa/pos_emb
# >>>> Reload layer: stack_1_block_2/block_window_mhsa/pos_emb
# >>>> Reload layer: stack_1_block_2/grid_window_mhsa/pos_emb
# >>>> Reload layer: stack_2_block_1/block_window_mhsa/pos_emb
# >>>> Reload layer: stack_2_block_1/grid_window_mhsa/pos_emb
# >>>> Reload layer: stack_2_block_2/block_window_mhsa/pos_emb
# >>>> Reload layer: stack_2_block_2/grid_window_mhsa/pos_emb
# >>>> Reload layer: stack_3_block_1/block_window_mhsa/pos_emb
# >>>> Reload layer: stack_3_block_1/grid_window_mhsa/pos_emb
# >>>> Reload layer: stack_3_block_2/block_window_mhsa/pos_emb
# >>>> Reload layer: stack_3_block_2/grid_window_mhsa/pos_emb
# >>>> Reload layer: stack_3_block_3/block_window_mhsa/pos_emb
# >>>> Reload layer: stack_3_block_3/grid_window_mhsa/pos_emb
# >>>> Reload layer: stack_3_block_4/block_window_mhsa/pos_emb
# >>>> Reload layer: stack_3_block_4/grid_window_mhsa/pos_emb
# >>>> Reload layer: stack_3_block_5/block_window_mhsa/pos_emb
# >>>> Reload layer: stack_3_block_5/grid_window_mhsa/pos_emb
# >>>> Reload layer: stack_4_block_1/block_window_mhsa/pos_emb
# >>>> Reload layer: stack_4_block_1/grid_window_mhsa/pos_emb
# >>>> Reload layer: stack_4_block_2/block_window_mhsa/pos_emb
# >>>> Reload layer: stack_4_block_2/grid_window_mhsa/pos_emb

# %% [markdown]
# ## Original

# %%
train_dir = r"D:\Personal\Ocular Toxoplasmosis\data\BinaryClassification\train"
test_dir = r"D:\Personal\Ocular Toxoplasmosis\data\BinaryClassification\val"
generator_train, generator_test, labels, class_weights, num_classes, steps_per_epoch, steps_test = get_train_test(train_dir, test_dir)
model, callbacks = compile_model(model, weight)
# Out:
# Found 366 images belonging to 2 classes.
# Found 83 images belonging to 2 classes.
# {0: 1.3863636363636365, 1: 0.782051282051282}
# C:\Users\HSSL77\anaconda3\envs\tf_gpu_final\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
epochs = 50
history = model.fit_generator(generator=generator_train, epochs=epochs,steps_per_epoch=steps_per_epoch,
                                  validation_data=generator_test, validation_steps=steps_test,
                                 callbacks= callbacks, class_weight =class_weights)
# Out:
# C:\Users\HSSL77\AppData\Local\Temp\ipykernel_12164\1010306549.py:5: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(generator=generator_train, epochs=epochs,steps_per_epoch=steps_per_epoch,
# Epoch 1/50
# 46/45 [==============================] - ETA: 0s - loss: 0.8420 - accuracy: 0.4536 - categorical_accuracy: 0.4536 - auc: 0.4484 - precision: 0.4536 - recall: 0.4536 - true_positives: 166.0000 - true_negatives: 166.0000 - false_positives: 200.0000 - false_negatives: 200.0000 - cohen_kappa: -0.9542 - f1_score: 0.4405
# C:\Users\HSSL77\anaconda3\envs\tf_gpu_final\lib\site-packages\keras\engine\training.py:2034: UserWarning: Metric CohenKappa implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
# C:\Users\HSSL77\anaconda3\envs\tf_gpu_final\lib\site-packages\keras\engine\training.py:2034: UserWarning: Metric F1Score implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
# Epoch 1: val_accuracy improved from -inf to 0.50602, saving model to MaxVIT.h5
# 45/45 [==============================] - 78s 581ms/step - loss: 0.8420 - accuracy: 0.4536 - categorical_accuracy: 0.4536 - auc: 0.4484 - precision: 0.4536 - recall: 0.4536 - true_positives: 166.0000 - true_negatives: 166.0000 - false_positives: 200.0000 - false_negatives: 200.0000 - cohen_kappa: -0.9542 - f1_score: 0.4405 - val_loss: 0.7414 - val_accuracy: 0.5060 - val_categorical_accuracy: 0.5060 - val_auc: 0.4386 - val_precision: 0.5060 - val_recall: 0.5060 - val_true_positives: 42.0000 - val_true_negatives: 42.0000 - val_false_positives: 41.0000 - val_false_negatives: 41.0000 - val_cohen_kappa: -0.9988 - val_f1_score: 0.5057 - lr: 1.0000e-05
# Epoch 2/50
# 46/45 [==============================] - ETA: 0s - loss: 0.6436 - accuracy: 0.5956 - categorical_accuracy: 0.5956 - auc: 0.6715 - precision: 0.5956 - recall: 0.5956 - true_positives: 218.0000 - true_negatives: 218.0000 - false_positives: 148.0000 - false_negatives: 148.0000 - cohen_kappa: -0.9477 - f1_score: 0.5845
# Epoch 2: val_accuracy improved from 0.50602 to 0.51807, saving model to MaxVIT.h5
# 45/45 [==============================] - 17s 363ms/step - loss: 0.6436 - accuracy: 0.5956 - categorical_accuracy: 0.5956 - auc: 0.6715 - precision: 0.5956 - recall: 0.5956 - true_positives: 218.0000 - true_negatives: 218.0000 - false_positives: 148.0000 - false_negatives: 148.0000 - cohen_kappa: -0.9477 - f1_score: 0.5845 - val_loss: 0.6974 - val_accuracy: 0.5181 - val_categorical_accuracy: 0.5181 - val_auc: 0.5533 - val_precision: 0.5181 - val_recall: 0.5181 - val_true_positives: 43.0000 - val_true_negatives: 43.0000 - val_false_positives: 40.0000 - val_false_negatives: 40.0000 - val_cohen_kappa: -0.9768 - val_f1_score: 0.5123 - lr: 1.0000e-05
# Epoch 3/50
# 46/45 [==============================] - ETA: 0s - loss: 0.6082 - accuracy: 0.6667 - categorical_accuracy: 0.6667 - auc: 0.7187 - precision: 0.6667 - recall: 0.6667 - true_positives: 244.0000 - true_negatives: 244.0000 - false_positives: 122.0000 - false_negatives: 122.0000 - cohen_kappa: -0.9477 - f1_score: 0.6575
# Epoch 3: val_accuracy improved from 0.51807 to 0.57831, saving model to MaxVIT.h5
# 45/45 [==============================] - 21s 442ms/step - loss: 0.6082 - accuracy: 0.6667 - categorical_accuracy: 0.6667 - auc: 0.7187 - precision: 0.6667 - recall: 0.6667 - true_positives: 244.0000 - true_negatives: 244.0000 - false_positives: 122.0000 - false_negatives: 122.0000 - cohen_kappa: -0.9477 - f1_score: 0.6575 - val_loss: 0.6625 - val_accuracy: 0.5783 - val_categorical_accuracy: 0.5783 - val_auc: 0.6467 - val_precision: 0.5783 - val_recall: 0.5783 - val_true_positives: 48.0000 - val_true_negatives: 48.0000 - val_false_positives: 35.0000 - val_false_negatives: 35.0000 - val_cohen_kappa: -0.9714 - val_f1_score: 0.5721 - lr: 1.0000e-05
# Epoch 4/50
# 46/45 [==============================] - ETA: 0s - loss: 0.5084 - accuracy: 0.7432 - categorical_accuracy: 0.7432 - auc: 0.8352 - precision: 0.7432 - recall: 0.7432 - true_positives: 272.0000 - true_negatives: 272.0000 - false_positives: 94.0000 - false_negatives: 94.0000 - cohen_kappa: -0.9407 - f1_score: 0.7351
# Epoch 4: val_accuracy improved from 0.57831 to 0.67470, saving model to MaxVIT.h5
# 45/45 [==============================] - 17s 366ms/step - loss: 0.5084 - accuracy: 0.7432 - categorical_accuracy: 0.7432 - auc: 0.8352 - precision: 0.7432 - recall: 0.7432 - true_positives: 272.0000 - true_negatives: 272.0000 - false_positives: 94.0000 - false_negatives: 94.0000 - cohen_kappa: -0.9407 - f1_score: 0.7351 - val_loss: 0.6348 - val_accuracy: 0.6747 - val_categorical_accuracy: 0.6747 - val_auc: 0.7135 - val_precision: 0.6747 - val_recall: 0.6747 - val_true_positives: 56.0000 - val_true_negatives: 56.0000 - val_false_positives: 27.0000 - val_false_negatives: 27.0000 - val_cohen_kappa: -0.9283 - val_f1_score: 0.6621 - lr: 1.0000e-05
# Epoch 5/50
# 46/45 [==============================] - ETA: 0s - loss: 0.4536 - accuracy: 0.7923 - categorical_accuracy: 0.7923 - auc: 0.8807 - precision: 0.7923 - recall: 0.7923 - true_positives: 290.0000 - true_negatives: 290.0000 - false_positives: 76.0000 - false_negatives: 76.0000 - cohen_kappa: -0.9088 - f1_score: 0.7819
# Epoch 5: val_accuracy improved from 0.67470 to 0.69880, saving model to MaxVIT.h5
# 45/45 [==============================] - 17s 365ms/step - loss: 0.4536 - accuracy: 0.7923 - categorical_accuracy: 0.7923 - auc: 0.8807 - precision: 0.7923 - recall: 0.7923 - true_positives: 290.0000 - true_negatives: 290.0000 - false_positives: 76.0000 - false_negatives: 76.0000 - cohen_kappa: -0.9088 - f1_score: 0.7819 - val_loss: 0.6603 - val_accuracy: 0.6988 - val_categorical_accuracy: 0.6988 - val_auc: 0.7267 - val_precision: 0.6988 - val_recall: 0.6988 - val_true_positives: 58.0000 - val_true_negatives: 58.0000 - val_false_positives: 25.0000 - val_false_negatives: 25.0000 - val_cohen_kappa: -0.8902 - val_f1_score: 0.6802 - lr: 1.0000e-05
# Epoch 6/50
# 46/45 [==============================] - ETA: 0s - loss: 0.4123 - accuracy: 0.8005 - categorical_accuracy: 0.8005 - auc: 0.8985 - precision: 0.8005 - recall: 0.8005 - true_positives: 293.0000 - true_negatives: 293.0000 - false_positives: 73.0000 - false_negatives: 73.0000 - cohen_kappa: -0.9152 - f1_score: 0.7913
# Epoch 6: val_accuracy did not improve from 0.69880
# 45/45 [==============================] - 16s 337ms/step - loss: 0.4123 - accuracy: 0.8005 - categorical_accuracy: 0.8005 - auc: 0.8985 - precision: 0.8005 - recall: 0.8005 - true_positives: 293.0000 - true_negatives: 293.0000 - false_positives: 73.0000 - false_negatives: 73.0000 - cohen_kappa: -0.9152 - f1_score: 0.7913 - val_loss: 0.6450 - val_accuracy: 0.6627 - val_categorical_accuracy: 0.6627 - val_auc: 0.7603 - val_precision: 0.6627 - val_recall: 0.6627 - val_true_positives: 55.0000 - val_true_negatives: 55.0000 - val_false_positives: 28.0000 - val_false_negatives: 28.0000 - val_cohen_kappa: -0.9004 - val_f1_score: 0.6440 - lr: 1.0000e-05
# Epoch 7/50
# 46/45 [==============================] - ETA: 0s - loss: 0.3766 - accuracy: 0.8361 - categorical_accuracy: 0.8361 - auc: 0.9150 - precision: 0.8361 - recall: 0.8361 - true_positives: 306.0000 - true_negatives: 306.0000 - false_positives: 60.0000 - false_negatives: 60.0000 - cohen_kappa: -0.9370 - f1_score: 0.8306
# Epoch 7: val_accuracy improved from 0.69880 to 0.73494, saving model to MaxVIT.h5
# 45/45 [==============================] - 17s 365ms/step - loss: 0.3766 - accuracy: 0.8361 - categorical_accuracy: 0.8361 - auc: 0.9150 - precision: 0.8361 - recall: 0.8361 - true_positives: 306.0000 - true_negatives: 306.0000 - false_positives: 60.0000 - false_negatives: 60.0000 - cohen_kappa: -0.9370 - f1_score: 0.8306 - val_loss: 0.5986 - val_accuracy: 0.7349 - val_categorical_accuracy: 0.7349 - val_auc: 0.7862 - val_precision: 0.7349 - val_recall: 0.7349 - val_true_positives: 61.0000 - val_true_negatives: 61.0000 - val_false_positives: 22.0000 - val_false_negatives: 22.0000 - val_cohen_kappa: -0.8086 - val_f1_score: 0.7036 - lr: 1.0000e-05
# Epoch 8/50
# 46/45 [==============================] - ETA: 0s - loss: 0.3448 - accuracy: 0.8607 - categorical_accuracy: 0.8607 - auc: 0.9347 - precision: 0.8607 - recall: 0.8607 - true_positives: 315.0000 - true_negatives: 315.0000 - false_positives: 51.0000 - false_negatives: 51.0000 - cohen_kappa: -0.8687 - f1_score: 0.8501
# Epoch 8: val_accuracy did not improve from 0.73494
# 45/45 [==============================] - 15s 330ms/step - loss: 0.3448 - accuracy: 0.8607 - categorical_accuracy: 0.8607 - auc: 0.9347 - precision: 0.8607 - recall: 0.8607 - true_positives: 315.0000 - true_negatives: 315.0000 - false_positives: 51.0000 - false_negatives: 51.0000 - cohen_kappa: -0.8687 - f1_score: 0.8501 - val_loss: 0.5527 - val_accuracy: 0.7349 - val_categorical_accuracy: 0.7349 - val_auc: 0.8164 - val_precision: 0.7349 - val_recall: 0.7349 - val_true_positives: 61.0000 - val_true_negatives: 61.0000 - val_false_positives: 22.0000 - val_false_negatives: 22.0000 - val_cohen_kappa: -0.8574 - val_f1_score: 0.7129 - lr: 1.0000e-05
# Epoch 9/50
# 46/45 [==============================] - ETA: 0s - loss: 0.3251 - accuracy: 0.8607 - categorical_accuracy: 0.8607 - auc: 0.9336 - precision: 0.8607 - recall: 0.8607 - true_positives: 315.0000 - true_negatives: 315.0000 - false_positives: 51.0000 - false_negatives: 51.0000 - cohen_kappa: -0.9235 - f1_score: 0.8549
# Epoch 9: val_accuracy improved from 0.73494 to 0.77108, saving model to MaxVIT.h5
# 45/45 [==============================] - 16s 358ms/step - loss: 0.3251 - accuracy: 0.8607 - categorical_accuracy: 0.8607 - auc: 0.9336 - precision: 0.8607 - recall: 0.8607 - true_positives: 315.0000 - true_negatives: 315.0000 - false_positives: 51.0000 - false_negatives: 51.0000 - cohen_kappa: -0.9235 - f1_score: 0.8549 - val_loss: 0.5059 - val_accuracy: 0.7711 - val_categorical_accuracy: 0.7711 - val_auc: 0.8438 - val_precision: 0.7711 - val_recall: 0.7711 - val_true_positives: 64.0000 - val_true_negatives: 64.0000 - val_false_positives: 19.0000 - val_false_negatives: 19.0000 - val_cohen_kappa: -0.8457 - val_f1_score: 0.7502 - lr: 1.0000e-05
# Epoch 10/50
# 46/45 [==============================] - ETA: 0s - loss: 0.3098 - accuracy: 0.8716 - categorical_accuracy: 0.8716 - auc: 0.9463 - precision: 0.8716 - recall: 0.8716 - true_positives: 319.0000 - true_negatives: 319.0000 - false_positives: 47.0000 - false_negatives: 47.0000 - cohen_kappa: -0.8738 - f1_score: 0.8623
# Epoch 10: val_accuracy improved from 0.77108 to 0.78313, saving model to MaxVIT.h5
# 45/45 [==============================] - 17s 359ms/step - loss: 0.3098 - accuracy: 0.8716 - categorical_accuracy: 0.8716 - auc: 0.9463 - precision: 0.8716 - recall: 0.8716 - true_positives: 319.0000 - true_negatives: 319.0000 - false_positives: 47.0000 - false_negatives: 47.0000 - cohen_kappa: -0.8738 - f1_score: 0.8623 - val_loss: 0.4971 - val_accuracy: 0.7831 - val_categorical_accuracy: 0.7831 - val_auc: 0.8553 - val_precision: 0.7831 - val_recall: 0.7831 - val_true_positives: 65.0000 - val_true_negatives: 65.0000 - val_false_positives: 18.0000 - val_false_negatives: 18.0000 - val_cohen_kappa: -0.9004 - val_f1_score: 0.7711 - lr: 1.0000e-05
# Epoch 11/50
# 46/45 [==============================] - ETA: 0s - loss: 0.2271 - accuracy: 0.9180 - categorical_accuracy: 0.9180 - auc: 0.9705 - precision: 0.9180 - recall: 0.9180 - true_positives: 336.0000 - true_negatives: 336.0000 - false_positives: 30.0000 - false_negatives: 30.0000 - cohen_kappa: -0.8954 - f1_score: 0.9132
# Epoch 11: val_accuracy improved from 0.78313 to 0.80723, saving model to MaxVIT.h5
# 45/45 [==============================] - 17s 369ms/step - loss: 0.2271 - accuracy: 0.9180 - categorical_accuracy: 0.9180 - auc: 0.9705 - precision: 0.9180 - recall: 0.9180 - true_positives: 336.0000 - true_negatives: 336.0000 - false_positives: 30.0000 - false_negatives: 30.0000 - cohen_kappa: -0.8954 - f1_score: 0.9132 - val_loss: 0.4401 - val_accuracy: 0.8072 - val_categorical_accuracy: 0.8072 - val_auc: 0.8844 - val_precision: 0.8072 - val_recall: 0.8072 - val_true_positives: 67.0000 - val_true_negatives: 67.0000 - val_false_positives: 16.0000 - val_false_negatives: 16.0000 - val_cohen_kappa: -0.8336 - val_f1_score: 0.7880 - lr: 1.0000e-05
# Epoch 12/50
# 46/45 [==============================] - ETA: 0s - loss: 0.2374 - accuracy: 0.9180 - categorical_accuracy: 0.9180 - auc: 0.9709 - precision: 0.9180 - recall: 0.9180 - true_positives: 336.0000 - true_negatives: 336.0000 - false_positives: 30.0000 - false_negatives: 30.0000 - cohen_kappa: -0.8713 - f1_score: 0.9120
# Epoch 12: val_accuracy improved from 0.80723 to 0.81928, saving model to MaxVIT.h5
# 45/45 [==============================] - 17s 373ms/step - loss: 0.2374 - accuracy: 0.9180 - categorical_accuracy: 0.9180 - auc: 0.9709 - precision: 0.9180 - recall: 0.9180 - true_positives: 336.0000 - true_negatives: 336.0000 - false_positives: 30.0000 - false_negatives: 30.0000 - cohen_kappa: -0.8713 - f1_score: 0.9120 - val_loss: 0.4447 - val_accuracy: 0.8193 - val_categorical_accuracy: 0.8193 - val_auc: 0.8852 - val_precision: 0.8193 - val_recall: 0.8193 - val_true_positives: 68.0000 - val_true_negatives: 68.0000 - val_false_positives: 15.0000 - val_false_negatives: 15.0000 - val_cohen_kappa: -0.8902 - val_f1_score: 0.8081 - lr: 1.0000e-05
# Epoch 13/50
# 46/45 [==============================] - ETA: 0s - loss: 0.2077 - accuracy: 0.9262 - categorical_accuracy: 0.9262 - auc: 0.9745 - precision: 0.9262 - recall: 0.9262 - true_positives: 339.0000 - true_negatives: 339.0000 - false_positives: 27.0000 - false_negatives: 27.0000 - cohen_kappa: -0.8836 - f1_score: 0.9214
# Epoch 13: val_accuracy improved from 0.81928 to 0.85542, saving model to MaxVIT.h5
# 45/45 [==============================] - 17s 365ms/step - loss: 0.2077 - accuracy: 0.9262 - categorical_accuracy: 0.9262 - auc: 0.9745 - precision: 0.9262 - recall: 0.9262 - true_positives: 339.0000 - true_negatives: 339.0000 - false_positives: 27.0000 - false_negatives: 27.0000 - cohen_kappa: -0.8836 - f1_score: 0.9214 - val_loss: 0.4323 - val_accuracy: 0.8554 - val_categorical_accuracy: 0.8554 - val_auc: 0.8914 - val_precision: 0.8554 - val_recall: 0.8554 - val_true_positives: 71.0000 - val_true_negatives: 71.0000 - val_false_positives: 12.0000 - val_false_negatives: 12.0000 - val_cohen_kappa: -0.8336 - val_f1_score: 0.8410 - lr: 1.0000e-05
# Epoch 14/50
# 46/45 [==============================] - ETA: 0s - loss: 0.2041 - accuracy: 0.9262 - categorical_accuracy: 0.9262 - auc: 0.9738 - precision: 0.9262 - recall: 0.9262 - true_positives: 339.0000 - true_negatives: 339.0000 - false_positives: 27.0000 - false_negatives: 27.0000 - cohen_kappa: -0.8930 - f1_score: 0.9218
# Epoch 14: val_accuracy did not improve from 0.85542
# 45/45 [==============================] - 15s 327ms/step - loss: 0.2041 - accuracy: 0.9262 - categorical_accuracy: 0.9262 - auc: 0.9738 - precision: 0.9262 - recall: 0.9262 - true_positives: 339.0000 - true_negatives: 339.0000 - false_positives: 27.0000 - false_negatives: 27.0000 - cohen_kappa: -0.8930 - f1_score: 0.9218 - val_loss: 0.4200 - val_accuracy: 0.8313 - val_categorical_accuracy: 0.8313 - val_auc: 0.8969 - val_precision: 0.8313 - val_recall: 0.8313 - val_true_positives: 69.0000 - val_true_negatives: 69.0000 - val_false_positives: 14.0000 - val_false_negatives: 14.0000 - val_cohen_kappa: -0.8574 - val_f1_score: 0.8173 - lr: 1.0000e-05
# Epoch 15/50
# 46/45 [==============================] - ETA: 0s - loss: 0.2010 - accuracy: 0.9208 - categorical_accuracy: 0.9208 - auc: 0.9747 - precision: 0.9208 - recall: 0.9208 - true_positives: 337.0000 - true_negatives: 337.0000 - false_positives: 29.0000 - false_negatives: 29.0000 - cohen_kappa: -0.8738 - f1_score: 0.9150
# Epoch 15: val_accuracy did not improve from 0.85542
# 45/45 [==============================] - 15s 320ms/step - loss: 0.2010 - accuracy: 0.9208 - categorical_accuracy: 0.9208 - auc: 0.9747 - precision: 0.9208 - recall: 0.9208 - true_positives: 337.0000 - true_negatives: 337.0000 - false_positives: 29.0000 - false_negatives: 29.0000 - cohen_kappa: -0.8738 - f1_score: 0.9150 - val_loss: 0.4660 - val_accuracy: 0.8193 - val_categorical_accuracy: 0.8193 - val_auc: 0.8782 - val_precision: 0.8193 - val_recall: 0.8193 - val_true_positives: 68.0000 - val_true_negatives: 68.0000 - val_false_positives: 15.0000 - val_false_negatives: 15.0000 - val_cohen_kappa: -0.9283 - val_f1_score: 0.8123 - lr: 1.0000e-05
# Epoch 16/50
# 46/45 [==============================] - ETA: 0s - loss: 0.1701 - accuracy: 0.9317 - categorical_accuracy: 0.9317 - auc: 0.9808 - precision: 0.9317 - recall: 0.9317 - true_positives: 341.0000 - true_negatives: 341.0000 - false_positives: 25.0000 - false_negatives: 25.0000 - cohen_kappa: -0.8883 - f1_score: 0.9274
# Epoch 16: val_accuracy did not improve from 0.85542
# 45/45 [==============================] - 15s 333ms/step - loss: 0.1701 - accuracy: 0.9317 - categorical_accuracy: 0.9317 - auc: 0.9808 - precision: 0.9317 - recall: 0.9317 - true_positives: 341.0000 - true_negatives: 341.0000 - false_positives: 25.0000 - false_negatives: 25.0000 - cohen_kappa: -0.8883 - f1_score: 0.9274 - val_loss: 0.4487 - val_accuracy: 0.8313 - val_categorical_accuracy: 0.8313 - val_auc: 0.8876 - val_precision: 0.8313 - val_recall: 0.8313 - val_true_positives: 69.0000 - val_true_negatives: 69.0000 - val_false_positives: 14.0000 - val_false_negatives: 14.0000 - val_cohen_kappa: -0.9195 - val_f1_score: 0.8239 - lr: 1.0000e-05
# Epoch 17/50
# 46/45 [==============================] - ETA: 0s - loss: 0.1695 - accuracy: 0.9536 - categorical_accuracy: 0.9536 - auc: 0.9820 - precision: 0.9536 - recall: 0.9536 - true_positives: 349.0000 - true_negatives: 349.0000 - false_positives: 17.0000 - false_negatives: 17.0000 - cohen_kappa: -0.8836 - f1_score: 0.9505
# Epoch 17: val_accuracy did not improve from 0.85542
# 45/45 [==============================] - 15s 316ms/step - loss: 0.1695 - accuracy: 0.9536 - categorical_accuracy: 0.9536 - auc: 0.9820 - precision: 0.9536 - recall: 0.9536 - true_positives: 349.0000 - true_negatives: 349.0000 - false_positives: 17.0000 - false_negatives: 17.0000 - cohen_kappa: -0.8836 - f1_score: 0.9505 - val_loss: 0.4059 - val_accuracy: 0.8313 - val_categorical_accuracy: 0.8313 - val_auc: 0.9008 - val_precision: 0.8313 - val_recall: 0.8313 - val_true_positives: 69.0000 - val_true_negatives: 69.0000 - val_false_positives: 14.0000 - val_false_negatives: 14.0000 - val_cohen_kappa: -0.9195 - val_f1_score: 0.8239 - lr: 1.0000e-05
# Epoch 18/50
# 46/45 [==============================] - ETA: 0s - loss: 0.1474 - accuracy: 0.9481 - categorical_accuracy: 0.9481 - auc: 0.9868 - precision: 0.9481 - recall: 0.9481 - true_positives: 347.0000 - true_negatives: 347.0000 - false_positives: 19.0000 - false_negatives: 19.0000 - cohen_kappa: -0.8787 - f1_score: 0.9445
# Epoch 18: val_accuracy did not improve from 0.85542
# 45/45 [==============================] - 16s 339ms/step - loss: 0.1474 - accuracy: 0.9481 - categorical_accuracy: 0.9481 - auc: 0.9868 - precision: 0.9481 - recall: 0.9481 - true_positives: 347.0000 - true_negatives: 347.0000 - false_positives: 19.0000 - false_negatives: 19.0000 - cohen_kappa: -0.8787 - f1_score: 0.9445 - val_loss: 0.4172 - val_accuracy: 0.8313 - val_categorical_accuracy: 0.8313 - val_auc: 0.9016 - val_precision: 0.8313 - val_recall: 0.8313 - val_true_positives: 69.0000 - val_true_negatives: 69.0000 - val_false_positives: 14.0000 - val_false_negatives: 14.0000 - val_cohen_kappa: -0.9195 - val_f1_score: 0.8239 - lr: 1.0000e-05
# Epoch 19/50
# 46/45 [==============================] - ETA: 0s - loss: 0.1555 - accuracy: 0.9454 - categorical_accuracy: 0.9454 - auc: 0.9838 - precision: 0.9454 - recall: 0.9454 - true_positives: 346.0000 - true_negatives: 346.0000 - false_positives: 20.0000 - false_negatives: 20.0000 - cohen_kappa: -0.8860 - f1_score: 0.9418
# Epoch 19: val_accuracy did not improve from 0.85542
# 45/45 [==============================] - 15s 325ms/step - loss: 0.1555 - accuracy: 0.9454 - categorical_accuracy: 0.9454 - auc: 0.9838 - precision: 0.9454 - recall: 0.9454 - true_positives: 346.0000 - true_negatives: 346.0000 - false_positives: 20.0000 - false_negatives: 20.0000 - cohen_kappa: -0.8860 - f1_score: 0.9418 - val_loss: 0.3811 - val_accuracy: 0.8554 - val_categorical_accuracy: 0.8554 - val_auc: 0.9138 - val_precision: 0.8554 - val_recall: 0.8554 - val_true_positives: 71.0000 - val_true_negatives: 71.0000 - val_false_positives: 12.0000 - val_false_negatives: 12.0000 - val_cohen_kappa: -0.9004 - val_f1_score: 0.8474 - lr: 1.0000e-05
# Epoch 20/50
# 46/45 [==============================] - ETA: 0s - loss: 0.1483 - accuracy: 0.9590 - categorical_accuracy: 0.9590 - auc: 0.9874 - precision: 0.9590 - recall: 0.9590 - true_positives: 351.0000 - true_negatives: 351.0000 - false_positives: 15.0000 - false_negatives: 15.0000 - cohen_kappa: -0.8687 - f1_score: 0.9559
# Epoch 20: val_accuracy did not improve from 0.85542
# 45/45 [==============================] - 16s 345ms/step - loss: 0.1483 - accuracy: 0.9590 - categorical_accuracy: 0.9590 - auc: 0.9874 - precision: 0.9590 - recall: 0.9590 - true_positives: 351.0000 - true_negatives: 351.0000 - false_positives: 15.0000 - false_negatives: 15.0000 - cohen_kappa: -0.8687 - f1_score: 0.9559 - val_loss: 0.4472 - val_accuracy: 0.8313 - val_categorical_accuracy: 0.8313 - val_auc: 0.8900 - val_precision: 0.8313 - val_recall: 0.8313 - val_true_positives: 69.0000 - val_true_negatives: 69.0000 - val_false_positives: 14.0000 - val_false_negatives: 14.0000 - val_cohen_kappa: -0.9367 - val_f1_score: 0.8256 - lr: 1.0000e-05
# Epoch 21/50
# 46/45 [==============================] - ETA: 0s - loss: 0.1513 - accuracy: 0.9399 - categorical_accuracy: 0.9399 - auc: 0.9851 - precision: 0.9399 - recall: 0.9399 - true_positives: 344.0000 - true_negatives: 344.0000 - false_positives: 22.0000 - false_negatives: 22.0000 - cohen_kappa: -0.8860 - f1_score: 0.9360
# Epoch 21: val_accuracy improved from 0.85542 to 0.86747, saving model to MaxVIT.h5
# 45/45 [==============================] - 18s 390ms/step - loss: 0.1513 - accuracy: 0.9399 - categorical_accuracy: 0.9399 - auc: 0.9851 - precision: 0.9399 - recall: 0.9399 - true_positives: 344.0000 - true_negatives: 344.0000 - false_positives: 22.0000 - false_negatives: 22.0000 - cohen_kappa: -0.8860 - f1_score: 0.9360 - val_loss: 0.3786 - val_accuracy: 0.8675 - val_categorical_accuracy: 0.8675 - val_auc: 0.9157 - val_precision: 0.8675 - val_recall: 0.8675 - val_true_positives: 72.0000 - val_true_negatives: 72.0000 - val_false_positives: 11.0000 - val_false_negatives: 11.0000 - val_cohen_kappa: -0.8902 - val_f1_score: 0.8593 - lr: 1.0000e-05
# Epoch 22/50
# 46/45 [==============================] - ETA: 0s - loss: 0.1141 - accuracy: 0.9645 - categorical_accuracy: 0.9645 - auc: 0.9901 - precision: 0.9645 - recall: 0.9645 - true_positives: 353.0000 - true_negatives: 353.0000 - false_positives: 13.0000 - false_negatives: 13.0000 - cohen_kappa: -0.8787 - f1_score: 0.9620
# Epoch 22: val_accuracy did not improve from 0.86747
# 45/45 [==============================] - 18s 391ms/step - loss: 0.1141 - accuracy: 0.9645 - categorical_accuracy: 0.9645 - auc: 0.9901 - precision: 0.9645 - recall: 0.9645 - true_positives: 353.0000 - true_negatives: 353.0000 - false_positives: 13.0000 - false_negatives: 13.0000 - cohen_kappa: -0.8787 - f1_score: 0.9620 - val_loss: 0.3830 - val_accuracy: 0.8554 - val_categorical_accuracy: 0.8554 - val_auc: 0.9157 - val_precision: 0.8554 - val_recall: 0.8554 - val_true_positives: 71.0000 - val_true_negatives: 71.0000 - val_false_positives: 12.0000 - val_false_negatives: 12.0000 - val_cohen_kappa: -0.9195 - val_f1_score: 0.8491 - lr: 1.0000e-05
# Epoch 23/50
# 46/45 [==============================] - ETA: 0s - loss: 0.1343 - accuracy: 0.9508 - categorical_accuracy: 0.9508 - auc: 0.9876 - precision: 0.9508 - recall: 0.9508 - true_positives: 348.0000 - true_negatives: 348.0000 - false_positives: 18.0000 - false_negatives: 18.0000 - cohen_kappa: -0.8860 - f1_score: 0.9477
# Epoch 23: val_accuracy improved from 0.86747 to 0.89157, saving model to MaxVIT.h5
# 45/45 [==============================] - 20s 430ms/step - loss: 0.1343 - accuracy: 0.9508 - categorical_accuracy: 0.9508 - auc: 0.9876 - precision: 0.9508 - recall: 0.9508 - true_positives: 348.0000 - true_negatives: 348.0000 - false_positives: 18.0000 - false_negatives: 18.0000 - cohen_kappa: -0.8860 - f1_score: 0.9477 - val_loss: 0.3640 - val_accuracy: 0.8916 - val_categorical_accuracy: 0.8916 - val_auc: 0.9215 - val_precision: 0.8916 - val_recall: 0.8916 - val_true_positives: 74.0000 - val_true_negatives: 74.0000 - val_false_positives: 9.0000 - val_false_negatives: 9.0000 - val_cohen_kappa: -0.8902 - val_f1_score: 0.8849 - lr: 1.0000e-05
# Epoch 24/50
# 46/45 [==============================] - ETA: 0s - loss: 0.1293 - accuracy: 0.9617 - categorical_accuracy: 0.9617 - auc: 0.9870 - precision: 0.9617 - recall: 0.9617 - true_positives: 352.0000 - true_negatives: 352.0000 - false_positives: 14.0000 - false_negatives: 14.0000 - cohen_kappa: -0.8713 - f1_score: 0.9589
# Epoch 24: val_accuracy improved from 0.89157 to 0.90361, saving model to MaxVIT.h5
# 45/45 [==============================] - 21s 442ms/step - loss: 0.1293 - accuracy: 0.9617 - categorical_accuracy: 0.9617 - auc: 0.9870 - precision: 0.9617 - recall: 0.9617 - true_positives: 352.0000 - true_negatives: 352.0000 - false_positives: 14.0000 - false_negatives: 14.0000 - cohen_kappa: -0.8713 - f1_score: 0.9589 - val_loss: 0.3570 - val_accuracy: 0.9036 - val_categorical_accuracy: 0.9036 - val_auc: 0.9235 - val_precision: 0.9036 - val_recall: 0.9036 - val_true_positives: 75.0000 - val_true_negatives: 75.0000 - val_false_positives: 8.0000 - val_false_negatives: 8.0000 - val_cohen_kappa: -0.8797 - val_f1_score: 0.8970 - lr: 1.0000e-05
# Epoch 25/50
# 46/45 [==============================] - ETA: 0s - loss: 0.1296 - accuracy: 0.9617 - categorical_accuracy: 0.9617 - auc: 0.9870 - precision: 0.9617 - recall: 0.9617 - true_positives: 352.0000 - true_negatives: 352.0000 - false_positives: 14.0000 - false_negatives: 14.0000 - cohen_kappa: -0.8713 - f1_score: 0.9589
# Epoch 25: val_accuracy did not improve from 0.90361
# 45/45 [==============================] - 17s 373ms/step - loss: 0.1296 - accuracy: 0.9617 - categorical_accuracy: 0.9617 - auc: 0.9870 - precision: 0.9617 - recall: 0.9617 - true_positives: 352.0000 - true_negatives: 352.0000 - false_positives: 14.0000 - false_negatives: 14.0000 - cohen_kappa: -0.8713 - f1_score: 0.9589 - val_loss: 0.3528 - val_accuracy: 0.9036 - val_categorical_accuracy: 0.9036 - val_auc: 0.9252 - val_precision: 0.9036 - val_recall: 0.9036 - val_true_positives: 75.0000 - val_true_negatives: 75.0000 - val_false_positives: 8.0000 - val_false_negatives: 8.0000 - val_cohen_kappa: -0.8797 - val_f1_score: 0.8970 - lr: 1.0000e-05
# Epoch 26/50
# 46/45 [==============================] - ETA: 0s - loss: 0.1302 - accuracy: 0.9508 - categorical_accuracy: 0.9508 - auc: 0.9895 - precision: 0.9508 - recall: 0.9508 - true_positives: 348.0000 - true_negatives: 348.0000 - false_positives: 18.0000 - false_negatives: 18.0000 - cohen_kappa: -0.8713 - f1_score: 0.9472
# Epoch 26: val_accuracy did not improve from 0.90361
# 45/45 [==============================] - 18s 384ms/step - loss: 0.1302 - accuracy: 0.9508 - categorical_accuracy: 0.9508 - auc: 0.9895 - precision: 0.9508 - recall: 0.9508 - true_positives: 348.0000 - true_negatives: 348.0000 - false_positives: 18.0000 - false_negatives: 18.0000 - cohen_kappa: -0.8713 - f1_score: 0.9472 - val_loss: 0.4158 - val_accuracy: 0.8675 - val_categorical_accuracy: 0.8675 - val_auc: 0.9078 - val_precision: 0.8675 - val_recall: 0.8675 - val_true_positives: 72.0000 - val_true_negatives: 72.0000 - val_false_positives: 11.0000 - val_false_negatives: 11.0000 - val_cohen_kappa: -0.9102 - val_f1_score: 0.8609 - lr: 1.0000e-05
# Epoch 27/50
# 46/45 [==============================] - ETA: 0s - loss: 0.1128 - accuracy: 0.9617 - categorical_accuracy: 0.9617 - auc: 0.9884 - precision: 0.9617 - recall: 0.9617 - true_positives: 352.0000 - true_negatives: 352.0000 - false_positives: 14.0000 - false_negatives: 14.0000 - cohen_kappa: -0.8713 - f1_score: 0.9589
# Epoch 27: val_accuracy did not improve from 0.90361
# 45/45 [==============================] - 18s 384ms/step - loss: 0.1128 - accuracy: 0.9617 - categorical_accuracy: 0.9617 - auc: 0.9884 - precision: 0.9617 - recall: 0.9617 - true_positives: 352.0000 - true_negatives: 352.0000 - false_positives: 14.0000 - false_negatives: 14.0000 - cohen_kappa: -0.8713 - f1_score: 0.9589 - val_loss: 0.3159 - val_accuracy: 0.9036 - val_categorical_accuracy: 0.9036 - val_auc: 0.9360 - val_precision: 0.9036 - val_recall: 0.9036 - val_true_positives: 75.0000 - val_true_negatives: 75.0000 - val_false_positives: 8.0000 - val_false_negatives: 8.0000 - val_cohen_kappa: -0.8797 - val_f1_score: 0.8970 - lr: 1.0000e-05
# Epoch 28/50
# 46/45 [==============================] - ETA: 0s - loss: 0.0844 - accuracy: 0.9699 - categorical_accuracy: 0.9699 - auc: 0.9964 - precision: 0.9699 - recall: 0.9699 - true_positives: 355.0000 - true_negatives: 355.0000 - false_positives: 11.0000 - false_negatives: 11.0000 - cohen_kappa: -0.8787 - f1_score: 0.9679
# Epoch 28: val_accuracy did not improve from 0.90361
# 45/45 [==============================] - 20s 429ms/step - loss: 0.0844 - accuracy: 0.9699 - categorical_accuracy: 0.9699 - auc: 0.9964 - precision: 0.9699 - recall: 0.9699 - true_positives: 355.0000 - true_negatives: 355.0000 - false_positives: 11.0000 - false_negatives: 11.0000 - cohen_kappa: -0.8787 - f1_score: 0.9679 - val_loss: 0.3226 - val_accuracy: 0.9036 - val_categorical_accuracy: 0.9036 - val_auc: 0.9371 - val_precision: 0.9036 - val_recall: 0.9036 - val_true_positives: 75.0000 - val_true_negatives: 75.0000 - val_false_positives: 8.0000 - val_false_negatives: 8.0000 - val_cohen_kappa: -0.8797 - val_f1_score: 0.8970 - lr: 1.0000e-05
# Epoch 29/50
# 46/45 [==============================] - ETA: 0s - loss: 0.0883 - accuracy: 0.9672 - categorical_accuracy: 0.9672 - auc: 0.9961 - precision: 0.9672 - recall: 0.9672 - true_positives: 354.0000 - true_negatives: 354.0000 - false_positives: 12.0000 - false_negatives: 12.0000 - cohen_kappa: -0.8713 - f1_score: 0.9648
# Epoch 29: val_accuracy did not improve from 0.90361
# 45/45 [==============================] - 17s 376ms/step - loss: 0.0883 - accuracy: 0.9672 - categorical_accuracy: 0.9672 - auc: 0.9961 - precision: 0.9672 - recall: 0.9672 - true_positives: 354.0000 - true_negatives: 354.0000 - false_positives: 12.0000 - false_negatives: 12.0000 - cohen_kappa: -0.8713 - f1_score: 0.9648 - val_loss: 0.3588 - val_accuracy: 0.8916 - val_categorical_accuracy: 0.8916 - val_auc: 0.9274 - val_precision: 0.8916 - val_recall: 0.8916 - val_true_positives: 74.0000 - val_true_negatives: 74.0000 - val_false_positives: 9.0000 - val_false_negatives: 9.0000 - val_cohen_kappa: -0.8902 - val_f1_score: 0.8849 - lr: 1.0000e-05
# Epoch 30/50
# 46/45 [==============================] - ETA: 0s - loss: 0.0883 - accuracy: 0.9672 - categorical_accuracy: 0.9672 - auc: 0.9940 - precision: 0.9672 - recall: 0.9672 - true_positives: 354.0000 - true_negatives: 354.0000 - false_positives: 12.0000 - false_negatives: 12.0000 - cohen_kappa: -0.8811 - f1_score: 0.9650
# Epoch 30: val_accuracy did not improve from 0.90361
# 45/45 [==============================] - 21s 462ms/step - loss: 0.0883 - accuracy: 0.9672 - categorical_accuracy: 0.9672 - auc: 0.9940 - precision: 0.9672 - recall: 0.9672 - true_positives: 354.0000 - true_negatives: 354.0000 - false_positives: 12.0000 - false_negatives: 12.0000 - cohen_kappa: -0.8811 - f1_score: 0.9650 - val_loss: 0.3384 - val_accuracy: 0.9036 - val_categorical_accuracy: 0.9036 - val_auc: 0.9337 - val_precision: 0.9036 - val_recall: 0.9036 - val_true_positives: 75.0000 - val_true_negatives: 75.0000 - val_false_positives: 8.0000 - val_false_negatives: 8.0000 - val_cohen_kappa: -0.8797 - val_f1_score: 0.8970 - lr: 1.0000e-05
# Epoch 31/50
# 46/45 [==============================] - ETA: 0s - loss: 0.0820 - accuracy: 0.9727 - categorical_accuracy: 0.9727 - auc: 0.9963 - precision: 0.9727 - recall: 0.9727 - true_positives: 356.0000 - true_negatives: 356.0000 - false_positives: 10.0000 - false_negatives: 10.0000 - cohen_kappa: -0.8662 - f1_score: 0.9706
# Epoch 31: val_accuracy did not improve from 0.90361
# 45/45 [==============================] - 20s 441ms/step - loss: 0.0820 - accuracy: 0.9727 - categorical_accuracy: 0.9727 - auc: 0.9963 - precision: 0.9727 - recall: 0.9727 - true_positives: 356.0000 - true_negatives: 356.0000 - false_positives: 10.0000 - false_negatives: 10.0000 - cohen_kappa: -0.8662 - f1_score: 0.9706 - val_loss: 0.3374 - val_accuracy: 0.8916 - val_categorical_accuracy: 0.8916 - val_auc: 0.9332 - val_precision: 0.8916 - val_recall: 0.8916 - val_true_positives: 74.0000 - val_true_negatives: 74.0000 - val_false_positives: 9.0000 - val_false_negatives: 9.0000 - val_cohen_kappa: -0.8902 - val_f1_score: 0.8849 - lr: 1.0000e-05
# Epoch 32/50
# 46/45 [==============================] - ETA: 0s - loss: 0.1040 - accuracy: 0.9617 - categorical_accuracy: 0.9617 - auc: 0.9917 - precision: 0.9617 - recall: 0.9617 - true_positives: 352.0000 - true_negatives: 352.0000 - false_positives: 14.0000 - false_negatives: 14.0000 - cohen_kappa: -0.8762 - f1_score: 0.9590
# Epoch 32: val_accuracy did not improve from 0.90361
# 45/45 [==============================] - 18s 392ms/step - loss: 0.1040 - accuracy: 0.9617 - categorical_accuracy: 0.9617 - auc: 0.9917 - precision: 0.9617 - recall: 0.9617 - true_positives: 352.0000 - true_negatives: 352.0000 - false_positives: 14.0000 - false_negatives: 14.0000 - cohen_kappa: -0.8762 - f1_score: 0.9590 - val_loss: 0.2955 - val_accuracy: 0.8916 - val_categorical_accuracy: 0.8916 - val_auc: 0.9450 - val_precision: 0.8916 - val_recall: 0.8916 - val_true_positives: 74.0000 - val_true_negatives: 74.0000 - val_false_positives: 9.0000 - val_false_negatives: 9.0000 - val_cohen_kappa: -0.8687 - val_f1_score: 0.8834 - lr: 1.0000e-05
# Epoch 33/50
# 46/45 [==============================] - ETA: 0s - loss: 0.0822 - accuracy: 0.9754 - categorical_accuracy: 0.9754 - auc: 0.9954 - precision: 0.9754 - recall: 0.9754 - true_positives: 357.0000 - true_negatives: 357.0000 - false_positives: 9.0000 - false_negatives: 9.0000 - cohen_kappa: -0.8687 - f1_score: 0.9736
# Epoch 33: val_accuracy did not improve from 0.90361
# 45/45 [==============================] - 17s 370ms/step - loss: 0.0822 - accuracy: 0.9754 - categorical_accuracy: 0.9754 - auc: 0.9954 - precision: 0.9754 - recall: 0.9754 - true_positives: 357.0000 - true_negatives: 357.0000 - false_positives: 9.0000 - false_negatives: 9.0000 - cohen_kappa: -0.8687 - f1_score: 0.9736 - val_loss: 0.3423 - val_accuracy: 0.8916 - val_categorical_accuracy: 0.8916 - val_auc: 0.9329 - val_precision: 0.8916 - val_recall: 0.8916 - val_true_positives: 74.0000 - val_true_negatives: 74.0000 - val_false_positives: 9.0000 - val_false_negatives: 9.0000 - val_cohen_kappa: -0.8902 - val_f1_score: 0.8849 - lr: 1.0000e-05
# Epoch 34/50
# 46/45 [==============================] - ETA: 0s - loss: 0.0784 - accuracy: 0.9699 - categorical_accuracy: 0.9699 - auc: 0.9953 - precision: 0.9699 - recall: 0.9699 - true_positives: 355.0000 - true_negatives: 355.0000 - false_positives: 11.0000 - false_negatives: 11.0000 - cohen_kappa: -0.8787 - f1_score: 0.9679
# Epoch 34: val_accuracy did not improve from 0.90361
# 45/45 [==============================] - 16s 350ms/step - loss: 0.0784 - accuracy: 0.9699 - categorical_accuracy: 0.9699 - auc: 0.9953 - precision: 0.9699 - recall: 0.9699 - true_positives: 355.0000 - true_negatives: 355.0000 - false_positives: 11.0000 - false_negatives: 11.0000 - cohen_kappa: -0.8787 - f1_score: 0.9679 - val_loss: 0.3183 - val_accuracy: 0.9036 - val_categorical_accuracy: 0.9036 - val_auc: 0.9403 - val_precision: 0.9036 - val_recall: 0.9036 - val_true_positives: 75.0000 - val_true_negatives: 75.0000 - val_false_positives: 8.0000 - val_false_negatives: 8.0000 - val_cohen_kappa: -0.8797 - val_f1_score: 0.8970 - lr: 1.0000e-05
# Epoch 35/50
# 46/45 [==============================] - ETA: 0s - loss: 0.0678 - accuracy: 0.9781 - categorical_accuracy: 0.9781 - auc: 0.9964 - precision: 0.9781 - recall: 0.9781 - true_positives: 358.0000 - true_negatives: 358.0000 - false_positives: 8.0000 - false_negatives: 8.0000 - cohen_kappa: -0.8611 - f1_score: 0.9764
# Epoch 35: val_accuracy did not improve from 0.90361
# 45/45 [==============================] - 16s 347ms/step - loss: 0.0678 - accuracy: 0.9781 - categorical_accuracy: 0.9781 - auc: 0.9964 - precision: 0.9781 - recall: 0.9781 - true_positives: 358.0000 - true_negatives: 358.0000 - false_positives: 8.0000 - false_negatives: 8.0000 - cohen_kappa: -0.8611 - f1_score: 0.9764 - val_loss: 0.3477 - val_accuracy: 0.9036 - val_categorical_accuracy: 0.9036 - val_auc: 0.9332 - val_precision: 0.9036 - val_recall: 0.9036 - val_true_positives: 75.0000 - val_true_negatives: 75.0000 - val_false_positives: 8.0000 - val_false_negatives: 8.0000 - val_cohen_kappa: -0.8797 - val_f1_score: 0.8970 - lr: 1.0000e-05
# Epoch 36/50
# 46/45 [==============================] - ETA: 0s - loss: 0.0487 - accuracy: 0.9781 - categorical_accuracy: 0.9781 - auc: 0.9993 - precision: 0.9781 - recall: 0.9781 - true_positives: 358.0000 - true_negatives: 358.0000 - false_positives: 8.0000 - false_negatives: 8.0000 - cohen_kappa: -0.8662 - f1_score: 0.9765
# Epoch 36: val_accuracy did not improve from 0.90361
# 45/45 [==============================] - 20s 431ms/step - loss: 0.0487 - accuracy: 0.9781 - categorical_accuracy: 0.9781 - auc: 0.9993 - precision: 0.9781 - recall: 0.9781 - true_positives: 358.0000 - true_negatives: 358.0000 - false_positives: 8.0000 - false_negatives: 8.0000 - cohen_kappa: -0.8662 - f1_score: 0.9765 - val_loss: 0.3344 - val_accuracy: 0.9036 - val_categorical_accuracy: 0.9036 - val_auc: 0.9390 - val_precision: 0.9036 - val_recall: 0.9036 - val_true_positives: 75.0000 - val_true_negatives: 75.0000 - val_false_positives: 8.0000 - val_false_negatives: 8.0000 - val_cohen_kappa: -0.8797 - val_f1_score: 0.8970 - lr: 1.0000e-05
# Epoch 37/50
# 46/45 [==============================] - ETA: 0s - loss: 0.0496 - accuracy: 0.9781 - categorical_accuracy: 0.9781 - auc: 0.9990 - precision: 0.9781 - recall: 0.9781 - true_positives: 358.0000 - true_negatives: 358.0000 - false_positives: 8.0000 - false_negatives: 8.0000 - cohen_kappa: -0.8662 - f1_score: 0.9765
# Epoch 37: val_accuracy did not improve from 0.90361
# 45/45 [==============================] - 19s 421ms/step - loss: 0.0496 - accuracy: 0.9781 - categorical_accuracy: 0.9781 - auc: 0.9990 - precision: 0.9781 - recall: 0.9781 - true_positives: 358.0000 - true_negatives: 358.0000 - false_positives: 8.0000 - false_negatives: 8.0000 - cohen_kappa: -0.8662 - f1_score: 0.9765 - val_loss: 0.3783 - val_accuracy: 0.8916 - val_categorical_accuracy: 0.8916 - val_auc: 0.9248 - val_precision: 0.8916 - val_recall: 0.8916 - val_true_positives: 74.0000 - val_true_negatives: 74.0000 - val_false_positives: 9.0000 - val_false_negatives: 9.0000 - val_cohen_kappa: -0.8902 - val_f1_score: 0.8849 - lr: 1.0000e-05
# Epoch 38/50
# 46/45 [==============================] - ETA: 0s - loss: 0.0598 - accuracy: 0.9836 - categorical_accuracy: 0.9836 - auc: 0.9969 - precision: 0.9836 - recall: 0.9836 - true_positives: 360.0000 - true_negatives: 360.0000 - false_positives: 6.0000 - false_negatives: 6.0000 - cohen_kappa: -0.8713 - f1_score: 0.9824
# Epoch 38: val_accuracy did not improve from 0.90361
# 45/45 [==============================] - 19s 401ms/step - loss: 0.0598 - accuracy: 0.9836 - categorical_accuracy: 0.9836 - auc: 0.9969 - precision: 0.9836 - recall: 0.9836 - true_positives: 360.0000 - true_negatives: 360.0000 - false_positives: 6.0000 - false_negatives: 6.0000 - cohen_kappa: -0.8713 - f1_score: 0.9824 - val_loss: 0.2792 - val_accuracy: 0.9036 - val_categorical_accuracy: 0.9036 - val_auc: 0.9499 - val_precision: 0.9036 - val_recall: 0.9036 - val_true_positives: 75.0000 - val_true_negatives: 75.0000 - val_false_positives: 8.0000 - val_false_negatives: 8.0000 - val_cohen_kappa: -0.8797 - val_f1_score: 0.8970 - lr: 1.0000e-05
# Epoch 39/50
# 46/45 [==============================] - ETA: 0s - loss: 0.0675 - accuracy: 0.9754 - categorical_accuracy: 0.9754 - auc: 0.9972 - precision: 0.9754 - recall: 0.9754 - true_positives: 357.0000 - true_negatives: 357.0000 - false_positives: 9.0000 - false_negatives: 9.0000 - cohen_kappa: -0.8585 - f1_score: 0.9734
# Epoch 39: val_accuracy did not improve from 0.90361
# 45/45 [==============================] - 18s 383ms/step - loss: 0.0675 - accuracy: 0.9754 - categorical_accuracy: 0.9754 - auc: 0.9972 - precision: 0.9754 - recall: 0.9754 - true_positives: 357.0000 - true_negatives: 357.0000 - false_positives: 9.0000 - false_negatives: 9.0000 - cohen_kappa: -0.8585 - f1_score: 0.9734 - val_loss: 0.3393 - val_accuracy: 0.9036 - val_categorical_accuracy: 0.9036 - val_auc: 0.9392 - val_precision: 0.9036 - val_recall: 0.9036 - val_true_positives: 75.0000 - val_true_negatives: 75.0000 - val_false_positives: 8.0000 - val_false_negatives: 8.0000 - val_cohen_kappa: -0.8797 - val_f1_score: 0.8970 - lr: 1.0000e-05
# Epoch 40/50
# 46/45 [==============================] - ETA: 0s - loss: 0.0518 - accuracy: 0.9809 - categorical_accuracy: 0.9809 - auc: 0.9985 - precision: 0.9809 - recall: 0.9809 - true_positives: 359.0000 - true_negatives: 359.0000 - false_positives: 7.0000 - false_negatives: 7.0000 - cohen_kappa: -0.8636 - f1_score: 0.9794
# Epoch 40: val_accuracy did not improve from 0.90361
# 45/45 [==============================] - 18s 384ms/step - loss: 0.0518 - accuracy: 0.9809 - categorical_accuracy: 0.9809 - auc: 0.9985 - precision: 0.9809 - recall: 0.9809 - true_positives: 359.0000 - true_negatives: 359.0000 - false_positives: 7.0000 - false_negatives: 7.0000 - cohen_kappa: -0.8636 - f1_score: 0.9794 - val_loss: 0.3064 - val_accuracy: 0.9036 - val_categorical_accuracy: 0.9036 - val_auc: 0.9463 - val_precision: 0.9036 - val_recall: 0.9036 - val_true_positives: 75.0000 - val_true_negatives: 75.0000 - val_false_positives: 8.0000 - val_false_negatives: 8.0000 - val_cohen_kappa: -0.8797 - val_f1_score: 0.8970 - lr: 1.0000e-05
# Epoch 41/50
# 46/45 [==============================] - ETA: 0s - loss: 0.0450 - accuracy: 0.9836 - categorical_accuracy: 0.9836 - auc: 0.9993 - precision: 0.9836 - recall: 0.9836 - true_positives: 360.0000 - true_negatives: 360.0000 - false_positives: 6.0000 - false_negatives: 6.0000 - cohen_kappa: -0.8611 - f1_score: 0.9823
# Epoch 41: val_accuracy did not improve from 0.90361
# 45/45 [==============================] - 18s 386ms/step - loss: 0.0450 - accuracy: 0.9836 - categorical_accuracy: 0.9836 - auc: 0.9993 - precision: 0.9836 - recall: 0.9836 - true_positives: 360.0000 - true_negatives: 360.0000 - false_positives: 6.0000 - false_negatives: 6.0000 - cohen_kappa: -0.8611 - f1_score: 0.9823 - val_loss: 0.4033 - val_accuracy: 0.8795 - val_categorical_accuracy: 0.8795 - val_auc: 0.9250 - val_precision: 0.8795 - val_recall: 0.8795 - val_true_positives: 73.0000 - val_true_negatives: 73.0000 - val_false_positives: 10.0000 - val_false_negatives: 10.0000 - val_cohen_kappa: -0.9004 - val_f1_score: 0.8729 - lr: 1.0000e-05
# Epoch 42/50
# 46/45 [==============================] - ETA: 0s - loss: 0.0728 - accuracy: 0.9781 - categorical_accuracy: 0.9781 - auc: 0.9924 - precision: 0.9781 - recall: 0.9781 - true_positives: 358.0000 - true_negatives: 358.0000 - false_positives: 8.0000 - false_negatives: 8.0000 - cohen_kappa: -0.8762 - f1_score: 0.9766
# Epoch 42: val_accuracy did not improve from 0.90361
# 45/45 [==============================] - 18s 392ms/step - loss: 0.0728 - accuracy: 0.9781 - categorical_accuracy: 0.9781 - auc: 0.9924 - precision: 0.9781 - recall: 0.9781 - true_positives: 358.0000 - true_negatives: 358.0000 - false_positives: 8.0000 - false_negatives: 8.0000 - cohen_kappa: -0.8762 - f1_score: 0.9766 - val_loss: 0.2714 - val_accuracy: 0.9036 - val_categorical_accuracy: 0.9036 - val_auc: 0.9535 - val_precision: 0.9036 - val_recall: 0.9036 - val_true_positives: 75.0000 - val_true_negatives: 75.0000 - val_false_positives: 8.0000 - val_false_negatives: 8.0000 - val_cohen_kappa: -0.8797 - val_f1_score: 0.8970 - lr: 1.0000e-05
# Epoch 43/50
# 46/45 [==============================] - ETA: 0s - loss: 0.0557 - accuracy: 0.9863 - categorical_accuracy: 0.9863 - auc: 0.9981 - precision: 0.9863 - recall: 0.9863 - true_positives: 361.0000 - true_negatives: 361.0000 - false_positives: 5.0000 - false_negatives: 5.0000 - cohen_kappa: -0.8636 - f1_score: 0.9853
# Epoch 43: val_accuracy did not improve from 0.90361
# 45/45 [==============================] - 16s 355ms/step - loss: 0.0557 - accuracy: 0.9863 - categorical_accuracy: 0.9863 - auc: 0.9981 - precision: 0.9863 - recall: 0.9863 - true_positives: 361.0000 - true_negatives: 361.0000 - false_positives: 5.0000 - false_negatives: 5.0000 - cohen_kappa: -0.8636 - f1_score: 0.9853 - val_loss: 0.3484 - val_accuracy: 0.8916 - val_categorical_accuracy: 0.8916 - val_auc: 0.9430 - val_precision: 0.8916 - val_recall: 0.8916 - val_true_positives: 74.0000 - val_true_negatives: 74.0000 - val_false_positives: 9.0000 - val_false_negatives: 9.0000 - val_cohen_kappa: -0.8902 - val_f1_score: 0.8849 - lr: 1.0000e-05
# Epoch 44/50
# 46/45 [==============================] - ETA: 0s - loss: 0.0767 - accuracy: 0.9781 - categorical_accuracy: 0.9781 - auc: 0.9953 - precision: 0.9781 - recall: 0.9781 - true_positives: 358.0000 - true_negatives: 358.0000 - false_positives: 8.0000 - false_negatives: 8.0000 - cohen_kappa: -0.8662 - f1_score: 0.9765
# Epoch 44: val_accuracy did not improve from 0.90361
# 45/45 [==============================] - 18s 391ms/step - loss: 0.0767 - accuracy: 0.9781 - categorical_accuracy: 0.9781 - auc: 0.9953 - precision: 0.9781 - recall: 0.9781 - true_positives: 358.0000 - true_negatives: 358.0000 - false_positives: 8.0000 - false_negatives: 8.0000 - cohen_kappa: -0.8662 - f1_score: 0.9765 - val_loss: 0.3078 - val_accuracy: 0.8916 - val_categorical_accuracy: 0.8916 - val_auc: 0.9477 - val_precision: 0.8916 - val_recall: 0.8916 - val_true_positives: 74.0000 - val_true_negatives: 74.0000 - val_false_positives: 9.0000 - val_false_negatives: 9.0000 - val_cohen_kappa: -0.8902 - val_f1_score: 0.8849 - lr: 1.0000e-05
# Epoch 45/50
# 46/45 [==============================] - ETA: 0s - loss: 0.0591 - accuracy: 0.9781 - categorical_accuracy: 0.9781 - auc: 0.9976 - precision: 0.9781 - recall: 0.9781 - true_positives: 358.0000 - true_negatives: 358.0000 - false_positives: 8.0000 - false_negatives: 8.0000 - cohen_kappa: -0.8662 - f1_score: 0.9765
# Epoch 45: val_accuracy did not improve from 0.90361
# 45/45 [==============================] - 18s 397ms/step - loss: 0.0591 - accuracy: 0.9781 - categorical_accuracy: 0.9781 - auc: 0.9976 - precision: 0.9781 - recall: 0.9781 - true_positives: 358.0000 - true_negatives: 358.0000 - false_positives: 8.0000 - false_negatives: 8.0000 - cohen_kappa: -0.8662 - f1_score: 0.9765 - val_loss: 0.3191 - val_accuracy: 0.8916 - val_categorical_accuracy: 0.8916 - val_auc: 0.9447 - val_precision: 0.8916 - val_recall: 0.8916 - val_true_positives: 74.0000 - val_true_negatives: 74.0000 - val_false_positives: 9.0000 - val_false_negatives: 9.0000 - val_cohen_kappa: -0.8902 - val_f1_score: 0.8849 - lr: 1.0000e-05
# Epoch 46/50
# 46/45 [==============================] - ETA: 0s - loss: 0.0463 - accuracy: 0.9809 - categorical_accuracy: 0.9809 - auc: 0.9987 - precision: 0.9809 - recall: 0.9809 - true_positives: 359.0000 - true_negatives: 359.0000 - false_positives: 7.0000 - false_negatives: 7.0000 - cohen_kappa: -0.8687 - f1_score: 0.9794
# Epoch 46: val_accuracy did not improve from 0.90361
# 45/45 [==============================] - 19s 421ms/step - loss: 0.0463 - accuracy: 0.9809 - categorical_accuracy: 0.9809 - auc: 0.9987 - precision: 0.9809 - recall: 0.9809 - true_positives: 359.0000 - true_negatives: 359.0000 - false_positives: 7.0000 - false_negatives: 7.0000 - cohen_kappa: -0.8687 - f1_score: 0.9794 - val_loss: 0.2236 - val_accuracy: 0.9036 - val_categorical_accuracy: 0.9036 - val_auc: 0.9670 - val_precision: 0.9036 - val_recall: 0.9036 - val_true_positives: 75.0000 - val_true_negatives: 75.0000 - val_false_positives: 8.0000 - val_false_negatives: 8.0000 - val_cohen_kappa: -0.8797 - val_f1_score: 0.8970 - lr: 1.0000e-05
# Epoch 47/50
# 46/45 [==============================] - ETA: 0s - loss: 0.0451 - accuracy: 0.9863 - categorical_accuracy: 0.9863 - auc: 0.9984 - precision: 0.9863 - recall: 0.9863 - true_positives: 361.0000 - true_negatives: 361.0000 - false_positives: 5.0000 - false_negatives: 5.0000 - cohen_kappa: -0.8636 - f1_score: 0.9853
# Epoch 47: val_accuracy did not improve from 0.90361
# 45/45 [==============================] - 17s 379ms/step - loss: 0.0451 - accuracy: 0.9863 - categorical_accuracy: 0.9863 - auc: 0.9984 - precision: 0.9863 - recall: 0.9863 - true_positives: 361.0000 - true_negatives: 361.0000 - false_positives: 5.0000 - false_negatives: 5.0000 - cohen_kappa: -0.8636 - f1_score: 0.9853 - val_loss: 0.2470 - val_accuracy: 0.8916 - val_categorical_accuracy: 0.8916 - val_auc: 0.9643 - val_precision: 0.8916 - val_recall: 0.8916 - val_true_positives: 74.0000 - val_true_negatives: 74.0000 - val_false_positives: 9.0000 - val_false_negatives: 9.0000 - val_cohen_kappa: -0.8902 - val_f1_score: 0.8849 - lr: 1.0000e-05
# Epoch 48/50
# 46/45 [==============================] - ETA: 0s - loss: 0.0519 - accuracy: 0.9836 - categorical_accuracy: 0.9836 - auc: 0.9984 - precision: 0.9836 - recall: 0.9836 - true_positives: 360.0000 - true_negatives: 360.0000 - false_positives: 6.0000 - false_negatives: 6.0000 - cohen_kappa: -0.8611 - f1_score: 0.9823
# Epoch 48: val_accuracy did not improve from 0.90361
# 45/45 [==============================] - 18s 380ms/step - loss: 0.0519 - accuracy: 0.9836 - categorical_accuracy: 0.9836 - auc: 0.9984 - precision: 0.9836 - recall: 0.9836 - true_positives: 360.0000 - true_negatives: 360.0000 - false_positives: 6.0000 - false_negatives: 6.0000 - cohen_kappa: -0.8611 - f1_score: 0.9823 - val_loss: 0.2245 - val_accuracy: 0.9036 - val_categorical_accuracy: 0.9036 - val_auc: 0.9721 - val_precision: 0.9036 - val_recall: 0.9036 - val_true_positives: 75.0000 - val_true_negatives: 75.0000 - val_false_positives: 8.0000 - val_false_negatives: 8.0000 - val_cohen_kappa: -0.8797 - val_f1_score: 0.8970 - lr: 1.0000e-05
# Epoch 49/50
# 46/45 [==============================] - ETA: 0s - loss: 0.0573 - accuracy: 0.9754 - categorical_accuracy: 0.9754 - auc: 0.9983 - precision: 0.9754 - recall: 0.9754 - true_positives: 357.0000 - true_negatives: 357.0000 - false_positives: 9.0000 - false_negatives: 9.0000 - cohen_kappa: -0.8636 - f1_score: 0.9735
# Epoch 49: val_accuracy did not improve from 0.90361
# 45/45 [==============================] - 18s 384ms/step - loss: 0.0573 - accuracy: 0.9754 - categorical_accuracy: 0.9754 - auc: 0.9983 - precision: 0.9754 - recall: 0.9754 - true_positives: 357.0000 - true_negatives: 357.0000 - false_positives: 9.0000 - false_negatives: 9.0000 - cohen_kappa: -0.8636 - f1_score: 0.9735 - val_loss: 0.3500 - val_accuracy: 0.8795 - val_categorical_accuracy: 0.8795 - val_auc: 0.9457 - val_precision: 0.8795 - val_recall: 0.8795 - val_true_positives: 73.0000 - val_true_negatives: 73.0000 - val_false_positives: 10.0000 - val_false_negatives: 10.0000 - val_cohen_kappa: -0.9004 - val_f1_score: 0.8729 - lr: 1.0000e-05
# Epoch 50/50
# 46/45 [==============================] - ETA: 0s - loss: 0.0367 - accuracy: 0.9863 - categorical_accuracy: 0.9863 - auc: 0.9995 - precision: 0.9863 - recall: 0.9863 - true_positives: 361.0000 - true_negatives: 361.0000 - false_positives: 5.0000 - false_negatives: 5.0000 - cohen_kappa: -0.8479 - f1_score: 0.9851
# Epoch 50: val_accuracy did not improve from 0.90361
# 45/45 [==============================] - 17s 368ms/step - loss: 0.0367 - accuracy: 0.9863 - categorical_accuracy: 0.9863 - auc: 0.9995 - precision: 0.9863 - recall: 0.9863 - true_positives: 361.0000 - true_negatives: 361.0000 - false_positives: 5.0000 - false_negatives: 5.0000 - cohen_kappa: -0.8479 - f1_score: 0.9851 - val_loss: 0.3038 - val_accuracy: 0.8916 - val_categorical_accuracy: 0.8916 - val_auc: 0.9550 - val_precision: 0.8916 - val_recall: 0.8916 - val_true_positives: 74.0000 - val_true_negatives: 74.0000 - val_false_positives: 9.0000 - val_false_negatives: 9.0000 - val_cohen_kappa: -0.8902 - val_f1_score: 0.8849 - lr: 1.0000e-05

# %%
model = keras.models.load_model(weight)
evaluate_(model, generator_test)
plot_graphs(history, generator_test)
# Out:
# 11/11 [==============================] - 8s 183ms/step - loss: 0.3570 - accuracy: 0.9036 - categorical_accuracy: 0.9036 - auc: 0.9235 - precision: 0.9036 - recall: 0.9036 - true_positives: 75.0000 - true_negatives: 75.0000 - false_positives: 8.0000 - false_negatives: 8.0000 - cohen_kappa: -0.8797 - f1_score: 0.8970
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87        27
#            1       1.00      0.86      0.92        56
#
#     accuracy                           0.90        83
#    macro avg       0.89      0.93      0.90        83
# weighted avg       0.93      0.90      0.91        83
# C:\Users\HSSL77\AppData\Local\Temp\ipykernel_12164\3330063544.py:38: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   predictions = model.predict_generator(generator_test)
